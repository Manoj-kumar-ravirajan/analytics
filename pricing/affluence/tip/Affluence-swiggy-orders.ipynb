# %%
import h3 as h3
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats
from pyhive import presto
from keplergl import KeplerGl
from datetime import datetime, timedelta

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 1200)

# %% [markdown]
# ## Connection

# %%
## Connection
connection = presto.connect(
        host='presto-gateway.serving.data.production.internal',
        port=80,
        protocol='http',
        catalog='hive',
        username='manoj.ravirajan@rapido.bike'
)

# %% [markdown]
# ## Dataset

# %%
## Generate date range

start_date = '20230703'
end_date = '20230730'
city = 'Bangalore'
service = 'Delivery'

# %%
## datasets.service_mapping

service_mapping = f"""
        SELECT 
            city_display_name AS city,
            service_level AS service_name,
            service_detail_id,
            city_id,
            service_id
        FROM 
            datasets.service_mapping
        WHERE 
            city_display_name = '{city}'
            AND service_level = '{service}'
"""

df_service_mapping = pd.read_sql(service_mapping, connection)
service_detail_id = df_service_mapping.service_detail_id.loc[0]
df_service_mapping
# service_detail_id
# Out:
#         city service_name         service_detail_id                   city_id  \
# 0  Bangalore     Delivery  58dceb1f24565ce21202bca4  572ca7ff116b5db3057bd814
#
#                  service_id
# 0  58dcea3824565ce21202bca3

# %%
df_hex_affluence_tag = pd.read_csv('/Users/rapido/local-datasets/affluence/main/hex_affluence_tag.csv')
df_hex_affluence_tag =df_hex_affluence_tag[['pickup_hex_8', 'affluence_tag']]
df_hex_affluence_tag
# Out:
#          pickup_hex_8 affluence_tag
# 0     88618920a3fffff          High
# 1     8861892581fffff          High
# 2     886189258bfffff          High
# 3     886189258dfffff          High
# 4     8861892425fffff          High
# ...               ...           ...
# 2680  8860145955fffff          High
# 2681  8860145957fffff          High
# 2682  8860145959fffff          High
# 2683  886014595bfffff          High
# 2684  886014594bfffff          Less
#
# [2685 rows x 2 columns]

# %%
df_overlap_details = pd.read_csv('/Users/rapido/local-datasets/affluence/final/Bangalore Affluence List only 70 hex sample.csv')
df_overlap_details = df_overlap_details[['pickup_hex_8' ,'affluence_tag']]
df_overlap_details.head(2)
# Out:
#       pickup_hex_8   affluence_tag
# 0  88618921d3fffff  High Affluence
# 1  88618921c7fffff  High Affluence

# %%
## orders.order_logs_snapshot --> Tips

order_logs_snapshot = f"""
        
        SELECT
            -- yyyymmdd,
            city_name,
            location_hex_8,
            COUNT(DISTINCT CASE WHEN service_obj_service_name = 'Link' THEN order_id END) link_orders,
            COUNT(DISTINCT CASE WHEN service_obj_service_name = 'Auto' THEN order_id END) auto_orders,
            COUNT(DISTINCT CASE WHEN service_obj_service_name IN ('Auto', 'Link') THEN order_id END) taxi_orders,
            COUNT(DISTINCT CASE WHEN service_obj_service_name = 'Delivery' THEN order_id END) swiggy_orders,
            -- COUNT(DISTINCT CASE WHEN service_obj_service_name = 'Delivery' THEN customer_id END) swiggy_customers,
            COALESCE(ROUND(APPROX_PERCENTILE(bill_amount,0.50)), 0) swiggy_median_bill_amount,
            COALESCE(ROUND(AVG(bill_amount)), 0) swiggy_mean_bill_amount,
            COALESCE(SUM(bill_amount), 0) swiggy_total_bill_amount
            
        FROM
        (    
            SELECT  
                yyyymmdd,
                city_name,
                service_obj_service_name,
                order_id,
                customer_id,
                CASE 
                WHEN service_obj_service_name = 'Link' THEN pickup_location_hex_8
                WHEN service_obj_service_name = 'Auto' THEN pickup_location_hex_8
                WHEN service_obj_service_name = 'Delivery' THEN drop_location_hex_8
                END AS location_hex_8,
                delivery_info_bill_amount bill_amount

            FROM

                orders.order_logs_snapshot ols 

            WHERE 
                yyyymmdd >= '{start_date}'
                AND yyyymmdd <= '{end_date}'
                AND city_name = 'Bangalore'
                AND order_status = 'dropped'
                AND service_obj_service_name IN ('Delivery', 'Link', 'Auto')
        )
        GROUP BY 1,2

"""

df_swiggy_orders = pd.read_sql(order_logs_snapshot, connection)
df_swiggy_orders.head(2)
# Out:
#    city_name   location_hex_8  link_orders  auto_orders  taxi_orders  \
# 0  Bangalore  886014c967fffff           35            7           42
# 1  Bangalore  8861892195fffff          941          484         1425
#
#    swiggy_orders  swiggy_median_bill_amount  swiggy_mean_bill_amount  \
# 0             24                      373.0                    421.0
# 1            681                      339.0                    437.0
#
#    swiggy_total_bill_amount
# 0                   10098.0
# 1                  297635.0

# %%
df_swiggy_orders.to_csv('/Users/rapido/local-datasets/affluence/raw/raw_ols_swiggy_details_{}_{}_{}_{}.csv' \
                      .format(city,service,start_date,end_date), index = False)

# %%
df_swiggy_orders = pd.read_csv('/Users/rapido/local-datasets/affluence/raw/raw_ols_swiggy_details_{}_{}_{}_{}.csv' \
                      .format(city,service,start_date,end_date))

# %% [markdown]
# ## Analysis

# %%
df_swiggy_orders.head()
# Out:
#    city_name   location_hex_8  link_orders  auto_orders  taxi_orders  \
# 0  Bangalore  886014c967fffff           35            7           42
# 1  Bangalore  8861892195fffff          941          484         1425
# 2  Bangalore  8860145a93fffff           15            8           23
# 3  Bangalore  8861892d53fffff           12           13           25
# 4  Bangalore  886014521dfffff            2            0            2
#
#    swiggy_orders  swiggy_median_bill_amount  swiggy_mean_bill_amount  \
# 0             24                      373.0                    421.0
# 1            681                      339.0                    437.0
# 2              2                     1597.0                    952.0
# 3              3                      470.0                    450.0
# 4              0                        0.0                      0.0
#
#    swiggy_total_bill_amount
# 0                   10098.0
# 1                  297635.0
# 2                    1903.0
# 3                    1351.0
# 4                       0.0

# %%
df_swiggy_orders.location_hex_8.nunique()
# Out:
# 2163

# %%
df_swiggy_orders[df_swiggy_orders['link_orders'] < df_swiggy_orders['swiggy_orders']].nunique()
# Out:
# city_name                      1
# location_hex_8               367
# link_orders                  144
# auto_orders                  142
# taxi_orders                  166
# swiggy_orders                168
# swiggy_median_bill_amount    237
# swiggy_mean_bill_amount      262
# swiggy_total_bill_amount     364
# dtype: int64

# %%
df_affluence_tag_and_swiggy_orders = pd.merge(df_hex_affluence_tag, 
                                    df_swiggy_orders,
                                    how = 'left',
                                    left_on = ['pickup_hex_8'],
                                    right_on = ['location_hex_8']
                                   )
# df_affluence_tag_and_swiggy_orders['link_orders_contribution'] \
#             = (df_affluence_tag_and_swiggy_orders['link_orders']*100/(df_affluence_tag_and_swiggy_orders['link_orders'] + df_affluence_tag_and_swiggy_orders['swiggy_orders']))

# df_affluence_tag_and_swiggy_orders['auto_orders_contribution'] \
#             = (df_affluence_tag_and_swiggy_orders['auto_orders']*100/(df_affluence_tag_and_swiggy_orders['auto_orders'] + df_affluence_tag_and_swiggy_orders['swiggy_orders']))

# df_affluence_tag_and_swiggy_orders['taxi_orders_contribution'] \
#             = (df_affluence_tag_and_swiggy_orders['taxi_orders']*100/(df_affluence_tag_and_swiggy_orders['taxi_orders'] + df_affluence_tag_and_swiggy_orders['swiggy_orders']))

# df_affluence_tag_and_swiggy_orders['swiggy_orders_contribution'] \
#             = (df_affluence_tag_and_swiggy_orders['swiggy_orders']*100/(df_affluence_tag_and_swiggy_orders['link_orders'] + df_affluence_tag_and_swiggy_orders['swiggy_orders']))


df_affluence_tag_and_swiggy_orders = df_affluence_tag_and_swiggy_orders.round(2)
df_affluence_tag_and_swiggy_orders
# Out:
#          pickup_hex_8 affluence_tag  city_name   location_hex_8  link_orders  \
# 0     88618920a3fffff          High  Bangalore  88618920a3fffff      16049.0
# 1     8861892581fffff          High  Bangalore  8861892581fffff       4069.0
# 2     886189258bfffff          High  Bangalore  886189258bfffff       4293.0
# 3     886189258dfffff          High  Bangalore  886189258dfffff       5884.0
# 4     8861892425fffff          High  Bangalore  8861892425fffff       5397.0
# ...               ...           ...        ...              ...          ...
# 2680  8860145955fffff          High  Bangalore  8860145955fffff        672.0
# 2681  8860145957fffff          High  Bangalore  8860145957fffff       2376.0
# 2682  8860145959fffff          High  Bangalore  8860145959fffff       1027.0
# 2683  886014595bfffff          High  Bangalore  886014595bfffff        796.0
# 2684  886014594bfffff          Less  Bangalore  886014594bfffff       4212.0
#
#       auto_orders  taxi_orders  swiggy_orders  swiggy_median_bill_amount  \
# 0         11293.0      27342.0         7369.0                      271.0
# 1          4201.0       8270.0          441.0                      289.0
# 2          4013.0       8306.0          429.0                      301.0
# 3          7033.0      12917.0         1574.0                      309.0
# 4          9062.0      14459.0         3512.0                      296.0
# ...           ...          ...            ...                        ...
# 2680        601.0       1273.0          327.0                      331.0
# 2681       1695.0       4071.0          141.0                      273.0
# 2682       1194.0       2221.0          563.0                      312.0
# 2683        986.0       1782.0          385.0                      337.0
# 2684       3538.0       7750.0          973.0                      289.0
#
#       swiggy_mean_bill_amount  swiggy_total_bill_amount
# 0                       330.0                 2432131.0
# 1                       363.0                  159916.0
# 2                       386.0                  165752.0
# 3                       387.0                  608619.0
# 4                       359.0                 1259891.0
# ...                       ...                       ...
# 2680                    427.0                  139518.0
# 2681                    355.0                   50004.0
# 2682                    399.0                  224795.0
# 2683                    423.0                  162768.0
# 2684                    356.0                  346812.0
#
# [2685 rows x 11 columns]

# %%
df_affluence_tag_and_swiggy_orders[['link_orders', 'auto_orders', 
                                    'taxi_orders', 'swiggy_orders', 
                                    'swiggy_median_bill_amount']].describe([0.25,0.3,0.6,0.65,0.75,0.8,0.85,0.9,0.95])
# Out:
#         link_orders   auto_orders   taxi_orders  swiggy_orders  \
# count   2095.000000   2095.000000   2095.000000    2095.000000
# mean    1046.103580   1138.868735   2184.972315     417.336516
# std     2202.811007   2730.408532   4806.696473     941.001577
# min        0.000000      0.000000      0.000000       0.000000
# 25%        4.000000      6.000000     12.000000       1.000000
# 30%        8.000000     10.000000     17.000000       2.000000
# 50%       77.000000     64.000000    147.000000      26.000000
# 60%      290.800000    237.000000    546.400000      94.400000
# 65%      491.100000    432.400000    955.900000     161.100000
# 75%     1069.500000   1053.500000   2133.500000     413.500000
# 80%     1502.400000   1515.600000   3065.400000     614.000000
# 85%     2243.800000   2102.500000   4425.200000     895.900000
# 90%     3157.000000   3374.400000   6674.800000    1246.200000
# 95%     5478.200000   5387.900000  10442.200000    1908.500000
# max    21716.000000  32114.000000  52085.000000    8297.000000
#
#        swiggy_median_bill_amount
# count                2095.000000
# mean                  313.101671
# std                   224.885497
# min                     0.000000
# 25%                   275.000000
# 30%                   290.000000
# 50%                   320.000000
# 60%                   333.000000
# 65%                   340.100000
# 75%                   366.000000
# 80%                   390.000000
# 85%                   432.000000
# 90%                   509.600000
# 95%                   634.600000
# max                  1939.000000

# %%
df_affluence_tag_and_swiggy_orders['swiggy_order_flag'] = np.where(df_affluence_tag_and_swiggy_orders['swiggy_orders'] >= df_affluence_tag_and_swiggy_orders.swiggy_orders.quantile(0.80) , 'High Orders', 
                                                             np.where(df_affluence_tag_and_swiggy_orders['swiggy_orders'] >= df_affluence_tag_and_swiggy_orders.swiggy_orders.quantile(0.30) , 'Medium Orders', 
                                                             'Less/No Orders'))

df_affluence_tag_and_swiggy_orders['swiggy_bill_amount_flag'] = np.where(df_affluence_tag_and_swiggy_orders['swiggy_median_bill_amount'] >= df_affluence_tag_and_swiggy_orders.swiggy_median_bill_amount.quantile(0.80)  , 'High Price', 
                                                             np.where(df_affluence_tag_and_swiggy_orders['swiggy_median_bill_amount'] >= df_affluence_tag_and_swiggy_orders.swiggy_median_bill_amount.quantile(0.30) , 'Medium Price', 
                                                            'Less/No Price'))

df_affluence_tag_and_swiggy_orders
# Out:
#          pickup_hex_8 affluence_tag  city_name   location_hex_8  link_orders  \
# 0     88618920a3fffff          High  Bangalore  88618920a3fffff      16049.0
# 1     8861892581fffff          High  Bangalore  8861892581fffff       4069.0
# 2     886189258bfffff          High  Bangalore  886189258bfffff       4293.0
# 3     886189258dfffff          High  Bangalore  886189258dfffff       5884.0
# 4     8861892425fffff          High  Bangalore  8861892425fffff       5397.0
# ...               ...           ...        ...              ...          ...
# 2680  8860145955fffff          High  Bangalore  8860145955fffff        672.0
# 2681  8860145957fffff          High  Bangalore  8860145957fffff       2376.0
# 2682  8860145959fffff          High  Bangalore  8860145959fffff       1027.0
# 2683  886014595bfffff          High  Bangalore  886014595bfffff        796.0
# 2684  886014594bfffff          Less  Bangalore  886014594bfffff       4212.0
#
#       auto_orders  taxi_orders  swiggy_orders  swiggy_median_bill_amount  \
# 0         11293.0      27342.0         7369.0                      271.0
# 1          4201.0       8270.0          441.0                      289.0
# 2          4013.0       8306.0          429.0                      301.0
# 3          7033.0      12917.0         1574.0                      309.0
# 4          9062.0      14459.0         3512.0                      296.0
# ...           ...          ...            ...                        ...
# 2680        601.0       1273.0          327.0                      331.0
# 2681       1695.0       4071.0          141.0                      273.0
# 2682       1194.0       2221.0          563.0                      312.0
# 2683        986.0       1782.0          385.0                      337.0
# 2684       3538.0       7750.0          973.0                      289.0
#
#       swiggy_mean_bill_amount  swiggy_total_bill_amount swiggy_order_flag  \
# 0                       330.0                 2432131.0       High Orders
# 1                       363.0                  159916.0     Medium Orders
# 2                       386.0                  165752.0     Medium Orders
# 3                       387.0                  608619.0       High Orders
# 4                       359.0                 1259891.0       High Orders
# ...                       ...                       ...               ...
# 2680                    427.0                  139518.0     Medium Orders
# 2681                    355.0                   50004.0     Medium Orders
# 2682                    399.0                  224795.0     Medium Orders
# 2683                    423.0                  162768.0     Medium Orders
# 2684                    356.0                  346812.0       High Orders
#
#      swiggy_bill_amount_flag
# 0              Less/No Price
# 1              Less/No Price
# 2               Medium Price
# 3               Medium Price
# 4               Medium Price
# ...                      ...
# 2680            Medium Price
# 2681           Less/No Price
# 2682            Medium Price
# 2683            Medium Price
# 2684           Less/No Price
#
# [2685 rows x 13 columns]

# %% [markdown]
# ### Swiggy Flag

# %%
## swiggy_order_flag

df_aff_swiggy = df_affluence_tag_and_swiggy_orders \
                    .groupby([ 'swiggy_order_flag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_aff_swiggy['swiggy_orders_per_hex'] = df_aff_swiggy['swiggy_orders']/df_aff_swiggy['location_hex_8']
df_aff_swiggy['hex_distr'] = df_aff_swiggy['location_hex_8']*100.0/df_aff_swiggy.location_hex_8.sum()
df_aff_swiggy['swiggy_orders_distr'] = df_aff_swiggy['swiggy_orders']*100.0/df_aff_swiggy.swiggy_orders.sum()


df_aff_swiggy_1 = df_aff_swiggy.round(2)

# %%
## affluence_tag

df_aff_swiggy = df_affluence_tag_and_swiggy_orders \
                    .groupby([ 'affluence_tag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_aff_swiggy['swiggy_orders_per_hex'] = df_aff_swiggy['swiggy_orders']/df_aff_swiggy['location_hex_8']
df_aff_swiggy['hex_distr'] = df_aff_swiggy['location_hex_8']*100.0/df_aff_swiggy.location_hex_8.sum()
df_aff_swiggy['swiggy_orders_distr'] = df_aff_swiggy['swiggy_orders']*100.0/df_aff_swiggy.swiggy_orders.sum()


df_aff_swiggy_2 = df_aff_swiggy.round(2)

# %%
## Overlap

df_aff_swiggy = df_affluence_tag_and_swiggy_orders \
                    .groupby([ 'affluence_tag', 'swiggy_order_flag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_aff_swiggy['swiggy_orders_per_hex'] = df_aff_swiggy['swiggy_orders']/df_aff_swiggy['location_hex_8']
df_aff_swiggy['hex_distr'] = df_aff_swiggy['location_hex_8']*100.0/df_aff_swiggy.location_hex_8.sum()
df_aff_swiggy['swiggy_orders_distr'] = df_aff_swiggy['swiggy_orders']*100.0/df_aff_swiggy.swiggy_orders.sum()


df_aff_swiggy_3 = df_aff_swiggy.round(2)

# %%
df_aff_swiggy_1
# Out:
#   swiggy_order_flag  location_hex_8  link_orders  auto_orders  taxi_orders  \
# 0       High Orders             421    1595695.0    1823971.0    3419666.0
# 1    Less/No Orders             553       3559.0       4322.0       7881.0
# 2     Medium Orders            1121     592333.0     557637.0    1149970.0
#
#    swiggy_orders  swiggy_orders_per_hex  hex_distr  swiggy_orders_distr
# 0       735678.0                1747.45      20.10                84.14
# 1          157.0                   0.28      26.40                 0.02
# 2       138485.0                 123.54      53.51                15.84

# %%
df_aff_swiggy_2
# Out:
#   affluence_tag  location_hex_8  link_orders  auto_orders  taxi_orders  \
# 0          High            1019    1962256.0    2172881.0    4135137.0
# 1          Less            1076     229331.0     213049.0     442380.0
#
#    swiggy_orders  swiggy_orders_per_hex  hex_distr  swiggy_orders_distr
# 0       814329.0                 799.15      48.64                93.14
# 1        59991.0                  55.75      51.36                 6.86

# %%
df_aff_swiggy_3
# Out:
#   affluence_tag swiggy_order_flag  location_hex_8  link_orders  auto_orders  \
# 0          High       High Orders             403    1565276.0    1796095.0
# 1          High    Less/No Orders             162        512.0        914.0
# 2          High     Medium Orders             454     396468.0     375872.0
# 3          Less       High Orders              18      30419.0      27876.0
# 4          Less    Less/No Orders             391       3047.0       3408.0
# 5          Less     Medium Orders             667     195865.0     181765.0
#
#    taxi_orders  swiggy_orders  swiggy_orders_per_hex  hex_distr  \
# 0    3361371.0       719049.0                1784.24      19.24
# 1       1426.0           40.0                   0.25       7.73
# 2     772340.0        95240.0                 209.78      21.67
# 3      58295.0        16629.0                 923.83       0.86
# 4       6455.0          117.0                   0.30      18.66
# 5     377630.0        43245.0                  64.84      31.84
#
#    swiggy_orders_distr
# 0                82.24
# 1                 0.00
# 2                10.89
# 3                 1.90
# 4                 0.01
# 5                 4.95

# %%
# 30| 80| 80+
ha = round(403*100/421,2)
la = round(391*100/396,2)
print('High Swiggy with High Affluence signal overlap percentage',ha)
print('Less Swiggy with Less Affluence signal overlap percentage',la)
# Out:
# High Swiggy with High Affluence signal overlap percentage 95.72
# Less Swiggy with Less Affluence signal overlap percentage 98.74

# %% [markdown]
# ### Billing amount

# %%
df_aff_swiggy = df_affluence_tag_and_swiggy_orders \
                    .groupby([ 'swiggy_bill_amount_flag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_aff_swiggy['swiggy_orders_per_hex'] = df_aff_swiggy['swiggy_orders']/df_aff_swiggy['location_hex_8']
df_aff_swiggy['hex_distr'] = df_aff_swiggy['location_hex_8']*100.0/df_aff_swiggy.location_hex_8.sum()
df_aff_swiggy['swiggy_orders_distr'] = df_aff_swiggy['swiggy_orders']*100.0/df_aff_swiggy.swiggy_orders.sum()

df_aff_swiggy_bill_1 = df_aff_swiggy.round(2)

# %%
df_aff_swiggy = df_affluence_tag_and_swiggy_orders \
                    .groupby(['affluence_tag', 'swiggy_order_flag', 'swiggy_bill_amount_flag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_aff_swiggy['swiggy_orders_per_hex'] = df_aff_swiggy['swiggy_orders']/df_aff_swiggy['location_hex_8']
df_aff_swiggy['hex_distr'] = df_aff_swiggy['location_hex_8']*100.0/df_aff_swiggy.location_hex_8.sum()
df_aff_swiggy['swiggy_orders_distr'] = df_aff_swiggy['swiggy_orders']*100.0/df_aff_swiggy.swiggy_orders.sum()

df_aff_swiggy_bill_2 = df_aff_swiggy.round(2)

# %%
df_aff_swiggy = df_affluence_tag_and_swiggy_orders \
                    .groupby(['affluence_tag', 'swiggy_bill_amount_flag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_aff_swiggy['swiggy_orders_per_hex'] = df_aff_swiggy['swiggy_orders']/df_aff_swiggy['location_hex_8']
df_aff_swiggy['hex_distr'] = df_aff_swiggy['location_hex_8']*100.0/df_aff_swiggy.location_hex_8.sum()
df_aff_swiggy['swiggy_orders_distr'] = df_aff_swiggy['swiggy_orders']*100.0/df_aff_swiggy.swiggy_orders.sum()

df_aff_swiggy_bill_3 = df_aff_swiggy.round(2)

# %%
#df_aff_swiggy_1

# %%
#df_aff_swiggy_2

# %%
df_aff_swiggy_bill_1
# Out:
#   swiggy_bill_amount_flag  location_hex_8  link_orders  auto_orders  \
# 0              High Price             420      20268.0      18520.0
# 1           Less/No Price             624     414691.0     493507.0
# 2            Medium Price            1051    1756628.0    1873903.0
#
#    taxi_orders  swiggy_orders  swiggy_orders_per_hex  hex_distr  \
# 0      38788.0        10173.0                  24.22      20.05
# 1     908198.0       149053.0                 238.87      29.79
# 2    3630531.0       715094.0                 680.39      50.17
#
#    swiggy_orders_distr
# 0                 1.16
# 1                17.05
# 2                81.79

# %%
df_aff_swiggy_bill_2
# Out:
#    affluence_tag swiggy_order_flag swiggy_bill_amount_flag  location_hex_8  \
# 0           High       High Orders              High Price               2
# 1           High       High Orders           Less/No Price              40
# 2           High       High Orders            Medium Price             361
# 3           High    Less/No Orders              High Price              26
# 4           High    Less/No Orders           Less/No Price             133
# 5           High    Less/No Orders            Medium Price               3
# 6           High     Medium Orders              High Price              79
# 7           High     Medium Orders           Less/No Price              53
# 8           High     Medium Orders            Medium Price             322
# 9           Less       High Orders           Less/No Price               2
# 10          Less       High Orders            Medium Price              16
# 11          Less    Less/No Orders              High Price              61
# 12          Less    Less/No Orders           Less/No Price             306
# 13          Less    Less/No Orders            Medium Price              24
# 14          Less     Medium Orders              High Price             252
# 15          Less     Medium Orders           Less/No Price              90
# 16          Less     Medium Orders            Medium Price             325
#
#     link_orders  auto_orders  taxi_orders  swiggy_orders  \
# 0         456.0        251.0        707.0         1466.0
# 1      331632.0     411180.0     742812.0       135386.0
# 2     1233188.0    1384664.0    2617852.0       582197.0
# 3          90.0         66.0        156.0           26.0
# 4         396.0        832.0       1228.0           11.0
# 5          26.0         16.0         42.0            3.0
# 6        5498.0       5604.0      11102.0         3827.0
# 7       58784.0      58950.0     117734.0         8332.0
# 8      332186.0     311318.0     643504.0        83081.0
# 9        5196.0       4350.0       9546.0         2483.0
# 10      25223.0      23526.0      48749.0        14146.0
# 11       1721.0       1201.0       2922.0           61.0
# 12       1073.0       1989.0       3062.0           32.0
# 13        253.0        218.0        471.0           24.0
# 14      12503.0      11398.0      23901.0         4793.0
# 15      17610.0      16206.0      33816.0         2809.0
# 16     165752.0     154161.0     319913.0        35643.0
#
#     swiggy_orders_per_hex  hex_distr  swiggy_orders_distr
# 0                  733.00       0.10                 0.17
# 1                 3384.65       1.91                15.48
# 2                 1612.73      17.23                66.59
# 3                    1.00       1.24                 0.00
# 4                    0.08       6.35                 0.00
# 5                    1.00       0.14                 0.00
# 6                   48.44       3.77                 0.44
# 7                  157.21       2.53                 0.95
# 8                  258.02      15.37                 9.50
# 9                 1241.50       0.10                 0.28
# 10                 884.12       0.76                 1.62
# 11                   1.00       2.91                 0.01
# 12                   0.10      14.61                 0.00
# 13                   1.00       1.15                 0.00
# 14                  19.02      12.03                 0.55
# 15                  31.21       4.30                 0.32
# 16                 109.67      15.51                 4.08

# %%
df_aff_swiggy_bill_3
# Out:
#   affluence_tag swiggy_bill_amount_flag  location_hex_8  link_orders  \
# 0          High              High Price             107       6044.0
# 1          High           Less/No Price             226     390812.0
# 2          High            Medium Price             686    1565400.0
# 3          Less              High Price             313      14224.0
# 4          Less           Less/No Price             398      23879.0
# 5          Less            Medium Price             365     191228.0
#
#    auto_orders  taxi_orders  swiggy_orders  swiggy_orders_per_hex  hex_distr  \
# 0       5921.0      11965.0         5319.0                  49.71       5.11
# 1     470962.0     861774.0       143729.0                 635.97      10.79
# 2    1695998.0    3261398.0       665281.0                 969.80      32.74
# 3      12599.0      26823.0         4854.0                  15.51      14.94
# 4      22545.0      46424.0         5324.0                  13.38      19.00
# 5     177905.0     369133.0        49813.0                 136.47      17.42
#
#    swiggy_orders_distr
# 0                 0.61
# 1                16.44
# 2                76.09
# 3                 0.56
# 4                 0.61
# 5                 5.70

# %%
#  Median order price at hex level (0| 1-50| 50+)
ha = round(107*100/420,2)
la = round(398*100/624,2)
print('High Swiggy with High Affluence signal overlap percentage',ha)
print('Less Swiggy with Less Affluence signal overlap percentage',la)
# Out:
# High Swiggy with High Affluence signal overlap percentage 25.48
# Less Swiggy with Less Affluence signal overlap percentage 63.78

# %% [markdown]
# ## PPKM

# %%
start_date = '20230714' ## '20230703' 20230710 20230717
end_date = '20230716' ## 20230716 20230730

# %%
ppkm_data = f"""
        WITH city_cluster_hex AS (

                SELECT
                    cch.hex_id AS hex_id,
                    cch.cluster AS cluster
                FROM
                    datasets.city_cluster_hex cch
                WHERE
                    cch.resolution = 8
            ),

            fare_estimates AS (

                SELECT
                    fe_ench.epoch AS epoch,
                    fe_ench.yyyymmdd AS yyyymmdd,
                    fe_ench.city AS city_name,
                    fe_ench.service_name AS service_name,
                    fe_ench.service_detail_id AS service_detail_id,
                    fe_ench.pickup_location_hex_8 AS pickup_location_hex_8,
                    fe_ench.drop_location_hex_8 AS drop_location_hex_8,
                    fe_ench.fare_estimate_id AS fare_estimate_id,
                    fe_ench.sub_total AS sub_total,
                    fe_ench.final_amount AS final_amount,
                    CASE 
                    WHEN fe_ench.ride_distance BETWEEN 0.00001 AND 0.99 THEN 1.0 
                    ELSE ride_distance END AS ride_distance,
                    fe_ench.quarter_hour

                FROM
                    pricing.fare_estimates_enriched fe_ench
                WHERE
                    yyyymmdd >= '{start_date}'
                    AND yyyymmdd <= '{end_date}'
                    AND fe_ench.service_name IN ('Link') 
                    AND fe_ench.city = 'Bangalore'
                    AND fe_ench.ride_distance > 0
                    AND quarter_hour >= '0700' 
                    AND quarter_hour <= '2300'
            ),

            orders AS (

                SELECT
                    ols.yyyymmdd AS yyyymmdd,
                    ols.service_detail_id AS service_detail_id,
                    ols.service_obj_service_name AS service_name,
                    ols.estimate_id AS fare_estimate_id,
                    ols.order_status AS order_status,
                    ols.order_id AS order_id,
                    ols.accept_to_pickup_distance  AS accept_to_pickup_distance,
                    ols.spd_fraud_flag
                FROM
                    orders.order_logs_snapshot AS ols
                WHERE
                    yyyymmdd >= '{start_date}'
                    AND yyyymmdd <= '{end_date}'
                    AND ols.service_obj_service_name IN ('Link')
                    AND ols.city_name = 'Bangalore'
            )

            SELECT 
                fe.yyyymmdd AS yyyymmdd,
                fe.city_name AS city_name,
                fe.service_name AS service_name,
                fe.service_detail_id AS service_detail_id,

                CASE 
                WHEN pic.hex_id IN ('88618921d3fffff', '88618921c7fffff', '8861892665fffff', '8860145a33fffff', '8861892c97fffff', '886189219bfffff', '88618920b3fffff', '8861892e37fffff', '8861892ed9fffff',
                                    '8861892c1dfffff', '8861892c11fffff', '8861892ea5fffff', '8861892c55fffff', '8861892639fffff', '886189246dfffff', '8861892cbdfffff', '8861892ee5fffff', '88618925c9fffff',
                                    '88618925bbfffff', '8860145a61fffff', '8861892431fffff', '88618926adfffff', '8860145b43fffff', '8861892ed3fffff', '88618925a5fffff')
                THEN 'High Affluence'
                WHEN pic.hex_id IN ('886014594bfffff', '8860145863fffff', '8861892ca3fffff', '8860145829fffff', '8860145a05fffff', '8860169669fffff', '8860145943fffff', '8861892dd5fffff', '886014584dfffff',
                                    '886189244dfffff', '88618925a9fffff', '8860145913fffff', '8861892c0bfffff', '8861892cc1fffff', '8860145ad1fffff', '88618925e3fffff', '886016966bfffff', '88618920e9fffff',
                                    '8861892645fffff', '8861892521fffff', '8861892ccbfffff', '8861892e63fffff', '8861892f13fffff', '8860145ad9fffff', '88618921e3fffff', '8860145b51fffff', '8861892e2bfffff', 
                                    '8861892c8bfffff', '8860145b67fffff', '8861892e2dfffff', '8861892db5fffff', '8860145a21fffff', '8861892db7fffff', '8860145a29fffff', '8861892c95fffff', '8861892eb1fffff', 
                                    '8861892eb7fffff', '8861892eb5fffff', '8860145b53fffff', '8861892e93fffff', '8860145b55fffff', '886014595dfffff', '8861892e85fffff', '8860145b59fffff', '8860169663fffff')
                THEN 'Low Affluence'
                ELSE 'OTHER' END affluence,

                pic.hex_id AS pickup_hex_8,
                pic.cluster AS pickup_location,
                fe.fare_estimate_id AS fare_estimate_id,
                fe.quarter_hour AS quarter_hour,
                ord.order_id AS order_id,
                CASE 
                WHEN order_status = 'dropped' AND (spd_fraud_flag != true OR spd_fraud_flag IS NULL)
                THEN order_id END dropped_order_id,
                ord.order_status AS order_status,
                -- fe.sub_total AS sub_total,
                -- fe.final_amount AS final_amount,
                fe.ride_distance AS ride_distance,
                COALESCE(TRY(fe.sub_total/fe.ride_distance),0) ppkm
            FROM
                fare_estimates AS fe

            LEFT JOIN
                city_cluster_hex AS pic
                ON fe.pickup_location_hex_8 = pic.hex_id

            LEFT JOIN
                orders AS ord
                ON fe.yyyymmdd = ord.yyyymmdd
                AND fe.service_detail_id = ord.service_detail_id
                AND fe.service_name = ord.service_name
                AND fe.fare_estimate_id = ord.fare_estimate_id
                
"""


df_fe_ppkm_data = pd.read_sql(ppkm_data, connection)
df_fe_ppkm_data.head(2)
# Out:
#    yyyymmdd  city_name service_name         service_detail_id affluence  \
# 0  20230716  Bangalore         Link  57370b61a6855d70057417d1     OTHER
# 1  20230714  Bangalore         Link  57370b61a6855d70057417d1     OTHER
#
#       pickup_hex_8 pickup_location          fare_estimate_id quarter_hour  \
# 0  8861892e03fffff     Mahadevpura  64b3911adea6433e70bbf935         1200
# 1  8860145129fffff       Gattigere  64b1297f7f295fec236eb249         1615
#
#                    order_id          dropped_order_id order_status  \
# 0  64b38caa9b33b462d62b03ab  64b38caa9b33b462d62b03ab      dropped
# 1                      None                      None         None
#
#    ride_distance       ppkm
# 0          1.146  46.247818
# 1          4.244  15.080113

# %%
df11 = df_fe_ppkm_data
df11.to_csv('df11.csv', index = False)

# %%
df12 = df_fe_ppkm_data
df12.to_csv('df12.csv', index = False)

# %%
df13 = df_fe_ppkm_data
df13.to_csv('df13.csv', index = False)

# %%
df2 = df_fe_ppkm_data
df2.to_csv('df2.csv', index = False)

# %%
df11 = pd.read_csv('df11.csv')
df12 = pd.read_csv('df12.csv')
df13 = pd.read_csv('df13.csv')
df2 = pd.read_csv('df2.csv')

# %%
frames = [df11,df12,df13,df2]
df_fe_ppkm_data = pd.concat(frames)

# %%
# df_aff_hex = pd.read_clipboard()
# df_aff_hex.head(2)

# %%
df_fe_ppkm_data.quarter_hour.unique()
# Out:
# array([1245,  930, 1430, 2115, 1100, 2045, 1800, 2015,  945, 2100, 1600,
#        1915, 1145, 2000, 1945, 1015, 1815, 1030,  715,  745, 1700, 1330,
#        1300, 1845, 1715, 1445, 1900, 1515, 2300, 1830, 1115, 1645, 1000,
#        1745,  830, 1230, 1730,  815, 2030, 1045, 1400,  915,  800,  900,
#        2145, 1630, 1215, 1130, 1530, 2230, 1930, 2130, 1615,  730,  845,
#        2215, 1315, 1500, 1345, 1415, 2200, 2245, 1545, 1200,  700])

# %%
df_fe_ppkm_data['ppkm'] = pd.to_numeric(df_fe_ppkm_data['ppkm'])

# %%
df_fe_ppkm_data['ppkm'] = df_fe_ppkm_data['ppkm'].round()
df_fe_ppkm_data
# Out:
#           yyyymmdd  city_name service_name         service_detail_id  \
# 0         20230704  Bangalore         Link  57370b61a6855d70057417d1
# 1         20230704  Bangalore         Link  57370b61a6855d70057417d1
# 2         20230704  Bangalore         Link  57370b61a6855d70057417d1
# 3         20230704  Bangalore         Link  57370b61a6855d70057417d1
# 4         20230704  Bangalore         Link  57370b61a6855d70057417d1
# ...            ...        ...          ...                       ...
# 12280252  20230725  Bangalore         Link  57370b61a6855d70057417d1
# 12280253  20230725  Bangalore         Link  57370b61a6855d70057417d1
# 12280254  20230725  Bangalore         Link  57370b61a6855d70057417d1
# 12280255  20230725  Bangalore         Link  57370b61a6855d70057417d1
# 12280256  20230725  Bangalore         Link  57370b61a6855d70057417d1
#
#                affluence     pickup_hex_8         pickup_location  \
# 0          Low Affluence  8860145b55fffff                Majestic
# 1         High Affluence  88618920b3fffff    Marathahalli Village
# 2                  OTHER  8861892463fffff               Hosapalya
# 3                  OTHER  8860145165fffff          Subramanyapura
# 4         High Affluence  88618920b3fffff    Marathahalli Village
# ...                  ...              ...                     ...
# 12280252           OTHER  886189246bfffff              Kudlu Gate
# 12280253           OTHER  8861892e0dfffff  Mahadevpura RHB Colony
# 12280254           OTHER  8861892cbbfffff          Sahakara Nagar
# 12280255           OTHER  88601459e9fffff             Dasarahalli
# 12280256           OTHER  88601696e9fffff             Veerasandra
#
#                   fare_estimate_id  quarter_hour                  order_id  \
# 0         64a3c8a741cb0ca61bf01ac8          1245                       NaN
# 1         64a39bdc5bc4613b65ab5fae           930  64a39be1a83c242c0c879188
# 2         64a3e2d0aa513d85217f35d4          1430  64a3e2e916dced4587913a58
# 3         64a43eace85f6baddee53470          2115                       NaN
# 4         64a3b05b25729d0bd99ee6d0          1100                       NaN
# ...                            ...           ...                       ...
# 12280252  64bf4b60ddae85643666b3d4           930  64bf4b66139b7a5a366f86ce
# 12280253  64bfd6023a0d489950f9f242          1930  64bfd60e990dce1a751b9b58
# 12280254  64bf4f06377996b01db1098e           945  64bf4f09274fd00139c72093
# 12280255  64bfdd029ad3b7db68a0adb6          2000                       NaN
# 12280256  64bfcdfcca0edf4ffb861d23          1845  64bfce0829f86605994ce772
#
#                   dropped_order_id       order_status  ride_distance  ppkm
# 0                              NaN                NaN          3.627  20.0
# 1                              NaN  customerCancelled          4.610  18.0
# 2                              NaN  customerCancelled          2.598  16.0
# 3                              NaN                NaN          1.000  41.0
# 4                              NaN                NaN          6.756  14.0
# ...                            ...                ...            ...   ...
# 12280252                       NaN  customerCancelled          3.303  15.0
# 12280253  64bfd60e990dce1a751b9b58            dropped          4.749  14.0
# 12280254                       NaN  customerCancelled          5.981  16.0
# 12280255                       NaN                NaN          2.465  21.0
# 12280256                       NaN  customerCancelled          6.562  11.0
#
# [25601887 rows x 14 columns]

# %%
df_fe_ppkm_data.ppkm.describe([0.20,0.3,0.6,0.65,0.75,0.8,0.85,0.9,0.95])
# Out:
# count    2.560189e+07
# mean     1.761898e+01
# std      7.901521e+00
# min      2.000000e+00
# 20%      1.300000e+01
# 30%      1.400000e+01
# 50%      1.500000e+01
# 60%      1.600000e+01
# 65%      1.700000e+01
# 75%      1.800000e+01
# 80%      2.000000e+01
# 85%      2.200000e+01
# 90%      2.600000e+01
# 95%      3.500000e+01
# max      2.470000e+02
# Name: ppkm, dtype: float64

# %%
## city test

df_hex_level_ppkm = df_fe_ppkm_data[df_fe_ppkm_data['ride_distance'] > 1] \
                    .groupby(['ppkm']) \
                    .agg(
                         fe_count = pd.NamedAgg('fare_estimate_id', 'nunique'),
                         gross_count = pd.NamedAgg('order_id', 'nunique'),
                         net_count = pd.NamedAgg('dropped_order_id', 'nunique')
                        ).reset_index()
df_hex_level_ppkm['fe-rr'] = df_hex_level_ppkm['gross_count']*100.0/df_hex_level_ppkm['fe_count']
df_hex_level_ppkm['g2n'] = df_hex_level_ppkm['net_count']*100.0/df_hex_level_ppkm['gross_count']
df_hex_level_ppkm['fe-net'] = df_hex_level_ppkm['net_count']*100.0/df_hex_level_ppkm['fe_count']

df_hex_level_ppkm = df_hex_level_ppkm.fillna(0)
df_hex_level_ppkm
# Out:
#    ppkm  fe_count  gross_count  net_count     fe-rr  g2n  fe-net
# 0   2.0         2            0          0  0.000000  0.0     0.0
# 1   3.0        37            2          0  5.405405  0.0     0.0

# %%
df_hex_level_ppkm[df_hex_level_ppkm['fe_count'] >= df_hex_level_ppkm.fe_count.quantile(.9)]
# Out:
#     ppkm  fe_count  gross_count  net_count      fe-rr        g2n    fe-net
# 9   11.0    698214        95461      40168  13.672169  42.077917  5.752964
# 10  12.0   4049269       605684     288639  14.957860  47.655048  7.128175
# 11  13.0   2780029       427856     202038  15.390343  47.221028  7.267478
# 12  14.0   2896412       483472     253739  16.692100  52.482667  8.760459
# 13  15.0   2960852       501338     262589  16.932221  52.377637  8.868697
# 14  16.0   2262026       369052     191369  16.315109  51.854210  8.460071
# 15  17.0   2011379       301468     155660  14.988125  51.634004  7.738969
# 16  18.0   1446265       227193     120704  15.708947  53.128397  8.345912
# 17  19.0    971421       157741      84760  16.238171  53.733652  8.725362
# 18  20.0    726194       116493      62632  16.041581  53.764604  8.624693
# 19  21.0    593822        93823      51250  15.799852  54.624133  8.630532
# 20  22.0    481778        75960      42620  15.766598  56.108478  8.846398
# 21  23.0    395049        61944      35479  15.680080  57.275927  8.980911

# %%
df_hex_level_ppkm = df_fe_ppkm_data[df_fe_ppkm_data['ride_distance'] > 1] \
                    .groupby(['pickup_location', 'pickup_hex_8','ppkm']) \
                    .agg(
                         fe_count = pd.NamedAgg('fare_estimate_id', 'nunique'),
                         gross_count = pd.NamedAgg('order_id', 'nunique'),
                         net_count = pd.NamedAgg('dropped_order_id', 'nunique')
                        ).reset_index()
df_hex_level_ppkm['fe-rr'] = df_hex_level_ppkm['gross_count']*100.0/df_hex_level_ppkm['fe_count']
df_hex_level_ppkm['g2n'] = df_hex_level_ppkm['net_count']*100.0/df_hex_level_ppkm['gross_count']
df_hex_level_ppkm['fe-net'] = df_hex_level_ppkm['net_count']*100.0/df_hex_level_ppkm['fe_count']

df_hex_level_ppkm = df_hex_level_ppkm.fillna(0)
df_hex_level_ppkm.head(2)
# Out:
#            pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  \
# 0  AECS Layout Brookefield  88618920a3fffff   7.0         1            0
# 1  AECS Layout Brookefield  88618920a3fffff   8.0        15            2
#
#    net_count      fe-rr  g2n  fe-net
# 0          0   0.000000  0.0     0.0
# 1          0  13.333333  0.0     0.0

# %%
df_hex_level_ppkm.fe_count.describe()
# Out:
# count    67753.000000
# mean       367.897053
# std       1461.311703
# min          1.000000
# 25%          4.000000
# 50%         20.000000
# 75%        120.000000
# max      40177.000000
# Name: fe_count, dtype: float64

# %%
df_hex_level_ppkm_fe_filter = df_hex_level_ppkm[df_hex_level_ppkm['fe_count'] > df_hex_level_ppkm.fe_count.quantile(0.5)]
# df_hex_level_ppkm_fe_filter = df_hex_level_ppkm

# %%
df_hex_level_ppkm_fe_filter = df_hex_level_ppkm_fe_filter.round(2)
df_hex_level_ppkm_fe_filter
# Out:
#                 pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  \
# 2       AECS Layout Brookefield  88618920a3fffff   9.0        86            5
# 3       AECS Layout Brookefield  88618920a3fffff  10.0       314           43
# 4       AECS Layout Brookefield  88618920a3fffff  11.0      2488          411
# 5       AECS Layout Brookefield  88618920a3fffff  12.0     22586         3682
# 6       AECS Layout Brookefield  88618920a3fffff  13.0     15240         2214
# ...                         ...              ...   ...       ...          ...
# 67737  Yeshwanthpur - Mathikere  886014594bfffff  45.0        35            3
# 67738  Yeshwanthpur - Mathikere  886014594bfffff  46.0        61           14
# 67739  Yeshwanthpur - Mathikere  886014594bfffff  47.0        27            4
# 67740  Yeshwanthpur - Mathikere  886014594bfffff  48.0        29            1
# 67743  Yeshwanthpur - Mathikere  886014594bfffff  51.0        25            5
#
#        net_count  fe-rr     g2n  fe-net
# 2              1   5.81   20.00    1.16
# 3              7  13.69   16.28    2.23
# 4            197  16.52   47.93    7.92
# 5           1971  16.30   53.53    8.73
# 6           1106  14.53   49.95    7.26
# ...          ...    ...     ...     ...
# 67737          3   8.57  100.00    8.57
# 67738          4  22.95   28.57    6.56
# 67739          3  14.81   75.00   11.11
# 67740          1   3.45  100.00    3.45
# 67743          2  20.00   40.00    8.00
#
# [33424 rows x 9 columns]

# %%
df_hex_level_fe_threshold = df_hex_level_ppkm_fe_filter \
                                    .groupby(['pickup_location', 'pickup_hex_8']) \
                                    .agg(fe_threshold=pd.NamedAgg('fe_count', lambda x: x.quantile(0.90)))\
                                    .reset_index()
df_hex_level_fe_threshold
# Out:
#                pickup_location     pickup_hex_8  fe_threshold
# 0      AECS Layout Brookefield  88618920a3fffff       13460.5
# 1                      Adugodi  8861892581fffff        6026.5
# 2                      Adugodi  886189258bfffff        5978.0
# 3      Adugodi Traffic Station  886189258dfffff        6754.8
# 4                   Agara Lake  8861892425fffff        5227.4
# ...                        ...              ...           ...
# 2043              Yeshwanthpur  8860145955fffff        1264.5
# 2044              Yeshwanthpur  8860145957fffff        3303.0
# 2045              Yeshwanthpur  8860145959fffff        1084.4
# 2046              Yeshwanthpur  886014595bfffff        1003.6
# 2047  Yeshwanthpur - Mathikere  886014594bfffff        2897.0
#
# [2048 rows x 3 columns]

# %%
df_hex_level_threshold_merge = pd.merge(df_hex_level_ppkm_fe_filter,
                                        df_hex_level_fe_threshold,
                                        how = 'inner',
                                        left_on = ['pickup_location', 'pickup_hex_8'],
                                        right_on = ['pickup_location', 'pickup_hex_8']
                                       )
df_hex_level_threshold_merge = df_hex_level_threshold_merge[df_hex_level_threshold_merge['fe_count'] >= df_hex_level_threshold_merge['fe_threshold']]
df_hex_level_threshold_merge
# Out:
#                 pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  \
# 3       AECS Layout Brookefield  88618920a3fffff  12.0     22586         3682
# 4       AECS Layout Brookefield  88618920a3fffff  13.0     15240         2214
# 5       AECS Layout Brookefield  88618920a3fffff  14.0     16055         2863
# 6       AECS Layout Brookefield  88618920a3fffff  15.0     20049         3784
# 7       AECS Layout Brookefield  88618920a3fffff  16.0     14392         2654
# ...                         ...              ...   ...       ...          ...
# 33386  Yeshwanthpur - Mathikere  886014594bfffff  12.0      7174         1131
# 33387  Yeshwanthpur - Mathikere  886014594bfffff  13.0      4632          724
# 33388  Yeshwanthpur - Mathikere  886014594bfffff  14.0      5555         1003
# 33389  Yeshwanthpur - Mathikere  886014594bfffff  15.0      5608         1143
# 33390  Yeshwanthpur - Mathikere  886014594bfffff  16.0      2897          564
#
#        net_count  fe-rr    g2n  fe-net  fe_threshold
# 3           1971  16.30  53.53    8.73       13460.5
# 4           1106  14.53  49.95    7.26       13460.5
# 5           1536  17.83  53.65    9.57       13460.5
# 6           2057  18.87  54.36   10.26       13460.5
# 7           1330  18.44  50.11    9.24       13460.5
# ...          ...    ...    ...     ...           ...
# 33386        660  15.77  58.36    9.20        2897.0
# 33387        431  15.63  59.53    9.30        2897.0
# 33388        647  18.06  64.51   11.65        2897.0
# 33389        666  20.38  58.27   11.88        2897.0
# 33390        370  19.47  65.60   12.77        2897.0
#
# [4488 rows x 10 columns]

# %%
df_hex_level_max_fe_net_rate = df_hex_level_threshold_merge \
                                    .groupby(['pickup_location', 'pickup_hex_8']) \
                                    .agg( max_fe_rr = pd.NamedAgg('fe-rr' , 'max'), 
                                         max_fe_net = pd.NamedAgg('fe-net' , 'max'))\
                                    .reset_index()
df_hex_level_max_fe_net_rate
# Out:
#                pickup_location     pickup_hex_8  max_fe_rr  max_fe_net
# 0      AECS Layout Brookefield  88618920a3fffff      18.87       10.26
# 1                      Adugodi  8861892581fffff      15.70        7.32
# 2                      Adugodi  886189258bfffff      17.80        7.99
# 3      Adugodi Traffic Station  886189258dfffff      15.93        7.57
# 4                   Agara Lake  8861892425fffff      18.20       10.25
# ...                        ...              ...        ...         ...
# 2043              Yeshwanthpur  8860145955fffff      12.50        7.19
# 2044              Yeshwanthpur  8860145957fffff      19.61       10.38
# 2045              Yeshwanthpur  8860145959fffff      17.84       11.26
# 2046              Yeshwanthpur  886014595bfffff      15.11        9.70
# 2047  Yeshwanthpur - Mathikere  886014594bfffff      20.38       12.77
#
# [2048 rows x 4 columns]

# %%
df_hex_level_threshold_merge1 = pd.merge(df_hex_level_threshold_merge,
                                        df_hex_level_max_fe_net_rate,
                                        how = 'inner',
                                        left_on = ['pickup_location', 'pickup_hex_8'],
                                        right_on = ['pickup_location', 'pickup_hex_8']
                                       )
df_hex_level_threshold_merge1
# Out:
#                pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  \
# 0      AECS Layout Brookefield  88618920a3fffff  12.0     22586         3682
# 1      AECS Layout Brookefield  88618920a3fffff  13.0     15240         2214
# 2      AECS Layout Brookefield  88618920a3fffff  14.0     16055         2863
# 3      AECS Layout Brookefield  88618920a3fffff  15.0     20049         3784
# 4      AECS Layout Brookefield  88618920a3fffff  16.0     14392         2654
# ...                        ...              ...   ...       ...          ...
# 4483  Yeshwanthpur - Mathikere  886014594bfffff  12.0      7174         1131
# 4484  Yeshwanthpur - Mathikere  886014594bfffff  13.0      4632          724
# 4485  Yeshwanthpur - Mathikere  886014594bfffff  14.0      5555         1003
# 4486  Yeshwanthpur - Mathikere  886014594bfffff  15.0      5608         1143
# 4487  Yeshwanthpur - Mathikere  886014594bfffff  16.0      2897          564
#
#       net_count  fe-rr    g2n  fe-net  fe_threshold  max_fe_rr  max_fe_net
# 0          1971  16.30  53.53    8.73       13460.5      18.87       10.26
# 1          1106  14.53  49.95    7.26       13460.5      18.87       10.26
# 2          1536  17.83  53.65    9.57       13460.5      18.87       10.26
# 3          2057  18.87  54.36   10.26       13460.5      18.87       10.26
# 4          1330  18.44  50.11    9.24       13460.5      18.87       10.26
# ...         ...    ...    ...     ...           ...        ...         ...
# 4483        660  15.77  58.36    9.20        2897.0      20.38       12.77
# 4484        431  15.63  59.53    9.30        2897.0      20.38       12.77
# 4485        647  18.06  64.51   11.65        2897.0      20.38       12.77
# 4486        666  20.38  58.27   11.88        2897.0      20.38       12.77
# 4487        370  19.47  65.60   12.77        2897.0      20.38       12.77
#
# [4488 rows x 12 columns]

# %%
df_hex_level_threshold = df_hex_level_threshold_merge1[
                                                       (df_hex_level_threshold_merge1['fe-rr'] == df_hex_level_threshold_merge1['max_fe_rr'])

#                                                         (df_hex_level_threshold_merge['fe-net'] == df_hex_level_threshold_merge['max_fe_rr'])
                                                    ]
df_hex_level_threshold
# Out:
#                pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  \
# 3      AECS Layout Brookefield  88618920a3fffff  15.0     20049         3784
# 8                      Adugodi  8861892581fffff  15.0      6760         1061
# 12                     Adugodi  886189258bfffff  15.0      7433         1323
# 16     Adugodi Traffic Station  886189258dfffff  15.0      7432         1184
# 21                  Agara Lake  8861892425fffff  16.0      5461          994
# ...                        ...              ...   ...       ...          ...
# 4471              Yeshwanthpur  8860145955fffff  14.0      1336          167
# 4475              Yeshwanthpur  8860145957fffff  15.0      3574          701
# 4479              Yeshwanthpur  8860145959fffff  15.0      1368          244
# 4482              Yeshwanthpur  886014595bfffff  14.0      1072          162
# 4486  Yeshwanthpur - Mathikere  886014594bfffff  15.0      5608         1143
#
#       net_count  fe-rr    g2n  fe-net  fe_threshold  max_fe_rr  max_fe_net
# 3          2057  18.87  54.36   10.26       13460.5      18.87       10.26
# 8           495  15.70  46.65    7.32        6026.5      15.70        7.32
# 12          594  17.80  44.90    7.99        5978.0      17.80        7.99
# 16          555  15.93  46.88    7.47        6754.8      15.93        7.57
# 21          560  18.20  56.34   10.25        5227.4      18.20       10.25
# ...         ...    ...    ...     ...           ...        ...         ...
# 4471         96  12.50  57.49    7.19        1264.5      12.50        7.19
# 4475        365  19.61  52.07   10.21        3303.0      19.61       10.38
# 4479        154  17.84  63.11   11.26        1084.4      17.84       11.26
# 4482        104  15.11  64.20    9.70        1003.6      15.11        9.70
# 4486        666  20.38  58.27   11.88        2897.0      20.38       12.77
#
# [2056 rows x 12 columns]

# %%
df_hex_level_threshold['ppkm_flag'] = np.where(df_hex_level_threshold['ppkm'] > 15, 'High ppkm', 'Less ppkm')
df_hex_level_threshold  = pd.merge(df_hex_level_threshold,
                                   df_hex_affluence_tag,
                                   how = 'left',
                                   left_on = ['pickup_hex_8'],
                                   right_on = ['pickup_hex_8']
                                  )
df_hex_level_threshold
# Out:
#                pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  \
# 0      AECS Layout Brookefield  88618920a3fffff  15.0     20049         3784
# 1                      Adugodi  8861892581fffff  15.0      6760         1061
# 2                      Adugodi  886189258bfffff  15.0      7433         1323
# 3      Adugodi Traffic Station  886189258dfffff  15.0      7432         1184
# 4                   Agara Lake  8861892425fffff  16.0      5461          994
# ...                        ...              ...   ...       ...          ...
# 2051              Yeshwanthpur  8860145955fffff  14.0      1336          167
# 2052              Yeshwanthpur  8860145957fffff  15.0      3574          701
# 2053              Yeshwanthpur  8860145959fffff  15.0      1368          244
# 2054              Yeshwanthpur  886014595bfffff  14.0      1072          162
# 2055  Yeshwanthpur - Mathikere  886014594bfffff  15.0      5608         1143
#
#       net_count  fe-rr    g2n  fe-net  fe_threshold  max_fe_rr  max_fe_net  \
# 0          2057  18.87  54.36   10.26       13460.5      18.87       10.26
# 1           495  15.70  46.65    7.32        6026.5      15.70        7.32
# 2           594  17.80  44.90    7.99        5978.0      17.80        7.99
# 3           555  15.93  46.88    7.47        6754.8      15.93        7.57
# 4           560  18.20  56.34   10.25        5227.4      18.20       10.25
# ...         ...    ...    ...     ...           ...        ...         ...
# 2051         96  12.50  57.49    7.19        1264.5      12.50        7.19
# 2052        365  19.61  52.07   10.21        3303.0      19.61       10.38
# 2053        154  17.84  63.11   11.26        1084.4      17.84       11.26
# 2054        104  15.11  64.20    9.70        1003.6      15.11        9.70
# 2055        666  20.38  58.27   11.88        2897.0      20.38       12.77
#
#       ppkm_flag affluence_tag
# 0     Less ppkm          High
# 1     Less ppkm          High
# 2     Less ppkm          High
# 3     Less ppkm          High
# 4     High ppkm          High
# ...         ...           ...
# 2051  Less ppkm          High
# 2052  Less ppkm          High
# 2053  Less ppkm          High
# 2054  Less ppkm          High
# 2055  Less ppkm          Less
#
# [2056 rows x 14 columns]

# %%
df_hex_level_threshold
# Out:
#                pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  \
# 0      AECS Layout Brookefield  88618920a3fffff  15.0     20049         3784
# 1                      Adugodi  8861892581fffff  15.0      6760         1061
# 2                      Adugodi  886189258bfffff  15.0      7433         1323
# 3      Adugodi Traffic Station  886189258dfffff  15.0      7432         1184
# 4                   Agara Lake  8861892425fffff  16.0      5461          994
# ...                        ...              ...   ...       ...          ...
# 2051              Yeshwanthpur  8860145955fffff  14.0      1336          167
# 2052              Yeshwanthpur  8860145957fffff  15.0      3574          701
# 2053              Yeshwanthpur  8860145959fffff  15.0      1368          244
# 2054              Yeshwanthpur  886014595bfffff  14.0      1072          162
# 2055  Yeshwanthpur - Mathikere  886014594bfffff  15.0      5608         1143
#
#       net_count  fe-rr    g2n  fe-net  fe_threshold  max_fe_rr  max_fe_net  \
# 0          2057  18.87  54.36   10.26       13460.5      18.87       10.26
# 1           495  15.70  46.65    7.32        6026.5      15.70        7.32
# 2           594  17.80  44.90    7.99        5978.0      17.80        7.99
# 3           555  15.93  46.88    7.47        6754.8      15.93        7.57
# 4           560  18.20  56.34   10.25        5227.4      18.20       10.25
# ...         ...    ...    ...     ...           ...        ...         ...
# 2051         96  12.50  57.49    7.19        1264.5      12.50        7.19
# 2052        365  19.61  52.07   10.21        3303.0      19.61       10.38
# 2053        154  17.84  63.11   11.26        1084.4      17.84       11.26
# 2054        104  15.11  64.20    9.70        1003.6      15.11        9.70
# 2055        666  20.38  58.27   11.88        2897.0      20.38       12.77
#
#       ppkm_flag affluence_tag
# 0     Less ppkm          High
# 1     Less ppkm          High
# 2     Less ppkm          High
# 3     Less ppkm          High
# 4     High ppkm          High
# ...         ...           ...
# 2051  Less ppkm          High
# 2052  Less ppkm          High
# 2053  Less ppkm          High
# 2054  Less ppkm          High
# 2055  Less ppkm          Less
#
# [2056 rows x 14 columns]

# %%
df_hex_level_threshold[df_hex_level_threshold['pickup_hex_8'].isin(['8861892cd7fffff', '8861892c8bfffff'])]
# Out:
#     pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  net_count  \
# 842          Hebbal  8861892c8bfffff  15.0      3282          571        298
# 845          Hebbal  8861892cd7fffff  14.0      3825          598        363
#
#      fe-rr    g2n  fe-net  fe_threshold  max_fe_rr  max_fe_net  ppkm_flag  \
# 842  17.40  52.19    9.08        2968.8      17.40        9.08  Less ppkm
# 845  15.63  60.70    9.49        2575.1      15.63        9.49  Less ppkm
#
#     affluence_tag
# 842          Less
# 845          Less

# %%
df_hex_level_threshold[df_hex_level_threshold['pickup_hex_8'] == '8861892cd7fffff']
# Out:
#     pickup_location     pickup_hex_8  ppkm  fe_count  gross_count  net_count  \
# 845          Hebbal  8861892cd7fffff  14.0      3825          598        363
#
#      fe-rr   g2n  fe-net  fe_threshold  max_fe_rr  max_fe_net  ppkm_flag  \
# 845  15.63  60.7    9.49        2575.1      15.63        9.49  Less ppkm
#
#     affluence_tag
# 845          Less

# %%
df_hex_level_threshold_dis = df_hex_level_threshold \
                        .groupby(['affluence_tag', 'ppkm_flag']) \
                        .agg({'pickup_hex_8' : 'nunique'}) \
                        .reset_index()
# df_hex_level_threshold_dis['hex_dist'] = df_hex_level_threshold_dis['pickup_hex_8']*100.0/df_hex_level_threshold_dis.pickup_hex_8.sum()

df_hex_level_threshold_dis.round(2)
# Out:
#   affluence_tag  ppkm_flag  pickup_hex_8
# 0          High  High ppkm            68
# 1          High  Less ppkm           895
# 2          Less  High ppkm            17
# 3          Less  Less ppkm          1061

# %%
test_ppkm = df_hex_level_threshold \
                        .groupby(['affluence_tag', 'pickup_hex_8', 'ppkm_flag']) \
                        .agg({'fe_count' : 'sum'}) \
                        .reset_index()

# %%
test_ppkm.to_clipboard(index=False)

# %%
# less aff overlap
764/(338+764)
# Out:
# 0.6932849364791288

# %%
# high aff overlap
630/(331+630)
# Out:
# 0.6555671175858481

# %%
df_hex_level_threshold[(df_hex_level_threshold['affluence_tag'] == 'Less' )
                        &
                        (df_hex_level_threshold['ppkm_flag'] == 'Less ppkm')
                        ]
# Out:
#                   pickup_location     pickup_hex_8  ppkm  fe_count  \
# 60                       Attibele  8861893401fffff  11.0        90
# 61                       Attibele  8861893403fffff  13.0        37
# 62                       Attibele  8861893405fffff  10.0        20
# 63                       Attibele  8861893407fffff  14.0        65
# 65                       Attibele  886189340bfffff  10.0        23
# 66                       Attibele  886189340dfffff  11.0        93
# 67                       Attibele  8861893411fffff  14.0        35
# 70                       Attibele  8861893415fffff  12.0        39
# 71                       Attibele  8861893417fffff  10.0        39
# 72                       Attibele  8861893423fffff  12.0        25
# 73                       Attibele  8861893431fffff  12.0        51
# 74                       Attibele  8861893433fffff  13.0        20
# 75                       Attibele  8861893435fffff  12.0        22
# 76                       Attibele  8861893437fffff  12.0        23
# 77                       Attibele  8861893439fffff  13.0        52
# 78                       Attibele  886189343bfffff  14.0        44
# 79                       Attibele  8861893441fffff  12.0        27
# 80                       Attibele  8861893445fffff  13.0       128
# 81                       Attibele  8861893447fffff  12.0        31
# 82                       Attibele  8861893463fffff  11.0        37
# 84                       Attibele  8861893469fffff  10.0       120
# 85                       Attibele  886189346bfffff  11.0        45
# 87                       Attibele  8861893485fffff  14.0        24
# 88                       Attibele  8861893489fffff  10.0        27
# 89                       Attibele  886189348dfffff  11.0        22
# 92                       Attibele  88618934c1fffff  13.0        33
# 93                       Attibele  88618934c3fffff  11.0        23
# 95                       Attibele  88618934c7fffff  14.0        78
# 96                       Attibele  88618934cbfffff  11.0        81
# 100                      Attibele  88618934e5fffff  13.0       152
# 102                      Attibele  88618934e9fffff  14.0        81
# 104                      Attibele  88618934edfffff  12.0        25
# 105                      Attibele  88618935cbfffff  11.0        33
# 106                      Attibele  88618935d1fffff  12.0       159
# 108                      Attibele  88618935d5fffff  10.0        35
# 110                      Attibele  88618935d9fffff   8.0        78
# 112                      Attibele  88618935ddfffff  12.0        27
# 113                      Attibele  8861893713fffff  11.0       133
# 116                    BEL Layout  88601458c1fffff  13.0        97
# 123                   BGS Kengeri  8860145a83fffff  12.0       822
# 126                   BGS Kengeri  8860145a8bfffff  14.0       145
# 127                   BGS Kengeri  8860145a9dfffff  14.0        57
# 128                   BGS Kengeri  8860145ab9fffff  12.0       241
# 141                   BLR_Hoskote  8861892a83fffff  14.0        23
# 146                   BLR_Hoskote  8861892a9dfffff  13.0        21
# 147                   BLR_Hoskote  8861892ab9fffff  13.0       130
# 161                       Bagalur  8860169299fffff  11.0        25
# 164                       Bagalur  88601692c3fffff  11.0        61
# 166                       Bagalur  88601692cdfffff  12.0        26
# 167                       Bagalur  88601692d1fffff  13.0        24
# 169                       Bagalur  88601692d5fffff  13.0       179
# 170                       Bagalur  88601692d7fffff  12.0        71
# 638                  Bannerghatta  886189268dfffff  14.0       137
# 639                  Bannerghatta  8861892693fffff  13.0        26
# 642                  Bannerghatta  886189269bfffff  12.0        41
# 644                  Bannerghatta  88618926a9fffff  12.0       515
# 647                  Bannerghatta  88618926bbfffff  13.0       204
# 650                  Bannerghatta  88618926c3fffff  11.0        55
# 652                  Bannerghatta  88618926c7fffff   9.0        29
# 653                  Bannerghatta  88618926c9fffff  11.0        51
# 654                  Bannerghatta  88618926cbfffff  11.0        22
# 655                  Bannerghatta  88618926cbfffff  12.0        49
# 657                  Bannerghatta  88618926d3fffff  13.0        44
# 658                  Bannerghatta  88618926d5fffff   9.0        24
# 659                  Bannerghatta  88618926d7fffff  14.0        31
# 660                  Bannerghatta  88618926d9fffff  12.0        51
# 661                  Bannerghatta  88618926dbfffff  13.0        46
# 662                  Bannerghatta  88618926ddfffff  11.0        20
# 663                  Bannerghatta  88618926ddfffff  12.0        70
# 666                  Bannerghatta  88618926e5fffff  14.0        90
# 672              Bannerghatta Zoo  8860145201fffff  11.0        40
# 673              Bannerghatta Zoo  8860145263fffff  11.0        43
# 674              Bannerghatta Zoo  8860145265fffff  12.0        20
# 675              Bannerghatta Zoo  886014c911fffff  12.0        23
# 676              Bannerghatta Zoo  886014c915fffff  14.0        46
# 677              Bannerghatta Zoo  886014c917fffff  12.0        36
# 678              Bannerghatta Zoo  886014c919fffff  12.0        21
# 679              Bannerghatta Zoo  886014c91bfffff  11.0        25
# 681              Bannerghatta Zoo  886014c93bfffff  11.0        28
# 682              Bannerghatta Zoo  886014c957fffff  11.0        65
# 683              Bannerghatta Zoo  886014c989fffff  12.0        71
# 684              Bannerghatta Zoo  886014c989fffff  13.0        23
# 685              Bannerghatta Zoo  886014c9abfffff  10.0        37
# 686              Bannerghatta Zoo  886014c9abfffff  11.0        58
# 687              Bannerghatta Zoo  886014c9abfffff  12.0       227
# 688              Bannerghatta Zoo  886014c9abfffff  13.0        36
# 689              Bannerghatta Zoo  886014c9abfffff  14.0        29
# 691              Bannerghatta Zoo  886014c9edfffff  12.0        48
# 710                     Bellandur  8861892501fffff  11.0        77
# 726                        Bidadi  8860144105fffff  10.0        33
# 728                        Bidadi  8860144109fffff  12.0        20
# 732                        Bidadi  8860144149fffff  11.0        27
# 733                        Bidadi  8860144149fffff  12.0        29
# 737                        Bidadi  886014414dfffff  12.0        32
# 738                        Bidadi  8860144159fffff  10.0        40
# 739                        Bidadi  886014415dfffff  10.0        90
# 740                        Bidadi  886014415dfffff  12.0        25
# 741                        Bidadi  886014415dfffff  13.0        26
# 742                        Bidadi  8860144165fffff  12.0        44
# 743                        Bidadi  886014420dfffff  12.0        35
# 744                        Bidadi  8860144221fffff  12.0        20
# 745                        Bidadi  8860144223fffff  10.0        37
# 746                        Bidadi  8860144223fffff  11.0        36
# 747                        Bidadi  8860144223fffff  12.0        61
# 748                        Bidadi  8860144223fffff  13.0        21
# 752                        Bidadi  8860144235fffff  12.0        24
# 753                        Bidadi  8860144239fffff  10.0        20
# 754                        Bidadi  886014423bfffff  11.0        28
# 755                        Bidadi  8860144265fffff  12.0        81
# 756                        Bidadi  8860144309fffff  12.0        27
# 757                        Bidadi  8860144323fffff  11.0        39
# 759                        Bidadi  8860144327fffff  11.0        27
# 760                        Bidadi  8860144327fffff  12.0        32
# 761                        Bidadi  886014432dfffff  11.0        25
# 763                        Bidadi  8860144335fffff  11.0        22
# 764                        Bidadi  8860144337fffff   9.0        23
# 765                        Bidadi  8860144337fffff  10.0        25
# 766                        Bidadi  8860144337fffff  11.0       109
# 767                        Bidadi  8860144337fffff  12.0        99
# 769                        Bidadi  886014433dfffff  10.0        23
# 770                        Bidadi  886014433dfffff  12.0        28
# 771                        Bidadi  8860144345fffff  10.0        31
# 772                        Bidadi  8860144345fffff  11.0        20
# 773                        Bidadi  8860144349fffff  10.0        47
# 774                        Bidadi  886014434dfffff  10.0       107
# 775                        Bidadi  886014434dfffff  11.0       162
# 776                        Bidadi  886014434dfffff  12.0        76
# 778                        Bidadi  8860144355fffff  12.0        22
# 783                        Bidadi  8860144369fffff  11.0        23
# 784                        Bidadi  8860144369fffff  12.0        29
# 785                        Bidadi  886014436dfffff  12.0        29
# 786                        Bidadi  8860144a5bfffff  10.0        25
# 787                        Bidadi  8860144a8dfffff   8.0        20
# 790                        Bidadi  8860144ac5fffff  10.0        36
# 791                        Bidadi  8860144acbfffff  10.0        23
# 792                        Bidadi  8860145181fffff  13.0       236
# 793                        Bidadi  8860145183fffff  14.0        35
# 795                        Bidadi  8860145187fffff  12.0        81
# 796                        Bidadi  886014518dfffff  14.0        51
# 797                        Bidadi  8860145195fffff  12.0       107
# 798                        Bidadi  88601451a1fffff  12.0        31
# 799                        Bidadi  88601451a3fffff   9.0        21
# 801                        Bidadi  88601451a7fffff  11.0        29
# 802                        Bidadi  88601451a9fffff  14.0        43
# 803                        Bidadi  88601451abfffff  10.0        21
# 804                        Bidadi  88601451abfffff  11.0        42
# 805                        Bidadi  88601451abfffff  12.0        31
# 808                        Bidadi  88601451b3fffff  10.0        42
# 809                        Bidadi  88601451b3fffff  11.0        29
# 810                        Bidadi  88601451b3fffff  12.0        36
# 811                        Bidadi  88601451b5fffff  10.0        40
# 813                        Bidadi  88601451bbfffff  10.0        21
# 814                        Bidadi  88601451bdfffff  12.0        24
# 816                        Bidadi  8860145881fffff  14.0        41
# 817                        Bidadi  8860145883fffff  14.0        23
# 818                        Bidadi  8860145887fffff  12.0        78
# 819                        Bidadi  8860145889fffff  13.0        68
# 822                        Bidadi  8860145895fffff  12.0       141
# 825                        Bidadi  886014589bfffff  12.0       106
# 826                        Bidadi  886014589dfffff  11.0       133
# 827                        Bidadi  88601458b1fffff  11.0        35
# 828                        Bidadi  88601458b9fffff  13.0        23
# 832                        Bidadi  88601458cbfffff  12.0        68
# 834                        Bidadi  88601458d3fffff  12.0        48
# 837                        Bidadi  88601458ddfffff  10.0        56
# 838                        Bidadi  8860145a91fffff  13.0        36
# 1260                      Hoskote  88618928d9fffff  10.0        49
# 1261                      Hoskote  88618928dbfffff  14.0        88
# 1263                      Hoskote  88618928ebfffff  10.0        28
# 1264                      Hoskote  8861892ab7fffff  12.0        43
# 1266                      Hoskote  8861892f21fffff  11.0        37
# 1267                      Hoskote  8861892f23fffff  13.0        78
# 1269                      Hoskote  8861892f27fffff  10.0        65
# 1270                      Hoskote  8861892f29fffff  11.0        23
# 1271                      Hoskote  8861892f29fffff  13.0        20
# 1273                      Hoskote  8861892f2dfffff  12.0        95
# 1274                  Hoskote_BLR  8861892101fffff  14.0        26
# 1275                  Hoskote_BLR  8861892103fffff  14.0        33
# 1276                  Hoskote_BLR  8861892109fffff  14.0        44
# 1277                  Hoskote_BLR  8861892111fffff  10.0        95
# 1278                  Hoskote_BLR  8861892113fffff  14.0       212
# 1279                  Hoskote_BLR  8861892115fffff  12.0        80
# 1281                  Hoskote_BLR  8861892119fffff  10.0        51
# 1282                  Hoskote_BLR  886189211bfffff  14.0        60
# 1283                  Hoskote_BLR  886189211dfffff  11.0        20
# 1284                  Hoskote_BLR  8861892131fffff  12.0        33
# 1285                  Hoskote_BLR  8861892133fffff  10.0        32
# 1289                  Hoskote_BLR  886189213bfffff  14.0        23
# 1290                  Hoskote_BLR  886189213dfffff  12.0        24
# 1292                  Hoskote_BLR  8861892143fffff  11.0       150
# 1294                  Hoskote_BLR  8861892147fffff  11.0       109
# 1295                  Hoskote_BLR  8861892149fffff  10.0        40
# 1296                  Hoskote_BLR  886189214bfffff  13.0        36
# 1297                  Hoskote_BLR  8861892157fffff  10.0        56
# 1298                  Hoskote_BLR  886189216bfffff  12.0        35
# 1301                  Hoskote_BLR  88618921e5fffff  11.0        21
# 1302                  Hoskote_BLR  88618921e9fffff  12.0        51
# 1303                  Hoskote_BLR  88618921edfffff  14.0        49
# 1305                  Hoskote_BLR  8861892801fffff  14.0        38
# 1307                  Hoskote_BLR  886189280dfffff  12.0       122
# 1308                  Hoskote_BLR  8861892813fffff  10.0        25
# 1309                  Hoskote_BLR  886189281bfffff  10.0        20
# 1310                  Hoskote_BLR  8861892825fffff  10.0        24
# 1311                  Hoskote_BLR  8861892825fffff  12.0        27
# 1315                  Hoskote_BLR  886189282dfffff  12.0        52
# 1316                  Hoskote_BLR  8861892843fffff  12.0        37
# 1317                  Hoskote_BLR  8861892845fffff  12.0        31
# 1318                  Hoskote_BLR  8861892851fffff  14.0        84
# 1319                  Hoskote_BLR  8861892853fffff  10.0        76
# 1320                  Hoskote_BLR  8861892855fffff  11.0        38
# 1321                  Hoskote_BLR  8861892857fffff  14.0        20
# 1322                  Hoskote_BLR  8861892859fffff  11.0        25
# 1324                  Hoskote_BLR  886189285dfffff  11.0        55
# 1325                  Hoskote_BLR  886189285dfffff  12.0        84
# 1326                  Hoskote_BLR  886189285dfffff  14.0        21
# 1327                  Hoskote_BLR  8861892863fffff  10.0        58
# 1328                  Hoskote_BLR  88618929c9fffff   6.0        33
# 1329                  Hoskote_BLR  88618929dbfffff  12.0        24
# 1330                  Hoskote_BLR  8861892a19fffff  12.0        32
# 1331                  Hoskote_BLR  8861892a2bfffff  11.0        20
# 1332                  Hoskote_BLR  8861892a55fffff  12.0        20
# 1333                  Hoskote_BLR  8861892a85fffff  12.0        44
# 1334                  Hoskote_BLR  8861892a89fffff  12.0        20
# 1337                  Hoskote_BLR  8861892aa7fffff  10.0        64
# 1338                  Hoskote_BLR  8861892aa9fffff  11.0        33
# 1342                  Hoskote_BLR  8861892ad7fffff  14.0        58
# 1345                  Hoskote_BLR  8861892ae7fffff  12.0        43
# 1346                  Hoskote_BLR  8861893893fffff  12.0        66
# 1347                  Hoskote_BLR  8861893893fffff  13.0        27
# 1354                       Huskur  8861892297fffff  13.0        27
# 1355                       Huskur  886189229bfffff  12.0        80
# 1357                       Huskur  8861892741fffff  13.0        26
# 1358                       Huskur  8861892743fffff  14.0        28
# 1360                       Huskur  8861892747fffff  14.0        47
# 1361                       Huskur  8861892749fffff  10.0        26
# 1362                       Huskur  886189274bfffff  14.0        66
# 1363                       Huskur  886189274dfffff  12.0        27
# ...
# 495           Less
# 496           Less
# 497           Less
# 498           Less
# 499           Less
# 500           Less
# 501           Less
# 502           Less
# 503           Less
# 504           Less
# 505           Less
# 506           Less
# 507           Less
# 508           Less
# 509           Less
# 510           Less
# 511           Less
# 512           Less
# 513           Less
# 514           Less
# 515           Less
# 516           Less
# 517           Less
# 518           Less
# 519           Less
# 520           Less
# 521           Less
# 522           Less
# 523           Less
# 524           Less
# 525           Less
# 526           Less
# 527           Less
# 528           Less
# 529           Less
# 530           Less
# 531           Less
# 532           Less
# 534           Less
# 535           Less
# 536           Less
# 537           Less
# 538           Less
# 539           Less
# 540           Less
# 541           Less
# 542           Less
# 543           Less
# 544           Less
# 545           Less
# 546           Less
# 547           Less
# 550           Less
# 551           Less
# 552           Less
# 553           Less
# 555           Less
# 556           Less
# 557           Less
# 558           Less
# 559           Less
# 560           Less
# 561           Less
# 562           Less
# 565           Less
# 566           Less
# 567           Less
# 568           Less
# 569           Less
# 570           Less
# 571           Less
# 572           Less
# 574           Less
# 575           Less
# 576           Less
# 577           Less
# 579           Less
# 580           Less
# 581           Less
# 582           Less
# 583           Less
# 584           Less
# 585           Less
# 586           Less
# 587           Less
# 588           Less
# 591           Less
# 592           Less
# 593           Less
# 594           Less
# 595           Less
# 596           Less
# 597           Less
# 598           Less
# 599           Less
# 600           Less
# 604           Less
# 605           Less
# 606           Less
# 607           Less
# 608           Less
# 611           Less
# 612           Less
# 613           Less
# 614           Less
# 615           Less
# 616           Less
# 618           Less
# 619           Less
# 622           Less
# 623           Less
# 624           Less
# 628           Less
# 629           Less
# 632           Less
# 633           Less
# 635           Less
# 636           Less
# 637           Less
# 638           Less
# 639           Less
# 642           Less
# 644           Less
# 647           Less
# 650           Less
# 652           Less
# 653           Less
# 654           Less
# 655           Less
# 657           Less
# 658           Less
# 659           Less
# 660           Less
# 661           Less
# 662           Less
# 663           Less
# 666           Less
# 672           Less
# 673           Less
# 674           Less
# 675           Less
# 676           Less
# 677           Less
# 678           Less
# 679           Less
# 681           Less
# 682           Less
# 683           Less
# 684           Less
# 685           Less
# 686           Less
# 687           Less
# 688           Less
# 689           Less
# 691           Less
# 710           Less
# 726           Less
# 728           Less
# 732           Less
# 733           Less
# 737           Less
# 738           Less
# 739           Less
# 740           Less
# 741           Less
# 742           Less
# 743           Less
# 744           Less
# 745           Less
# 746           Less
# 747           Less
# 748           Less
# 752           Less
# 753           Less
# 754           Less
# 755           Less
# 756           Less
# 757           Less
# 759           Less
# 760           Less
# 761           Less
# 763           Less
# 764           Less
# 765           Less
# 766           Less
# 767           Less
# 769           Less
# 770           Less
# 771           Less
# 772           Less
# 773           Less
# 774           Less
# 775           Less
# 776           Less
# 778           Less
# 783           Less
# 784           Less
# 785           Less
# 786           Less
# 787           Less
# 790           Less
# 791           Less
# 792           Less
# 793           Less
# 795           Less
# 796           Less
# 797           Less
# 798           Less
# 799           Less
# 801           Less
# 802           Less
# 803           Less
# 804           Less
# 805           Less
# 808           Less
# 809           Less
# 810           Less
# 811           Less
# 813           Less
# 814           Less
# 816           Less
# 817           Less
# 818           Less
# 819           Less
# 822           Less
# 825           Less
# 826           Less
# 827           Less
# 828           Less
# 832           Less
# 834           Less
# 837           Less
# 838           Less
# 840           Less
# 841           Less
# 842           Less
# 843           Less
# 844           Less
# 853           Less
# 855           Less
# 899           Less
# 900           Less
# 905           Less
# 908           Less
# 909           Less
# 915           Less
# 918           Less
# 923           Less
# 925           Less
# 926           Less
# 927           Less
# 928           Less
# 929           Less
# 931           Less
# 932           Less
# 934           Less
# 937           Less
# 939           Less
# 940           Less
# 950           Less
# 953           Less
# 959           Less
# 981           Less
# 982           Less
# 985           Less
# 986           Less
# 987           Less
# 989           Less
# 990           Less
# 991           Less
# 992           Less
# 993           Less
# 994           Less
# 995           Less
# 996           Less
# 997           Less
# 998           Less
# 1000          Less
# 1001          Less
# 1002          Less
# 1003          Less
# 1004          Less
# 1007          Less
# 1008          Less
# 1009          Less
# 1010          Less
# 1012          Less
# 1013          Less
# 1014          Less
# 1015          Less
# 1017          Less
# 1018          Less
# 1019          Less
# 1021          Less
# 1023          Less
# 1024          Less
# 1025          Less
# 1027          Less
# 1029          Less
# 1031          Less
# 1032          Less
# 1033          Less
# 1034          Less
# 1035          Less
# 1038          Less
# 1039          Less
# 1055          Less
# 1056          Less
# 1150          Less
# 1158          Less
# 1159          Less
# 1165          Less
# 1166          Less
# 1167          Less
# 1170          Less
# 1171          Less
# 1173          Less
# 1174          Less
# 1176          Less
# 1177          Less
# 1178          Less
# 1197          Less
# 1199          Less
# 1216          Less
# 1219          Less
# 1222          Less
# 1223          Less
# 1224          Less
# 1227          Less
# 1228          Less
# 1229          Less
# 1235          Less
# 1239          Less
# 1240          Less
# 1247          Less
# 1248          Less
# 1249          Less
# 1250          Less
# 1251          Less
# 1252          Less
# 1253          Less
# 1254          Less
# 1256          Less
# 1257          Less
# 2257          Less
# 2259          Less
# 2265          Less
# 2267          Less
# 2269          Less
# 2271          Less
# 2272          Less
# 2278          Less
# 2286          Less
# 2293          Less
# 2294          Less
# 2297          Less
# 2298          Less
# 2300          Less
# 2301          Less
# 2302          Less
# 2306          Less
# 2307          Less
# 2319          Less
# 2321          Less
# 2325          Less
# 2335          Less
# 2343          Less
# 2382          Less
# 2389          Less
# 2390          Less
# 2392          Less
# 2394          Less
# 2396          Less
# 2399          Less
# 2400          Less
# 2401          Less
# 2402          Less
# 2403          Less
# 2404          Less
# 2406          Less
# 2407          Less
# 2409          Less
# 2410          Less

# %% [markdown]
# ## Other details

# %%
df_overlap_details.head()
# Out:
#       pickup_hex_8   affluence_tag
# 0  88618921d3fffff  High Affluence
# 1  88618921c7fffff  High Affluence
# 2  8861892665fffff  High Affluence
# 3  8860145a33fffff  High Affluence
# 4  8861892c97fffff  High Affluence

# %%
df_overlap_and_swiggy_orders = pd.merge(df_overlap_details, 
                                    df_swiggy_orders,
                                    how = 'inner',
                                    left_on = ['pickup_hex_8'],
                                    right_on = ['location_hex_8']
                                   )

# %%
df_overlap_and_swiggy_orders.swiggy_orders.describe([0.75,0.8,0.85,0.9,0.95])
# Out:
# count      70.000000
# mean      697.485714
# std       937.462328
# min         1.000000
# 50%       350.000000
# 75%       858.750000
# 80%      1056.800000
# 85%      1179.000000
# 90%      1279.700000
# 95%      2066.050000
# max      5667.000000
# Name: swiggy_orders, dtype: float64

# %%
df_overlap_and_swiggy_orders['swiggy_order_flag'] = np.where(df_overlap_and_swiggy_orders['swiggy_orders'] >= df_overlap_and_swiggy_orders.swiggy_orders.quantile(0.80) , 'High Swiggy', 
                                                             np.where(df_overlap_and_swiggy_orders['swiggy_orders'] >= df_overlap_and_swiggy_orders.swiggy_orders.quantile(0.20) , 'Medium Swiggy', 
                                                             'Less Swiggy'))
df_overlap_and_swiggy_orders.head(2)
# Out:
#       pickup_hex_8   affluence_tag  city_name   location_hex_8  link_orders  \
# 0  88618921d3fffff  High Affluence  Bangalore  88618921d3fffff         5513
# 1  88618921c7fffff  High Affluence  Bangalore  88618921c7fffff         2074
#
#    auto_orders  taxi_orders  swiggy_orders  swiggy_median_bill_amount  \
# 0         4892        10405           3059                      326.0
# 1         1301         3375           1186                      336.0
#
#    swiggy_mean_bill_amount  swiggy_total_bill_amount swiggy_order_flag  \
# 0                    407.0                 1246327.0       High Swiggy
# 1                    432.0                  511943.0       High Swiggy
#
#   swiggy_bill_amount_flag
# 0            Medium Price
# 1            Medium Price

# %%
df_overlap_swiggy = df_overlap_and_swiggy_orders \
                    .groupby(['swiggy_order_flag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_overlap_swiggy['swiggy_orders_per_hex'] = df_overlap_swiggy['swiggy_orders']/df_overlap_swiggy['location_hex_8']
df_overlap_swiggy['hex_distr'] = df_overlap_swiggy['location_hex_8']*100.0/df_overlap_swiggy.location_hex_8.sum()
df_overlap_swiggy['swiggy_orders_distr'] = df_overlap_swiggy['swiggy_orders']*100.0/df_overlap_swiggy.swiggy_orders.sum()


df_overlap_swiggy_1 = df_overlap_swiggy.round(2)

# %%
df_overlap_swiggy = df_overlap_and_swiggy_orders \
                    .groupby(['affluence_tag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_overlap_swiggy['swiggy_orders_per_hex'] = df_overlap_swiggy['swiggy_orders']/df_overlap_swiggy['location_hex_8']
df_overlap_swiggy['hex_distr'] = df_overlap_swiggy['location_hex_8']*100.0/df_overlap_swiggy.location_hex_8.sum()
df_overlap_swiggy['swiggy_orders_distr'] = df_overlap_swiggy['swiggy_orders']*100.0/df_overlap_swiggy.swiggy_orders.sum()


df_overlap_swiggy_2 = df_overlap_swiggy.round(2)

# %%
df_overlap_swiggy = df_overlap_and_swiggy_orders \
                    .groupby(['affluence_tag','swiggy_order_flag']) \
                    .agg(
                        location_hex_8 = pd.NamedAgg('location_hex_8', 'nunique'),
                        link_orders = pd.NamedAgg('link_orders', 'sum'),
                        auto_orders = pd.NamedAgg('auto_orders', 'sum'),
                        taxi_orders = pd.NamedAgg('taxi_orders', 'sum'),
                        swiggy_orders = pd.NamedAgg('swiggy_orders', 'sum')
                        ).reset_index()
df_overlap_swiggy['swiggy_orders_per_hex'] = df_overlap_swiggy['swiggy_orders']/df_overlap_swiggy['location_hex_8']
df_overlap_swiggy['hex_distr'] = df_overlap_swiggy['location_hex_8']*100.0/df_overlap_swiggy.location_hex_8.sum()
df_overlap_swiggy['swiggy_orders_distr'] = df_overlap_swiggy['swiggy_orders']*100.0/df_overlap_swiggy.swiggy_orders.sum()


df_overlap_swiggy_3 = df_overlap_swiggy.round(2)

# %%
df_overlap_swiggy_1
# Out:
#   swiggy_order_flag  location_hex_8  link_orders  auto_orders  taxi_orders  \
# 0       High Swiggy              14        60995        69815       130810
# 1       Less Swiggy              14        24856        20963        45819
# 2     Medium Swiggy              42       110990       104703       215693
#
#    swiggy_orders  swiggy_orders_per_hex  hex_distr  swiggy_orders_distr
# 0          28676                2048.29       20.0                58.73
# 1           1164                  83.14       20.0                 2.38
# 2          18984                 452.00       60.0                38.88

# %%
df_overlap_swiggy_2
# Out:
#     affluence_tag  location_hex_8  link_orders  auto_orders  taxi_orders  \
# 0  High Affluence              25        95031        97137       192168
# 1   Low Affluence              45       101810        98344       200154
#
#    swiggy_orders  swiggy_orders_per_hex  hex_distr  swiggy_orders_distr
# 0          34908                1396.32      35.71                 71.5
# 1          13916                 309.24      64.29                 28.5

# %%
df_overlap_swiggy_3
# Out:
#     affluence_tag swiggy_order_flag  location_hex_8  link_orders  auto_orders  \
# 0  High Affluence       High Swiggy              13        59185        68755
# 1  High Affluence     Medium Swiggy              12        35846        28382
# 2   Low Affluence       High Swiggy               1         1810         1060
# 3   Low Affluence       Less Swiggy              14        24856        20963
# 4   Low Affluence     Medium Swiggy              30        75144        76321
#
#    taxi_orders  swiggy_orders  swiggy_orders_per_hex  hex_distr  \
# 0       127940          27372                2105.54      18.57
# 1        64228           7536                 628.00      17.14
# 2         2870           1304                1304.00       1.43
# 3        45819           1164                  83.14      20.00
# 4       151465          11448                 381.60      42.86
#
#    swiggy_orders_distr
# 0                56.06
# 1                15.44
# 2                 2.67
# 3                 2.38
# 4                23.45

# %%
# 20| 80| 80+
ha = round(13*100/14,2)
la = round(14*100/14,2)
print('High Swiggy with High Affluence signal overlap percentage',ha)
print('Less Swiggy with Less Affluence signal overlap percentage',la)
# Out:
# High Swiggy with High Affluence signal overlap percentage 92.86
# Less Swiggy with Less Affluence signal overlap percentage 100.0

# %% [markdown]
# ### Summary
# #### Less 0-50 quantile | Medium 50-80 quantile | High 80 Above quantile
#
# - Bangalore city all hex<br>
#     High Swiggy with High Affluence signal overlap percentage 98.06<br>
#     Less Swiggy with Less Affluence signal overlap percentage 67.43<br><br>
# - 70 hex<br>
#     High Swiggy with High Affluence signal overlap percentage 92.86<br>
#     Less Swiggy with Less Affluence signal overlap percentage 97.14<br><br><br>
#
# #### Less 0-35 quantile | Medium 35-75 quantile | High 75 Above quantile
#
# - Bangalore city all hex<br>
#     High Swiggy with High Affluence signal overlap percentage 97.53<br>
#     Less Swiggy with Less Affluence signal overlap percentage 69.87<br><br>
# - 70 hex<br>
#     High Swiggy with High Affluence signal overlap percentage 83.33<br>
#     Less Swiggy with Less Affluence signal overlap percentage 96.0<br><br><br>
#
# #### Less 0-20 quantile | Medium 20-80 quantile | High 80 Above quantile
#
# - Bangalore city all hex<br>
#     High Swiggy with High Affluence signal overlap percentage 98.06<br>
#     Less Swiggy with Less Affluence signal overlap percentage 72.46<br><br>
# - 70 hex<br>
#     High Swiggy with High Affluence signal overlap percentage 92.86<br>
#     Less Swiggy with Less Affluence signal overlap percentage 100.0

# %% [markdown]
# ## 30% of Low Affluence hex_8 with negative funnel rate.
#
# BGS Kengeri	- 8860145ad1fffff -> Minor change in PPKM (-0.03)
# <br>
# Mathikere Lake	- 8860145943fffff -> PPKM Increased by (0.04)
# <br>
# Mysore rd	- 8860145a05fffff -> PPKM Increased by (0.11)
# <br>
# Sahakara Nagar	- 8861892c95fffff -> Minor change in PPKM (-0.03)
# <br>
# Vijayanagar	- 886014584dfffff -> Minor change in PPKM (-0.03)
# <br>
# Yelanhanka	- 8861892db7fffff -> Minor change in PPKM (-0.07)
# <br>
# Yeshwanthpur - Mathikere	886014594bfffff -> PPKM Increased by (0.06)
