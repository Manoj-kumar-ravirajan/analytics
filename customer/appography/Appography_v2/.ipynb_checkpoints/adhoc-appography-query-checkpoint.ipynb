# %% [markdown]
# ## Imports

# %%
import os
import re
import time

import numpy as np
import pandas as pd
import hiplot as hip
import matplotlib.pyplot as plt
import datetime as datetime

from scipy import stats
from pyhive import presto
from datetime import datetime, timedelta

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 300)
os.environ['PYDEVD_DISABLE_FILE_VALIDATION'] = '1'

# %%
## Connection
connection = presto.connect(
        host='presto-gateway.serving.data.production.internal',
        port=80,
        protocol='http',
        catalog='hive',
        username='manoj.ravirajan@rapido.bike'
)

# %% [markdown]
# ## Datasets & Parameter

# %%
# Get the current working directory
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/rapido/analytics/customer/Appography/Appography_v2

# %% [markdown]
# ### Customer installed apps

# %%
## Parameter 
start_date = '20240318'
end_date = '20240331'
city = 'Hyderabad'

# %%
##customer_installed_apps

start_time = time.time()

customer_installed_apps_query = f"""

WITH active_customers AS (

    SELECT 
        customer_id
    FROM 
        orders.order_logs_snapshot
    WHERE
        yyyymmdd >= '{start_date}'
        AND yyyymmdd <= '{end_date}'
        AND channel_host IN ('android')
        AND city_name = '{city}'
    ),     
    
    customer_app AS (
    
    SELECT
        id user, 
        yyyymmdd,
        updated_epoch,
        json_extract(data, '$.appographyData') as app_list
    FROM 
        raw_internal.kafka_info_customer_installed_apps_v1
    WHERE 
        yyyymmdd >= DATE_FORMAT((DATE_TRUNC('month', CURRENT_DATE) - INTERVAL '2' MONTH), '%Y%m%d')
        AND yyyymmdd <= DATE_FORMAT((CURRENT_DATE - INTERVAL '1' DAY), '%Y%m%d')
    )
    
    SELECT
        user,
        app_list
    FROM 
        (
        SELECT
            customer_app.*,
            row_number() over(partition by user order by updated_epoch DESC) updated_seq
        FROM 
            active_customers
        JOIN 
            customer_app
            ON customer_id = user
        )
    WHERE 
        updated_seq = 1
"""

df_customer_installed_apps = pd.read_sql(customer_installed_apps_query, connection)

df_customer_installed_apps_v1 = df_customer_installed_apps[['user', 'app_list']].copy()

##Define a function to extract values between double quotations and trim extra spaces
def extract_and_trim(text):
    return [val.strip() for val in re.findall(r'"(.*?)"', text)]

df_customer_installed_apps_v1['app_list'] = df_customer_installed_apps_v1['app_list'].apply(lambda x: extract_and_trim(x))

end_time = time.time()
execution_time = ((end_time - start_time)/60.00)
print("Execution time:", execution_time, "mins")
# Out:
# Execution time: 2.0462626020113626 mins

# %%
df_customer_installed_apps_v1
# Out:
#                              user  \
# 0        656d6c78be45f1519468f640
# 1        658f99ad993d04939af5627b
# 2        64f8adff3917fcc97b65a82c
# 3        6348d12fb38d5d31230a9588
# 4        62d79c22b0c23282dd04ba4b
# ...                           ...
# 1616309  5e1077c9715b3f22b965bf37
# 1616310  62f66354c30fe22fbb8ea6a0
# 1616311  633eaea9417898d9e79927a8
# 1616312  5dab2970a52eca27857c0040
# 1616313  5ced649c25ee3218d4e7e761
#
#                                                   app_list
# 0        [Aha, Amazon Prime Video, Amazon Music, Bookin...
# 1        [Clock, Facebook, Messenger, Flipkart, Google ...
# 2        [Zomato, CRED, Flipkart, Google Sheets, Google...
# 3        [Wynk Music, Facebook, Messenger, Flipkart, Go...
# 4        [Aha, Amazon Prime Video, Zomato, BigBasket, B...
# ...                                                    ...
# 1616309  [Adobe Lightroom, Amazon Shopping, Axis Mobile...
# 1616310  [Amazon Prime Video, BookMyShow, Facebook, Fli...
# 1616311  [Aha, Amazon Prime Video, Zomato, Wynk Music, ...
# 1616312  [Facebook, Messenger, Google Maps, Google Phot...
# 1616313  [Aha, Amazon Prime Video, Clock, Zomato, MS Au...
#
# [1616314 rows x 2 columns]

# %% [markdown]
# ### Customer base

# %%
##Please replace the different customer cohort

start_time = time.time()


##active_customer_query
active_customer_demographic_query = f"""

    WITH active_customers AS (

    SELECT 
        channel_host,
        customer_id,
        COALESCE(city_name, 'NA') city_name
    FROM 
        (
        SELECT 
            channel_host,
            customer_id,
            city_name,
            row_number() over(partition by customer_id order by updated_epoch DESC) updated_seq
        FROM 
            orders.order_logs_snapshot
        WHERE
            yyyymmdd >= '{start_date}'
            AND yyyymmdd <= '{end_date}'
            AND channel_host IN ('android', 'ios')
            AND city_name = '{city}'
        ) 
    WHERE
        updated_seq = 1
    ), 

    customer_single_view AS (

    SELECT
        customerId,
        gender,
        lifetimeage rapido_age,
        CASE 
        WHEN ((POSITION('/' IN dateofbirth) > 0 AND dateofbirth <> 'NaN/NaN/NaN') or POSITION('-' IN dateofbirth) > 0) 
        THEN 
            CASE 
            WHEN TRY(date_diff('year', CAST(dateofbirth AS DATE), current_date)) IS NOT NULL 
            THEN date_diff('year', CAST(dateofbirth AS DATE), current_date)
            ELSE NULL
            END
        ELSE NULL
        END AS customer_age,
        lifetimerides
    FROM 
        datasets.customer_single_view
    WHERE 
        customerId IN (SELECT customer_id FROM active_customers)
    ),

    iallocator_customer_segments AS (

    SELECT
        customer_id user_id,
        taxi_ltr_segment ltr_segment,
        taxi_lifetime_rides life_time_rides,
        taxi_lifetime_stage life_time_stage,
        taxi_income_segment income_segment,
        taxi_service_affinity service_affinity,
        taxi_distance_preference distance_preference,
        CASE 
        WHEN ps_tag_auto = ps_tag_link THEN ps_tag_auto
        WHEN ps_tag_auto = 'PS' OR ps_tag_link = 'PS' THEN 'PS'
        WHEN ps_tag_auto = 'NPS' OR ps_tag_link = 'NPS' THEN 'NPS'
        ELSE 'UNKNOWN'
        END ps_tag_taxi

    FROM 
        datasets.iallocator_customer_segments
    WHERE 
        run_date = DATE_FORMAT(DATE_PARSE('{end_date}', '%Y%m%d'), '%Y-%m-%d')
        AND customer_id IN (SELECT customer_id FROM active_customers)
    )

    SELECT
        a.*,
        c.gender,
        c.rapido_age,
        COALESCE(CAST(c.customer_age AS VARCHAR), 'NA') customer_age,
        CASE 
        WHEN life_time_rides = 0 OR c.lifetimerides = 0 THEN 'LTR 0'
        WHEN life_time_rides > 0 THEN ltr_segment
        ELSE 'UNKNOWN'
        END AS ltr_segment,
        COALESCE(life_time_rides, c.lifetimerides) life_time_rides,
        COALESCE(life_time_stage, 'UNKNOWN') AS life_time_stage,
        COALESCE(income_segment, 'UNKNOWN') AS income_segment,
        COALESCE(service_affinity, 'NO_AFFINITY') AS service_affinity,
        COALESCE(distance_preference, 'UNKNOWN') AS distance_preference,
        COALESCE(ps_tag_taxi, 'UNKNOWN') AS price_sensitivity 
    FROM 
        active_customers a
    LEFT JOIN 
        customer_single_view c
        ON a.customer_id = c.customerId
    LEFT JOIN 
        iallocator_customer_segments b
        ON a.customer_id = b.user_id
"""

df_active_customer_demographic = pd.read_sql(active_customer_demographic_query, connection)

active_customer_ao_net_query = f"""

    WITH fe_tbl AS (
        SELECT
            DATE_FORMAT(DATE_PARSE(yyyymmdd, '%Y%m%d'), '%Y-%m-%d') order_date,
            city,
            service_name,
            user_id as user_id,
            fare_estimate_id
        FROM
            hive.pricing.fare_estimates_enriched
        WHERE 
            yyyymmdd >= '{start_date}'
            AND yyyymmdd <= '{end_date}'
            AND city = '{city}'
    ),

    rr_net_tbl as (
        SELECT   
            DATE_FORMAT(DATE_PARSE(yyyymmdd, '%Y%m%d'), '%Y-%m-%d') order_date,
            city_name AS city,
            service_obj_service_name AS service_name,
            customer_id,
            estimate_id AS fare_estimate_id,
            order_id,
            order_status,
            spd_fraud_flag
        FROM orders.order_logs_snapshot ols
        WHERE
            yyyymmdd >= '{start_date}'
            AND yyyymmdd <= '{end_date}'
            AND channel_host IN ('android', 'ios')
            AND city_name = '{city}'
    ),

    fe_merged AS (
        SELECT
            fe_tbl.*,
            rr_net_tbl.customer_id,
            rr_net_tbl.order_id,
            rr_net_tbl.order_status,
            rr_net_tbl.spd_fraud_flag
        FROM
            fe_tbl
        LEFT JOIN
            rr_net_tbl
            ON fe_tbl.order_date = rr_net_tbl.order_date
            AND fe_tbl.user_id = rr_net_tbl.customer_id
    )

    SELECT
        customer_id,
        COUNT(distinct fare_estimate_id) AS fe_count,
        COUNT(distinct order_id) AS rr_count,
        COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != True THEN order_id END) AS net_count

    FROM 
        fe_merged
    GROUP BY 1

"""

df_active_customer_ao_net_query = pd.read_sql(active_customer_ao_net_query, connection)

df_active_customer = pd.merge(df_active_customer_demographic,
                              df_active_customer_ao_net_query,
                              how='left',
                              on = ['customer_id']
                             )

end_time = time.time()
execution_time = ((end_time - start_time)/60.00)
print("Execution time:", execution_time, "mins")
# Out:
# Execution time: 4.197930967807769 mins

# %%
df_active_customer.head(2)
# Out:
#   channel_host               customer_id  city_name gender  rapido_age  \
# 0      android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 1      android  5d4ed35b55fbf50d45edac48  Hyderabad   MALE      1700.0
#
#   customer_age ltr_segment  life_time_rides life_time_stage income_segment  \
# 0           28         PHH              110         DORMANT    HIGH_INCOME
# 1           24         PHH               80      SUSTENANCE  MEDIUM_INCOME
#
#   service_affinity distance_preference price_sensitivity  fe_count  rr_count  \
# 0        ONLY_LINK     MEDIUM_DISTANCE               NPS       2.0       1.0
# 1      NO_AFFINITY             UNKNOWN               NPS       5.0       3.0
#
#    net_count
# 0        0.0
# 1        3.0

# %% [markdown]
# ### category list

# %% [markdown]
# Google Sheet - https://docs.google.com/spreadsheets/d/1O6IsJ2dzzhXKuoHFoOA0AD4s4SOerMC1U-KrpeFnbwQ/edit#gid=1742529009

# %%
##Read the shared mapping csv file

"""
cwd = os.getcwd()
file_path = os.path.join(cwd, 'category_list_v1.csv')
category_list = pd.read_csv(file_path)

"""

##category_list = pd.read_clipboard()

# %%
category_list['app_name'] = category_list['app_name'].str.lower()
category_list = category_list[['app_name', 'categories_l2', 'categories_l1']]
print(category_list.shape)
print(category_list.categories_l1.unique())
print(category_list.categories_l2.unique())
category_list.head(1)
# Out:
# (399, 3)
# ['Educational' 'OTT' 'Delivery_Grocery' 'Tools' 'Office' 'Dating' 'News'
#  'Devotional' 'Travel_Metro' 'Gaming' 'Travel_Bookings'
#  'Finance_Transactions' 'Ecommerce' 'Streaming_Music' 'Finance_Investment'
#  'Health' 'Fantasy_Sports' 'Delivery_Food' 'Home_Security' 'Finance_News'
#  'Travel_Ridehailing' 'Social' 'Telecom' 'Entertainment' 'News_finance'
#  'Wearable' 'Driver_App']
# ['Educational' 'Rest' 'Office' 'Ride haling' 'Gaming' 'Finance_Investment'
#  'Driver_App']
#           app_name categories_l2 categories_l1
# 0  ignou e-content   Educational   Educational

# %% [markdown]
# ### Merge

# %%
df_active_customer.head(1)
# Out:
#   channel_host               customer_id  city_name gender  rapido_age  \
# 0      android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
#
#   customer_age ltr_segment  life_time_rides life_time_stage income_segment  \
# 0           28         PHH              110         DORMANT    HIGH_INCOME
#
#   service_affinity distance_preference price_sensitivity  fe_count  rr_count  \
# 0        ONLY_LINK     MEDIUM_DISTANCE               NPS       2.0       1.0
#
#    net_count
# 0        0.0

# %%
df_customer_installed_apps_v1.head(1)
# Out:
#                        user                                           app_list
# 0  656d6c78be45f1519468f640  [Aha, Amazon Prime Video, Amazon Music, Bookin...

# %%
df_customer_coverage = pd.merge(df_active_customer,
                                df_customer_installed_apps_v1,
                                how='left',
                                left_on=['customer_id'], 
                                right_on=['user']
                                )
df_customer_coverage.head(2)
# Out:
#   channel_host               customer_id  city_name gender  rapido_age  \
# 0      android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 1      android  5d4ed35b55fbf50d45edac48  Hyderabad   MALE      1700.0
#
#   customer_age ltr_segment  life_time_rides life_time_stage income_segment  \
# 0           28         PHH              110         DORMANT    HIGH_INCOME
# 1           24         PHH               80      SUSTENANCE  MEDIUM_INCOME
#
#   service_affinity distance_preference price_sensitivity  fe_count  rr_count  \
# 0        ONLY_LINK     MEDIUM_DISTANCE               NPS       2.0       1.0
# 1      NO_AFFINITY             UNKNOWN               NPS       5.0       3.0
#
#    net_count                      user  \
# 0        0.0  60766b5ecde8c60e6fc0af3c
# 1        3.0  5d4ed35b55fbf50d45edac48
#
#                                             app_list
# 0  [Aha, Adobe Scan, Amazon Prime Video, Zomato, ...
# 1  [Amazon Prime Video, Facebook, Flipkart, Googl...

# %%
df_customer_app_list_explode = df_customer_coverage.explode('app_list')
df_customer_app_list_explode['app_list'] = df_customer_app_list_explode['app_list'].str.lower()
df_customer_app_list_explode
# Out:
#         channel_host               customer_id  city_name gender  rapido_age  \
# 0            android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 0            android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 0            android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 0            android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 0            android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# ...              ...                       ...        ...    ...         ...
# 2093497      android  65fe7bdfd77e95e12881109e  Hyderabad   MALE        13.0
# 2093497      android  65fe7bdfd77e95e12881109e  Hyderabad   MALE        13.0
# 2093497      android  65fe7bdfd77e95e12881109e  Hyderabad   MALE        13.0
# 2093497      android  65fe7bdfd77e95e12881109e  Hyderabad   MALE        13.0
# 2093497      android  65fe7bdfd77e95e12881109e  Hyderabad   MALE        13.0
#
#         customer_age ltr_segment  life_time_rides life_time_stage  \
# 0                 28         PHH              110         DORMANT
# 0                 28         PHH              110         DORMANT
# 0                 28         PHH              110         DORMANT
# 0                 28         PHH              110         DORMANT
# 0                 28         PHH              110         DORMANT
# ...              ...         ...              ...             ...
# 2093497           NA          HH                1     HANDHOLDING
# 2093497           NA          HH                1     HANDHOLDING
# 2093497           NA          HH                1     HANDHOLDING
# 2093497           NA          HH                1     HANDHOLDING
# 2093497           NA          HH                1     HANDHOLDING
#
#         income_segment service_affinity distance_preference price_sensitivity  \
# 0          HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE               NPS
# 0          HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE               NPS
# 0          HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE               NPS
# 0          HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE               NPS
# 0          HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE               NPS
# ...                ...              ...                 ...               ...
# 2093497    HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE           UNKNOWN
# 2093497    HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE           UNKNOWN
# 2093497    HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE           UNKNOWN
# 2093497    HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE           UNKNOWN
# 2093497    HIGH_INCOME        ONLY_LINK     MEDIUM_DISTANCE           UNKNOWN
#
#          fe_count  rr_count  net_count                      user  \
# 0             2.0       1.0        0.0  60766b5ecde8c60e6fc0af3c
# 0             2.0       1.0        0.0  60766b5ecde8c60e6fc0af3c
# 0             2.0       1.0        0.0  60766b5ecde8c60e6fc0af3c
# 0             2.0       1.0        0.0  60766b5ecde8c60e6fc0af3c
# 0             2.0       1.0        0.0  60766b5ecde8c60e6fc0af3c
# ...           ...       ...        ...                       ...
# 2093497       9.0       1.0        1.0  65fe7bdfd77e95e12881109e
# 2093497       9.0       1.0        1.0  65fe7bdfd77e95e12881109e
# 2093497       9.0       1.0        1.0  65fe7bdfd77e95e12881109e
# 2093497       9.0       1.0        1.0  65fe7bdfd77e95e12881109e
# 2093497       9.0       1.0        1.0  65fe7bdfd77e95e12881109e
#
#                         app_list
# 0                            aha
# 0                     adobe scan
# 0             amazon prime video
# 0                         zomato
# 0                     wynk music
# ...                          ...
# 2093497                  netflix
# 2093497                      ola
# 2093497  samsung galaxy wearable
# 2093497                     uber
# 2093497                 whatsapp
#
# [38142991 rows x 18 columns]

# %%
df_customer_app_cat_mapping = pd.merge(df_customer_app_list_explode, 
                                       category_list, 
                                       how='left', 
                                       left_on='app_list', 
                                       right_on='app_name')
df_customer_app_cat_mapping.head(5)
# Out:
#   channel_host               customer_id  city_name gender  rapido_age  \
# 0      android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 1      android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 2      android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 3      android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
# 4      android  60766b5ecde8c60e6fc0af3c  Hyderabad   MALE      1087.0
#
#   customer_age ltr_segment  life_time_rides life_time_stage income_segment  \
# 0           28         PHH              110         DORMANT    HIGH_INCOME
# 1           28         PHH              110         DORMANT    HIGH_INCOME
# 2           28         PHH              110         DORMANT    HIGH_INCOME
# 3           28         PHH              110         DORMANT    HIGH_INCOME
# 4           28         PHH              110         DORMANT    HIGH_INCOME
#
#   service_affinity distance_preference price_sensitivity  fe_count  rr_count  \
# 0        ONLY_LINK     MEDIUM_DISTANCE               NPS       2.0       1.0
# 1        ONLY_LINK     MEDIUM_DISTANCE               NPS       2.0       1.0
# 2        ONLY_LINK     MEDIUM_DISTANCE               NPS       2.0       1.0
# 3        ONLY_LINK     MEDIUM_DISTANCE               NPS       2.0       1.0
# 4        ONLY_LINK     MEDIUM_DISTANCE               NPS       2.0       1.0
#
#    net_count                      user            app_list  \
# 0        0.0  60766b5ecde8c60e6fc0af3c                 aha
# 1        0.0  60766b5ecde8c60e6fc0af3c          adobe scan
# 2        0.0  60766b5ecde8c60e6fc0af3c  amazon prime video
# 3        0.0  60766b5ecde8c60e6fc0af3c              zomato
# 4        0.0  60766b5ecde8c60e6fc0af3c              zomato
#
#              app_name categories_l2  categories_l1
# 0                 aha          Rest            OTT
# 1          adobe scan          Rest          Tools
# 2  amazon prime video          Rest            OTT
# 3              zomato          Rest  Delivery_Food
# 4              zomato          Rest  Delivery_Food

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Customer-wise App list

# %%
total_customers = df_customer_coverage.customer_id.nunique()
total_customers
# Out:
# 2089119

# %%
df_temp = df_customer_app_list_explode\
            .groupby(['app_list'])\
            .agg(customers = ('customer_id','nunique'))\
            .sort_values(['customers'],ascending=False)\
            .reset_index()
df_temp['%'] =  (df_temp['customers']*100.00/total_customers).round(2)
print(df_customer_app_list_explode.app_list.nunique())
df_temp
# Out:
# 219
#                     app_list  customers      %
# 0                google maps    1615635  77.34
# 1                    youtube    1612669  77.19
# 2                      gmail    1612123  77.17
# 3                   whatsapp    1578912  75.58
# 4              google photos    1543422  73.88
# 5                  instagram    1280854  61.31
# 6                   facebook    1095094  52.42
# 7                 truecaller    1088365  52.10
# 8                paytm money    1028638  49.24
# 9                   flipkart     977185  46.77
# 10           google calendar     963622  46.13
# 11                  snapchat     930687  44.55
# 12           disney+ hotstar     905372  43.34
# 13                    zomato     878003  42.03
# 14                       ola     830490  39.75
# 15                    swiggy     800395  38.31
# 16                   netflix     775485  37.12
# 17                      uber     775206  37.11
# 18                   spotify     728844  34.89
# 19                  linkedin     695864  33.31
# 20                  telegram     689020  32.98
# 21                jio cinema     660272  31.61
# 22        amazon prime video     635789  30.43
# 23                    meesho     615654  29.47
# 24                     clock     565302  27.06
# 25                    myntra     562114  26.91
# 26               google news     555673  26.60
# 27                 messenger     482604  23.10
# 28                bookmyshow     469592  22.48
# 29                      zoom     446989  21.40
# 30                wynk music     443711  21.24
# 31                      ajio     418647  20.04
# 32                  onedrive     376036  18.00
# 33                   outlook     339409  16.25
# 34             google sheets     335227  16.05
# 35                mx takatak     325722  15.59
# 36             microsoft 365     315402  15.10
# 37                       aha     290629  13.91
# 38                      cred     284649  13.63
# 39                 ludo king     282812  13.54
# 40           microsoft teams     277469  13.28
# 41                   grofers     276608  13.24
# 42                      zee5     275041  13.17
# 43       hdfc mobile banking     269715  12.91
# 44                 pinterest     247810  11.86
# 45                 sharechat     241770  11.57
# 46                    redbus     232290  11.12
# 47                 bigbasket     225380  10.79
# 48                   twitter     221621  10.61
# 49             google slides     211683  10.13
# 50               axis mobile     189665   9.08
# 51          ms authenticator     179509   8.59
# 52                adobe scan     171459   8.21
# 53                   sonyliv     163425   7.82
# 54                   picsart     151530   7.25
# 55   samsung galaxy wearable     151289   7.24
# 56                   jiomart     141997   6.80
# 57    intune  company portal     137437   6.58
# 58           microsoft excel     133646   6.40
# 59            rapido captain     121160   5.80
# 60                     groww     118130   5.65
# 61              amazon music     112171   5.37
# 62                  mobikwik     105201   5.04
# 63                     nykaa     105102   5.03
# 64                  firstcry      95251   4.56
# 65           kite by zerodha      84274   4.03
# 66           adobe lightroom      65298   3.13
# 67      google authenticator      64175   3.07
# 68                   goibibo      64168   3.07
# 69                   ms edge      61022   2.92
# 70                     gaana      60605   2.90
# 71                     udemy      60477   2.89
# 72           uber driver app      60416   2.89
# 73               booking.com      59502   2.85
# 74          google classroom      58343   2.79
# 75                     skype      56917   2.72
# 76                     webex      54973   2.63
# 77             angel broking      54733   2.62
# 78                  duolingo      53387   2.56
# 79                     dunzo      52641   2.52
# 80                   brainly      46679   2.23
# 81            ola driver app      43810   2.10
# 82                      byju      42040   2.01
# 83                 pharmeasy      36903   1.77
# 84               healthifyme      35421   1.70
# 85                      voot      34547   1.65
# 86                    indigo      34193   1.64
# 87                  hangouts      31424   1.50
# 88         swiggy driver app      28291   1.35
# 89                     slack      25314   1.21
# 90                 unacademy      24847   1.19
# 91            microsoft lens      22694   1.09
# 92                       nps      22227   1.06
# 93                    zivame      22121   1.06
# 94                  in drive      20353   0.97
# 95                    airbnb      19710   0.94
# 96         microsoft onenote      19373   0.93
# 97                 cleartrip      18840   0.90
# 98                freecharge      18383   0.88
# 99               namma yatri      18170   0.87
# 100                   tinder      17066   0.82
# 101                 coursera      15873   0.76
# 102                   fitbit      15795   0.76
# 103               my11circle      15186   0.73
# 104                   bumble      14987   0.72
# 105        porter driver app      14681   0.70
# 106               calculator      14323   0.69
# 107                  dropbox      13402   0.64
# 108                   swayam      12364   0.59
# 109           physics wallah      11720   0.56
# 110                    yatra      11509   0.55
# 111        zomato driver app      11448   0.55
# 112           zepp (amazfit)      10314   0.49
# 113                   mi fit      10006   0.48
# 114               soundcloud       9769   0.47
# 115            hungama music       9315   0.45
# 116               alt balaji       9087   0.43
# 117         zepto driver app       8863   0.42
# 118           economic times       8722   0.42
# 119          amazon shopping       8618   0.41
# 120            huawei health       8345   0.40
# 121                 doubtnut       8182   0.39
# 122                   notion       7279   0.35
# 123                   diksha       7115   0.34
# 124               quick ride       6981   0.33
# 125                   github       6701   0.32
# 126              simplilearn       6336   0.30
# 127                   strava       6181   0.30
# 128                uber eats       6160   0.29
# 129     shadowfax driver app       6119   0.29
# 130                    happn       5244   0.25
# 131             myfitnesspal       4843   0.23
# 132                    viber       4828   0.23
# 133                zoho mail       4737   0.23
# 134                     mint       4442   0.21
# 135        driveu driver app       4392   0.21
# 136          geeks for geeks       4369   0.21
# 137                     jira       4095   0.20
# 138                    hinge       4002   0.19
# 139                  trivago       3976   0.19
# 140                    aisle       3456   0.17
# 141                   roposo       3386   0.16
# 142                   moodle       3350   0.16
# 143               quackquack       3076   0.15
# 144                 blusmart       3012   0.14
# 145                  vedantu       2968   0.14
# 146      fossil smartwatches       2837   0.14
# 147                     line       2830   0.14
# 148     grofers delivery app       2820   0.13
# 149                goodreads       2770   0.13
# 150              tripadvisor       2664   0.13
# 151                photomath       2599   0.12
# 152                      edx       2500   0.12
# 153    shiprocket driver app       2471   0.12
# 154             zoho meeting       2462   0.12
# 155            namma partner       2330   0.11
# 156         dunzo driver app       1857   0.09
# 157               paytm mall       1816   0.09
# 158             khan academy       1808   0.09
# 159              accuweather       1739   0.08
# 160       the indian express       1685   0.08
# 161              ncert books       1615   0.08
# 162                   tumblr       1527   0.07
# 163         borzo driver app       1478   0.07
# 164                   trello       1427   0.07
# 165                   aakash       1402   0.07
# 166           garmin connect       1391   0.07
# 167         google analytics       1219   0.06
# 168           e-pg pathshala       1149   0.05
# 169              chegg study       1142   0.05
# 170              whitehat jr       1128   0.05
# 171                flipboard       1113   0.05
# 172                  okcupid       1093   0.05
# 173                   pocket       1077   0.05
# 174                quickride        979   0.05
# 175          ignou e-content        971   0.05
# 176                    cisco        971   0.05
# 177                   embibe        957   0.05
# 178               trulymadly        949   0.05
# 179    microsoft math solver        889   0.04
# 180       nike training club        876   0.04
# 181                    asana        876   0.04
# 182                   wechat        847   0.04
# 183           file commander        837   0.04
# 184               confluence        803   0.04
# 185                    kayak        799   0.04
# 186              mycbseguide        718   0.03
# 187                      nba        709   0.03
# 188                 vision11        568   0.03
# 189                   jugnoo        532   0.03
# 190                     hike        486   0.02
# 191              shiksha.com        413   0.02
# 192                     miro        376   0.02
# 193                   feedly        259   0.01
# 194             club factory        252   0.01
# 195           qr code reader        201   0.01
# 196             colegeduniya        190   0.01
# 197                    fiton        189   0.01
# 198              caclubindia        171   0.01
# 199                 myteam11        128   0.01
# 200              course hero        105   0.01
# 201                    toppr         87   0.00
# 202            my study life         85   0.00
# 203       coffee meets bagel         76   0.00
# 204                aastha tv         63   0.00
# 205                      nhl         47   0.00
# 206                      nfl         44   0.00
# 207           stack overflow         43   0.00
# 208                  happify         38   0.00
# 209                 vidyakul         33   0.00
# 210                      mlb         31   0.00
# 211                   voonik         21   0.00
# 212             collegedekho         17   0.00
# 213     yahoo fantasy sports         12   0.00
# 214            shiksha mitra         12   0.00
# 215                  fiitjee         10   0.00
# 216                 cricplay          7   0.00
# 217                free fire          3   0.00
# 218                  nishtha          3   0.00

# %%
df_customer_mapped = df_customer_app_cat_mapping\
                        .groupby(['customer_id'])\
                        .agg(app_list = ('app_list', lambda x: list(set(x))),
                             app_count = ('app_list', 'nunique'),
                             categories_l1 = ('categories_l1', lambda x: list(set(x))),
                             categories_l1_count = ('categories_l1', 'nunique'),
                             categories_l2 = ('categories_l2', lambda x: list(set(x))),
                             categories_l2_count = ('categories_l2', 'nunique')
                            )\
                        .reset_index()

print(df_customer_mapped.shape)
df_customer_mapped.head(5)
# Out:
# (2089119, 7)
#                 customer_id  \
# 0  5737c6d3ddbec2203f7332ba
# 1  573f28f39b0ffc283676efee
# 2  573f28f39b0ffc283676f013
# 3  573f28f39b0ffc283676f08f
# 4  573f28f39b0ffc283676f0a1
#
#                                             app_list  app_count  \
# 0  [flipkart, twitter, google maps, facebook, ola...         22
# 1  [flipkart, sonyliv, slack, google maps, micros...         53
# 2                                              [nan]          0
# 3                                              [nan]          0
# 4  [flipkart, wynk music, google maps, twitter, l...         43
#
#                                        categories_l1  categories_l1_count  \
# 0  [Delivery_Food, Office, Tools, OTT, Travel_Rid...                    8
# 1  [Delivery_Food, Office, Health, Tools, Finance...                   16
# 2                                              [nan]                    0
# 3                                              [nan]                    0
# 4  [Social, Delivery_Food, Office, Educational, T...                   13
#
#                                        categories_l2  categories_l2_count
# 0                        [Rest, Office, Ride haling]                    3
# 1    [Rest, Office, Finance_Investment, Ride haling]                    4
# 2                                              [nan]                    0
# 3                                              [nan]                    0
# 4  [Educational, Office, Finance_Investment, Rest...                    5

# %% [markdown]
# #### Distribution check on categories

# %%
df_temp = df_customer_app_cat_mapping\
            .groupby(['categories_l1'])\
            .agg(app_list = ('app_list', lambda x: list(set(x))),
                 app_count = ('app_list', 'nunique'),
                 customers = ('customer_id','nunique'))\
            .sort_values(['customers'],ascending=False)\
            .reset_index()
df_temp['%'] =  (df_temp['customers']*100.00/total_customers).round(2)
df_temp
# Out:
#            categories_l1                                           app_list  \
# 0                  Tools  [ms edge, microsoft onenote, google maps, gmai...
# 1                 Social  [snapchat, pinterest, hike, wechat, roposo, tw...
# 2                    OTT  [disney+ hotstar, sonyliv, alt balaji, voot, n...
# 3              Ecommerce  [myntra, meesho, amazon shopping, zivame, flip...
# 4   Finance_Transactions  [paytm money, mobikwik, axis mobile, freecharg...
# 5     Travel_Ridehailing  [blusmart, driveu driver app, namma yatri, qui...
# 6          Delivery_Food                 [swiggy, dunzo, uber eats, zomato]
# 7        Streaming_Music  [soundcloud, spotify, wynk music, hungama musi...
# 8                 Office  [jira, google analytics, slack, onedrive, trel...
# 9                   News          [feedly, the indian express, google news]
# 10         Entertainment                                       [bookmyshow]
# 11    Finance_Investment  [groww, nps, kite by zerodha, namma partner, h...
# 12      Delivery_Grocery         [bigbasket, grofers, grofers delivery app]
# 13       Travel_Bookings  [airbnb, tripadvisor, booking.com, cleartrip, ...
# 14                Gaming                             [free fire, ludo king]
# 15           Educational  [happify, fiitjee, brainly, toppr, udemy, cour...
# 16              Wearable  [fossil smartwatches, samsung galaxy wearable,...
# 17            Driver_App  [ola driver app, shadowfax driver app, borzo d...
# 18                Health  [myfitnesspal, nike training club, healthifyme...
# 19                Dating  [tinder, okcupid, hinge, aisle, bumble, quackq...
# 20        Fantasy_Sports  [nba, mlb, cricplay, my11circle, nfl, yahoo fa...
# 21          Finance_News                             [economic times, mint]
# 22            Devotional                                        [aastha tv]
#
#     app_count  customers      %
# 0          23    1616283  77.37
# 1          18    1614195  77.27
# 2           9    1302594  62.35
# 3          14    1246760  59.68
# 4           5    1107020  52.99
# 5           9    1073581  51.39
# 6           4    1061120  50.79
# 7           6    1020987  48.87
# 8          23     869355  41.61
# 9           3     556751  26.65
# 10          1     469592  22.48
# 11          6     429819  20.57
# 12          3     403139  19.30
# 13         10     335333  16.05
# 14          2     282813  13.54
# 15         41     280774  13.44
# 16          6     178348   8.54
# 17         10     172750   8.27
# 18          6      59292   2.84
# 19          9      34754   1.66
# 20          9      16434   0.79
# 21          2      12031   0.58
# 22          1         63   0.00

# %%
df_temp = df_customer_app_cat_mapping\
            .groupby(['categories_l2'])\
            .agg(app_list = ('app_list', lambda x: list(set(x))),
                 app_count = ('app_list', 'nunique'),
                 customers = ('customer_id','nunique'))\
            .sort_values(['customers'],ascending=False)\
            .reset_index()
df_temp['%'] =  (df_temp['customers']*100.00/total_customers).round(2)
df_temp
# Out:
#         categories_l2                                           app_list  \
# 0                Rest  [myfitnesspal, flipkart, nfl, fiton, dunzo, fi...
# 1         Ride haling  [blusmart, driveu driver app, namma yatri, qui...
# 2              Office  [jira, google analytics, slack, onedrive, trel...
# 3  Finance_Investment  [groww, nps, kite by zerodha, namma partner, h...
# 4              Gaming                             [free fire, ludo king]
# 5         Educational  [happify, fiitjee, brainly, toppr, udemy, cour...
# 6          Driver_App  [ola driver app, shadowfax driver app, borzo d...
#
#    app_count  customers      %
# 0        129    1616312  77.37
# 1          9    1073581  51.39
# 2         23     869355  41.61
# 3          6     429819  20.57
# 4          2     282813  13.54
# 5         41     280774  13.44
# 6         10     172750   8.27

# %% [markdown]
# #### Category-level App usage

# %%
print(df_customer_app_cat_mapping['categories_l1'].unique())
# Out:
# ['OTT' 'Tools' 'Delivery_Food' 'Streaming_Music' 'Social' 'Ecommerce'
#  'Office' 'Travel_Ridehailing' 'Wearable' 'Finance_Transactions' nan
#  'News' 'Finance_Investment' 'Educational' 'Travel_Bookings'
#  'Entertainment' 'Gaming' 'Driver_App' 'Dating' 'Delivery_Grocery'
#  'Finance_News' 'Health' 'Fantasy_Sports' 'Devotional']

# %%
print(df_customer_app_cat_mapping['categories_l2'].unique())
# Out:
# ['Rest' 'Office' 'Ride haling' nan 'Finance_Investment' 'Educational'
#  'Gaming' 'Driver_App']

# %%
df_temp = df_customer_app_cat_mapping[~df_customer_app_cat_mapping['categories_l2'].isin(['Rest'])]\
            .groupby(['categories_l2','app_list'])\
            .agg(customers = ('customer_id','nunique'))\
            .sort_values(by=['categories_l2', 'customers'], ascending=[False, False])\
            .reset_index()
df_temp['%'] =  (df_temp['customers']*100.00/total_customers).round(2)
df_temp
# Out:
#          categories_l2                app_list  customers      %
# 0          Ride haling                     ola     830490  39.75
# 1          Ride haling                    uber     775206  37.11
# 2          Ride haling                in drive      20353   0.97
# 3          Ride haling             namma yatri      18170   0.87
# 4          Ride haling              quick ride       6981   0.33
# 5          Ride haling       driveu driver app       4392   0.21
# 6          Ride haling                blusmart       3012   0.14
# 7          Ride haling               quickride        979   0.05
# 8          Ride haling                  jugnoo        532   0.03
# 9               Office                    zoom     446989  21.40
# 10              Office                onedrive     376036  18.00
# 11              Office                 outlook     339409  16.25
# 12              Office           microsoft 365     315402  15.10
# 13              Office         microsoft teams     277469  13.28
# 14              Office        ms authenticator     179509   8.59
# 15              Office  intune  company portal     137437   6.58
# 16              Office    google authenticator      64175   3.07
# 17              Office                   webex      54973   2.63
# 18              Office                   slack      25314   1.21
# 19              Office                 dropbox      13402   0.64
# 20              Office                  github       6701   0.32
# 21              Office               zoho mail       4737   0.23
# 22              Office                    jira       4095   0.20
# 23              Office            zoho meeting       2462   0.12
# 24              Office                  trello       1427   0.07
# 25              Office        google analytics       1219   0.06
# 26              Office                  pocket       1077   0.05
# 27              Office                   cisco        971   0.05
# 28              Office                   asana        876   0.04
# 29              Office              confluence        803   0.04
# 30              Office                    miro        376   0.02
# 31              Office                 nishtha          3   0.00
# 32              Gaming               ludo king     282812  13.54
# 33              Gaming               free fire          3   0.00
# 34  Finance_Investment     hdfc mobile banking     269715  12.91
# 35  Finance_Investment                   groww     118130   5.65
# 36  Finance_Investment         kite by zerodha      84274   4.03
# 37  Finance_Investment           angel broking      54733   2.62
# 38  Finance_Investment                     nps      22227   1.06
# 39  Finance_Investment           namma partner       2330   0.11
# 40         Educational                   udemy      60477   2.89
# 41         Educational        google classroom      58343   2.79
# 42         Educational                duolingo      53387   2.56
# 43         Educational                 brainly      46679   2.23
# 44         Educational                    byju      42040   2.01
# 45         Educational               unacademy      24847   1.19
# 46         Educational                coursera      15873   0.76
# 47         Educational                  swayam      12364   0.59
# 48         Educational          physics wallah      11720   0.56
# 49         Educational                doubtnut       8182   0.39
# 50         Educational                  diksha       7115   0.34
# 51         Educational             simplilearn       6336   0.30
# 52         Educational         geeks for geeks       4369   0.21
# 53         Educational                  moodle       3350   0.16
# 54         Educational                 vedantu       2968   0.14
# 55         Educational               goodreads       2770   0.13
# 56         Educational               photomath       2599   0.12
# 57         Educational                     edx       2500   0.12
# 58         Educational            khan academy       1808   0.09
# 59         Educational             ncert books       1615   0.08
# 60         Educational                  aakash       1402   0.07
# 61         Educational          e-pg pathshala       1149   0.05
# 62         Educational             chegg study       1142   0.05
# 63         Educational             whitehat jr       1128   0.05
# 64         Educational                  pocket       1077   0.05
# 65         Educational         ignou e-content        971   0.05
# 66         Educational                  embibe        957   0.05
# 67         Educational   microsoft math solver        889   0.04
# 68         Educational             mycbseguide        718   0.03
# 69         Educational             shiksha.com        413   0.02
# 70         Educational            colegeduniya        190   0.01
# 71         Educational             caclubindia        171   0.01
# 72         Educational             course hero        105   0.01
# 73         Educational                   toppr         87   0.00
# 74         Educational           my study life         85   0.00
# 75         Educational          stack overflow         43   0.00
# 76         Educational                 happify         38   0.00
# 77         Educational                vidyakul         33   0.00
# 78         Educational            collegedekho         17   0.00
# 79         Educational           shiksha mitra         12   0.00
# 80         Educational                 fiitjee         10   0.00
# 81          Driver_App          rapido captain     121160   5.80
# 82          Driver_App         uber driver app      60416   2.89
# 83          Driver_App          ola driver app      43810   2.10
# 84          Driver_App       swiggy driver app      28291   1.35
# 85          Driver_App       porter driver app      14681   0.70
# 86          Driver_App       zomato driver app      11448   0.55
# 87          Driver_App        zepto driver app       8863   0.42
# 88          Driver_App    shadowfax driver app       6119   0.29
# 89          Driver_App        dunzo driver app       1857   0.09
# 90          Driver_App        borzo driver app       1478   0.07

# %% [markdown]
# #### Transform Categories level-2

# %%
df_customer_mapped.head(1)
# Out:
#                 customer_id  \
# 0  5737c6d3ddbec2203f7332ba
#
#                                             app_list  app_count  \
# 0  [flipkart, twitter, google maps, facebook, ola...         22
#
#                                        categories_l1  categories_l1_count  \
# 0  [Delivery_Food, Office, Tools, OTT, Travel_Rid...                    8
#
#                  categories_l2  categories_l2_count
# 0  [Rest, Office, Ride haling]                    3

# %%
unique_categories = set(category for sublist in df_customer_mapped['categories_l1'] for category in sublist)
# print(unique_categories)

for category in unique_categories:
    df_customer_mapped[category] = df_customer_mapped['categories_l1']\
                                            .apply(lambda x: 1 if category in x else 0)
##When havnig nan last column
df_customer_mapped.drop(df_customer_mapped.columns[-1], axis=1, inplace=True)

# %%
df_customer_mapped
# Out:
#                       customer_id  \
# 0        5737c6d3ddbec2203f7332ba
# 1        573f28f39b0ffc283676efee
# 2        573f28f39b0ffc283676f013
# 3        573f28f39b0ffc283676f08f
# 4        573f28f39b0ffc283676f0a1
# ...                           ...
# 2089114  6609aa3ddb0e9c9b8b404bba
# 2089115  6609aa705a3971e793e3ae7e
# 2089116  6609aac5db0e9cf9fd405f1d
# 2089117  6609ab51a9381bcb0f3b3b50
# 2089118  6609ab59db0e9c191c40769c
#
#                                                   app_list  app_count  \
# 0        [flipkart, twitter, google maps, facebook, ola...         22
# 1        [flipkart, sonyliv, slack, google maps, micros...         53
# 2                                                    [nan]          0
# 3                                                    [nan]          0
# 4        [flipkart, wynk music, google maps, twitter, l...         43
# ...                                                    ...        ...
# 2089114  [youtube, google news, ludo king, flipkart, zo...         17
# 2089115                                              [nan]          0
# 2089116  [flipkart, google maps, hdfc mobile banking, g...         19
# 2089117  [flipkart, sonyliv, wynk music, google maps, f...         26
# 2089118                                              [nan]          0
#
#                                              categories_l1  \
# 0        [Delivery_Food, Office, Tools, OTT, Travel_Rid...
# 1        [Delivery_Food, Office, Health, Tools, Finance...
# 2                                                    [nan]
# 3                                                    [nan]
# 4        [Social, Delivery_Food, Office, Educational, T...
# ...                                                    ...
# 2089114  [Social, Delivery_Food, Office, Tools, Gaming,...
# 2089115                                              [nan]
# 2089116  [Office, Tools, Finance_Investment, OTT, Ecomm...
# 2089117  [Delivery_Food, Tools, Gaming, OTT, Entertainm...
# 2089118                                              [nan]
#
#          categories_l1_count  \
# 0                          8
# 1                         16
# 2                          0
# 3                          0
# 4                         13
# ...                      ...
# 2089114                    8
# 2089115                    0
# 2089116                    7
# 2089117                    9
# 2089118                    0
#
#                                              categories_l2  \
# 0                              [Rest, Office, Ride haling]
# 1          [Rest, Office, Finance_Investment, Ride haling]
# 2                                                    [nan]
# 3                                                    [nan]
# 4        [Educational, Office, Finance_Investment, Rest...
# ...                                                    ...
# 2089114                             [Rest, Gaming, Office]
# 2089115                                              [nan]
# 2089116                 [Rest, Office, Finance_Investment]
# 2089117                        [Rest, Gaming, Ride haling]
# 2089118                                              [nan]
#
#          categories_l2_count  Entertainment  Social  Travel_Bookings  Office  \
# 0                          3              0       1                0       1
# 1                          4              1       1                1       1
# 2                          0              0       0                0       0
# 3                          0              0       0                0       0
# 4                          5              1       1                0       1
# ...                      ...            ...     ...              ...     ...
# 2089114                    3              0       1                0       1
# 2089115                    0              0       0                0       0
# 2089116                    3              0       1                0       1
# 2089117                    3              1       1                0       0
# 2089118                    0              0       0                0       0
#
#          NaN  Educational  Tools  Gaming  Travel_Ridehailing  \
# 0          0            0      1       0                   1
# 1          0            0      1       0                   1
# 2          1            0      0       0                   0
# 3          1            0      0       0                   0
# 4          0            1      1       0                   1
# ...      ...          ...    ...     ...                 ...
# 2089114    0            0      1       1                   0
# 2089115    1            0      0       0                   0
# 2089116    0            0      1       0                   0
# 2089117    0            0      1       1                   1
# 2089118    1            0      0       0                   0
#
#          Delivery_Grocery  Devotional  Fantasy_Sports  Ecommerce  \
# 0                       0           0               0          1
# 1                       1           0               0          1
# 2                       0           0               0          0
# 3                       0           0               0          0
# 4                       0           0               0          1
# ...                   ...         ...             ...        ...
# 2089114                 0           0               0          1
# 2089115                 0           0               0          0
# 2089116                 0           0               0          1
# 2089117                 0           0               0          1
# 2089118                 0           0               0          0
#
#          Finance_Transactions  Streaming_Music  Dating  Finance_Investment  \
# 0                           0                1       0                   0
# 1                           1                1       0                   1
# 2                           0                0       0                   0
# 3                           0                0       0                   0
# 4                           1                1       0                   1
# ...                       ...              ...     ...                 ...
# 2089114                     0                1       0                   0
# 2089115                     0                0       0                   0
# 2089116                     1                0       0                   1
# 2089117                     0                1       0                   0
# 2089118                     0                0       0                   0
#
#          Finance_News  News  Driver_App  Delivery_Food  Health  OTT
# 0                   0     0           0              1       0    1
# 1                   1     0           0              1       1    1
# 2                   0     0           0              0       0    0
# 3                   0     0           0              0       0    0
# 4                   0     0           0              1       0    1
# ...               ...   ...         ...            ...     ...  ...
# 2089114             0     1           0              1       0    0
# 2089115             0     0           0              0       0    0
# 2089116             0     0           0              0       0    1
# 2089117             0     0           0              1       0    1
# 2089118             0     0           0              0       0    0
#
# [2089119 rows x 30 columns]

# %%
df_customer_mapped.head(5).T
# Out:
#                                                                       0  \
# customer_id                                    5737c6d3ddbec2203f7332ba
# app_list              [flipkart, twitter, google maps, facebook, ola...
# app_count                                                            22
# categories_l1         [Delivery_Food, Office, Tools, OTT, Travel_Rid...
# categories_l1_count                                                   8
# categories_l2                               [Rest, Office, Ride haling]
# categories_l2_count                                                   3
# Entertainment                                                         0
# Social                                                                1
# Travel_Bookings                                                       0
# Office                                                                1
# NaN                                                                   0
# Educational                                                           0
# Tools                                                                 1
# Gaming                                                                0
# Travel_Ridehailing                                                    1
# Delivery_Grocery                                                      0
# Devotional                                                            0
# Fantasy_Sports                                                        0
# Ecommerce                                                             1
# Finance_Transactions                                                  0
# Streaming_Music                                                       1
# Dating                                                                0
# Finance_Investment                                                    0
# Finance_News                                                          0
# News                                                                  0
# Driver_App                                                            0
# Delivery_Food                                                         1
# Health                                                                0
# OTT                                                                   1
#
#                                                                       1  \
# customer_id                                    573f28f39b0ffc283676efee
# app_list              [flipkart, sonyliv, slack, google maps, micros...
# app_count                                                            53
# categories_l1         [Delivery_Food, Office, Health, Tools, Finance...
# categories_l1_count                                                  16
# categories_l2           [Rest, Office, Finance_Investment, Ride haling]
# categories_l2_count                                                   4
# Entertainment                                                         1
# Social                                                                1
# Travel_Bookings                                                       1
# Office                                                                1
# NaN                                                                   0
# Educational                                                           0
# Tools                                                                 1
# Gaming                                                                0
# Travel_Ridehailing                                                    1
# Delivery_Grocery                                                      1
# Devotional                                                            0
# Fantasy_Sports                                                        0
# Ecommerce                                                             1
# Finance_Transactions                                                  1
# Streaming_Music                                                       1
# Dating                                                                0
# Finance_Investment                                                    1
# Finance_News                                                          1
# News                                                                  0
# Driver_App                                                            0
# Delivery_Food                                                         1
# Health                                                                1
# OTT                                                                   1
#
#                                              2                         3  \
# customer_id           573f28f39b0ffc283676f013  573f28f39b0ffc283676f08f
# app_list                                 [nan]                     [nan]
# app_count                                    0                         0
# categories_l1                            [nan]                     [nan]
# categories_l1_count                          0                         0
# categories_l2                            [nan]                     [nan]
# categories_l2_count                          0                         0
# Entertainment                                0                         0
# Social                                       0                         0
# Travel_Bookings                              0                         0
# Office                                       0                         0
# NaN                                          1                         1
# Educational                                  0                         0
# Tools                                        0                         0
# Gaming                                       0                         0
# Travel_Ridehailing                           0                         0
# Delivery_Grocery                             0                         0
# Devotional                                   0                         0
# Fantasy_Sports                               0                         0
# Ecommerce                                    0                         0
# Finance_Transactions                         0                         0
# Streaming_Music                              0                         0
# Dating                                       0                         0
# Finance_Investment                           0                         0
# Finance_News                                 0                         0
# News                                         0                         0
# Driver_App                                   0                         0
# Delivery_Food                                0                         0
# Health                                       0                         0
# OTT                                          0                         0
#
#                                                                       4
# customer_id                                    573f28f39b0ffc283676f0a1
# app_list              [flipkart, wynk music, google maps, twitter, l...
# app_count                                                            43
# categories_l1         [Social, Delivery_Food, Office, Educational, T...
# categories_l1_count                                                  13
# categories_l2         [Educational, Office, Finance_Investment, Rest...
# categories_l2_count                                                   5
# Entertainment                                                         1
# Social                                                                1
# Travel_Bookings                                                       0
# Office                                                                1
# NaN                                                                   0
# Educational                                                           1
# Tools                                                                 1
# Gaming                                                                0
# Travel_Ridehailing                                                    1
# Delivery_Grocery                                                      0
# Devotional                                                            0
# Fantasy_Sports                                                        0
# Ecommerce                                                             1
# Finance_Transactions                                                  1
# Streaming_Music                                                       1
# Dating                                                                0
# Finance_Investment                                                    1
# Finance_News                                                          0
# News                                                                  0
# Driver_App                                                            0
# Delivery_Food                                                         1
# Health                                                                0
# OTT                                                                   1
