# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ### Imports & Connection
# </div>

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
import datetime as datetime
import plotly.graph_objects as go

from scipy import stats
from pyhive import presto
from IPython.display import display
from datetime import datetime, timedelta
# from scipy.stats import gaussian_kde

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 100)

# %%
## Connection
connection = presto.connect(
        host='presto-gateway.serving.data.production.internal',
        port=80,
        protocol='http',
        catalog='hive',
        username='manoj.ravirajan@rapido.bike'
)

# %%
print('Notebook dir - ', os.getcwd())
local_extract = '/Users/E2074/local-datasets/customer/ads-monetisation/monet-benchmark'
print('Data dir - ', local_extract)
# Out:
# Notebook dir -  /Users/E2074/analytics/customer/Ads-Monetisation/monet-benchmark
# Data dir -  /Users/E2074/local-datasets/customer/ads-monetisation/monet-benchmark

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## Datasets & Parameter
# </div>

# %%
## Parameter 
start_date = '20241104'
end_date = '20241104'

# %%
def func_ad_response(date,segment_date):
    
    
    base_query = f"""


    with response AS (
        
            SELECT
                res.yyyymmdd as yyyymmdd,
                res.city as city,
                res.os as os,
                res.responsetype as responsetype,  
                res.userid as userid,
                res.slotname as slotname, 
                res.format as format, 
                res.responsestatus as responsestatus,
                res.isprefetched as isprefetched,
                coalesce(res.aduuid, res.adid) as response_id,
                REPLACE(REGEXP_EXTRACT(metadata1, 'title=([^,]*)'), 'title=', '') AS title,
                REPLACE(REGEXP_EXTRACT(metadata1, 'advertiserName=([^,]*)'), 'advertiserName=', '') AS advertiserName,
                REPLACE(REGEXP_EXTRACT(metadata1, 'body=([^,]*)'), 'body=', '') AS body
            FROM 
                canonical.iceberg_log_telemetry_ads_impressions_immutable res
            WHERE 
                res.yyyymmdd = '{date}'
                AND res.eventName = 'Ad_Response'
                AND NOT regexp_like(res.format, 'Arrived|OTW|Started|nativeBanner')
                AND res.responsetype IN ('GAMBanner', 'ONLINE_SALES', 'System Banner')
                AND (res.responsestatus = 'true' OR res.responsestatus IS NULL)

                -- AND quarter_hour = '1115'
        ),

        segment as (

        SELECT
            customer_id,
            taxi_ltr_segment,
            taxi_retention_segments taxi_retention_segment,
            taxi_regularity_segment taxi_rr_regularity_segment,
            taxi_intent_segment taxi_rr_intent_segment,
            taxi_fe_regularity_segment,
            taxi_fe_intent_segment
        FROM 
            datasets.iallocator_customer_segments
        WHERE 
            run_date = '{segment_date}'
        )
        
        SELECT
            response.yyyymmdd as yyyymmdd,
            response.city as city,
            response.os as os,
            response.responsetype as responsetype,  
            response.userid as userid,
            response.slotname as slotname, 
            response.format as format, 
            response.responsestatus as responsestatus,
            response.isprefetched as isprefetched,
            
            taxi_ltr_segment,
            taxi_retention_segment,
            taxi_rr_regularity_segment,
            taxi_rr_intent_segment,
            taxi_fe_regularity_segment,
            taxi_fe_intent_segment,

            response_id,
            
            title,
            advertiserName,
            body
            
        FROM    
            response
        LEFT JOIN 
            segment as segment
            ON response.userid = segment.customer_id

    """
    
    df_base = pd.read_sql(base_query, connection)

    return df_base

# %%
def func_ad_impression(date):
    
    
    base_query = f"""
    
        SELECT
            DISTINCT
            coalesce(imp.aduuid, imp.adid) as impression_id,
            imp.userid as userid,
            imp.yyyymmdd as yyyymmdd
        FROM 
            canonical.iceberg_log_telemetry_ads_impressions_immutable as imp
        WHERE 
            imp.yyyymmdd = '{date}'
            AND imp.eventName = 'Ad_Impression'
            
            -- AND quarter_hour = '1115'

    """
    
    df_base = pd.read_sql(base_query, connection)

    return df_base

# %%
def func_ad_viewable_impression(date):
    
    
    base_query = f"""
    
        SELECT
            DISTINCT
            coalesce(view_imp.aduuid, view_imp.adid) as viewable_impression_id,
            view_imp.userid as userid,
            view_imp.yyyymmdd as yyyymmdd
        FROM 
            canonical.iceberg_log_telemetry_ads_impressions_immutable view_imp
        WHERE 
            view_imp.yyyymmdd = '{date}'
            AND view_imp.eventName = 'Ad_Viewable_Impression'
            
            -- AND quarter_hour = '1115'

    """
    
    df_base = pd.read_sql(base_query, connection)

    return df_base

# %%
def func_ad_click(date):
    
    
    base_query = f"""

            
        SELECT
            DISTINCT
            coalesce(clk.aduuid, clk.adid) as click_id,
            clk.userid as userid,
            clk.yyyymmdd as yyyymmdd
        FROM 
            canonical.iceberg_log_telemetry_ads_impressions_immutable as clk
        WHERE 
            clk.yyyymmdd = '{date}'
            AND clk.eventName = 'Ad_Click'
            
            -- AND quarter_hour = '1115'

    """
    
    df_base = pd.read_sql(base_query, connection)

    return df_base

# %%
def func_pull_ads_data(start_date, end_date):
    
    date_list = pd.date_range(start=start_date, end=end_date).strftime('%Y%m%d').tolist()
    formatted_end_date = datetime.strptime(end_date, '%Y%m%d').strftime('%Y-%m-%d')
    
    for date in date_list:
        
        df_response_data_dump = func_ad_response(date, formatted_end_date)
        # display(df_response_data_dump.head(5))
        
        df_impression_data_dump = func_ad_impression(date)
        # display(df_impression_data_dump.head(5))
        
        df_viewable_impression_data_dump = func_ad_viewable_impression(date)
        # display(df_viewable_impression_data_dump.head(5))
        
        df_click_data_dump = func_ad_click(date)
        # display(df_click_data_dump.head(5))
        
        merge1 = pd.merge(df_response_data_dump, df_impression_data_dump, 
                          how='left', 
                          left_on=['yyyymmdd', 'userid', 'response_id'],
                          right_on=['yyyymmdd', 'userid', 'impression_id'])
        merge2 = pd.merge(merge1, df_viewable_impression_data_dump, 
                          how='left', 
                          left_on=['yyyymmdd', 'userid', 'impression_id'],
                          right_on=['yyyymmdd', 'userid', 'viewable_impression_id'])
        merge3 = pd.merge(merge2, df_click_data_dump, 
                          how='left', 
                          left_on=['yyyymmdd', 'userid', 'response_id'],
                          right_on=['yyyymmdd', 'userid', 'click_id'])
        merge3.to_parquet(local_extract + '/data_dump/{}_data.parquet'.format(date), index=False)

    folder_path = local_extract + '/data_dump'
    parquet_files = [os.path.join(folder_path, file) for file in os.listdir(folder_path) if file.endswith('.parquet')]
    df = pd.concat([pd.read_parquet(file) for file in parquet_files], ignore_index=True)
    
    return df

# %%
def func_percentage(df, numerator, denominator):
    df['ctr'] = (df[numerator]*100.00/df[denominator]).round(2)
    return df

# %%
df = func_pull_ads_data(start_date, end_date)

# %%
df

# %%
df_merge
# Out:
#         yyyymmdd       city       os   responsetype                    userid  \
# 0       20241104  Hyderabad  android      GAMBanner  5bf7a526647b2949efed5dde
# 1       20241104    Chennai  android      GAMBanner  635ba81785b399c6745338e7
# 2       20241104    Madurai  android  System Banner  629cb57a1b57e48b7be81a8e
# 3       20241104  Hyderabad  android      GAMBanner  638b4409d1162513e22529db
# 4       20241104  Hyderabad  android      GAMBanner  638b4409d1162513e22529db
# ...          ...        ...      ...            ...                       ...
# 140577  20241104     Jaipur  android      GAMBanner  6682bd3191ae397ce7b57d94
# 140578  20241104   Warangal  android      GAMBanner  6507166192c3a879f59c432b
# 140579  20241104   Warangal  android      GAMBanner  6507166192c3a879f59c432b
# 140580  20241104  Hyderabad  android      GAMBanner  6402279d8e212cf5464d3338
# 140581  20241104    Chennai  android      GAMBanner  61a9a60ff3de6f822e410b03
#
#                  slotname             format responsestatus isprefetched  \
# 0       PostOrderStarted1  gamCombinedBanner           None         None
# 1       PostOrderStarted3  gamCombinedBanner           None         None
# 2       PostOrderStarted4            Rewards           None         None
# 3       PostOrderStarted3  gamCombinedBanner           true        false
# 4       PostOrderStarted2  gamCombinedBanner           true        false
# ...                   ...                ...            ...          ...
# 140577     CaptainSearch1  gamCombinedBanner           true        false
# 140578  PostOrderStarted3  gamCombinedBanner           true        false
# 140579  PostOrderStarted1  gamCombinedBanner           true        false
# 140580  PostOrderStarted3  gamCombinedBanner           true        false
# 140581  PostOrderStarted3  gamCombinedBanner           None         None
#
#        taxi_ltr_segment taxi_retention_segment taxi_rr_regularity_segment  \
# 0                   PHH               PLATINUM                     WEEKLY
# 1                   PHH                   GOLD                  BI_WEEKLY
# 2                   PHH                   GOLD                  BI_WEEKLY
# 3                   PHH               PLATINUM                  BI_WEEKLY
# 4                   PHH               PLATINUM                  BI_WEEKLY
# ...                 ...                    ...                        ...
# 140577          UNKNOWN                UNKNOWN                    UNKNOWN
# 140578              PHH                  ELITE                      DAILY
# 140579              PHH                  ELITE                      DAILY
# 140580              PHH                 SILVER                    MONTHLY
# 140581              PHH                   GOLD                  BI_WEEKLY
#
#        taxi_rr_intent_segment taxi_fe_regularity_segment  \
# 0                      MEDIUM                  BI_WEEKLY
# 1                         LOW                  BI_WEEKLY
# 2                         LOW                    MONTHLY
# 3                      MEDIUM                  BI_WEEKLY
# 4                      MEDIUM                  BI_WEEKLY
# ...                       ...                        ...
# 140577                UNKNOWN                    UNKNOWN
# 140578                   HIGH                      DAILY
# 140579                   HIGH                      DAILY
# 140580                    LOW                    UNKNOWN
# 140581                    LOW                    MONTHLY
#
#        taxi_fe_intent_segment  \
# 0                         LOW
# 1                      MEDIUM
# 2                         LOW
# 3                         LOW
# 4                         LOW
# ...                       ...
# 140577                UNKNOWN
# 140578                   HIGH
# 140579                   HIGH
# 140580                UNKNOWN
# 140581                 MEDIUM
#
#                                               response_id title  \
# 0               ad_5bf7a526647b2949efed5dde_1730688557024  None
# 1               ad_635ba81785b399c6745338e7_1730699397815  None
# 2               ad_629cb57a1b57e48b7be81a8e_1730698942761  None
# 3       b69c5814-6748-490d-9c1f-9c1a8ed358eb638b4409d1...  None
# 4       10b46b16-bf50-4902-8a86-3fb4783fb244638b4409d1...  None
# ...                                                   ...   ...
# 140577  b91db866-06fe-46d9-83d0-8e350fb85caf6682bd3191...  None
# 140578  6fdf435a-60e9-4ffb-a2cb-46d06aaa6c306507166192...  None
# 140579  54546ff2-44da-4afe-a085-70c4599b1b8f6507166192...  None
# 140580  4db694ef-3f15-400c-bee3-4d16ec224b286402279d8e...  None
# 140581          ad_61a9a60ff3de6f822e410b03_1730699473027  None
#
#        advertiserName  body                              impression_id  \
# 0                None  None  ad_5bf7a526647b2949efed5dde_1730688557024
# 1                None  None                                        NaN
# 2                None  None  ad_629cb57a1b57e48b7be81a8e_1730698942761
# 3                None  None                                        NaN
# 4                None  None                                        NaN
# ...               ...   ...                                        ...
# 140577           None  None                                        NaN
# 140578           None  None                                        NaN
# 140579           None  None                                        NaN
# 140580           None  None                                        NaN
# 140581           None  None  ad_61a9a60ff3de6f822e410b03_1730699473027
#
#                            viewable_impression_id click_id
# 0       ad_5bf7a526647b2949efed5dde_1730688557024      NaN
# 1                                             NaN      NaN
# 2       ad_629cb57a1b57e48b7be81a8e_1730698942761      NaN
# 3                                             NaN      NaN
# 4                                             NaN      NaN
# ...                                           ...      ...
# 140577                                        NaN      NaN
# 140578                                        NaN      NaN
# 140579                                        NaN      NaN
# 140580                                        NaN      NaN
# 140581  ad_61a9a60ff3de6f822e410b03_1730699473027      NaN
#
# [140582 rows x 22 columns]

# %%
df_overall = df_merge\
.groupby(['yyyymmdd','os', 'responsetype'])\
.agg(
    response = ('response_id', 'nunique'),
    impression = ('impression_id', 'nunique'),
    viewable_impression = ('viewable_impression_id', 'nunique'),
    click = ('click_id', 'nunique')
)\
.reset_index()

func_percentage(df_overall, 'click', 'viewable_impression')
df_overall
# Out:
#    yyyymmdd       os   responsetype  response  impression  \
# 0  20241104  android      GAMBanner     79054       13806
# 1  20241104  android   ONLINE_SALES      4493        4036
# 2  20241104  android  System Banner     44897       38992
# 3  20241104      iOS   ONLINE_SALES       888         602
#
#    viewable_impression  click   ctr
# 0                11292     76  0.67
# 1                 1806     12  0.66
# 2                20485     66  0.32
# 3                  130      9  6.92
