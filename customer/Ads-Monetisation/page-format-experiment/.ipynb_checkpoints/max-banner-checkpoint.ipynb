# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## Import & Connections
# </div>

# %%
import numpy as np
import pandas as pd
import hashlib
import glob
import time
import os
import re
import matplotlib.pyplot as plt

from scipy import stats
from pyhive import presto
from datetime import datetime, timedelta

import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 50)

# %%
connection = presto.connect(
        host='presto-gateway.serving.data.production.internal',
        port=80,
        protocol='http',
        catalog='hive',
        username='manoj.ravirajan@rapido.bike'
)

# %%
start_date = '20250130'
end_date = '20250205'
response_type = 'ONLINE_SALES'
pagename = 'PostOrderScreen'
campaign_name = 'Exp3_MaxBanner_Zepto'
format = 'maxBanner'

# %%
print(os.getcwd())
local_dataset = '/Users/E2074/local-datasets/customer/ads-monetisation/page-format-experiment/max-banner'
print(local_dataset)
# Out:
# /Users/E2074/analytics/customer/Ads-Monetisation/page-format-experiment
# /Users/E2074/local-datasets/customer/ads-monetisation/page-format-experiment/max-banner

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ## Datasets & Functions
# </div>

# %%
start = datetime.strptime(start_date, '%Y%m%d')
end = datetime.strptime(end_date, '%Y%m%d')

# Generate the list of dates
date_range = [(start + timedelta(days=i)).strftime('%Y%m%d') for i in range((end - start).days + 1)]
print(date_range)
# Out:
# ['20250130', '20250131', '20250201', '20250202', '20250203', '20250204', '20250205']

# %%
def get_customer_metadata(date_range):

    all_df = []
    
    for date in date_range:
    
        customer_metadata = f"""
        
            with response as (
            
            select
                distinct
                yyyymmdd,
                json_extract_scalar(metadata1, '$.campaignName') AS campaignName,
                json_extract_scalar(metadata1, '$.slotUnitId') AS slotUnitId,
                city,
                os,
                userid,
                service,
                orderstatus,
                -- totalcardcount,
                -- cardposition,
                coalesce(aduuid, adid) response_id
            from 
                canonical.iceberg_log_telemetry_ads_impressions_immutable
            where 
                yyyymmdd = '{date}'
                and os = 'android'
                and responsetype = '{response_type}'
                and eventname = 'Ad_Response'
                and pagename = '{pagename}'
                and format = '{format}'
                and regexp_like(metadata1, '{campaign_name}')
            ),
            
            impression as (
            
            select
                distinct
                yyyymmdd,
                userid,
                coalesce(aduuid, adid) impression_id
            from 
                canonical.iceberg_log_telemetry_ads_impressions_immutable
            where 
                yyyymmdd = '{date}'
                and os = 'android'
                and responsetype = '{response_type}'
                and eventname = 'Ad_Impression'
                and pagename = '{pagename}'
                and format = '{format}'
                and regexp_like(metadata1, '{campaign_name}')
            ),
            
            viewable_impression as (
            
            select
                distinct
                yyyymmdd,
                userid,
                coalesce(aduuid, adid) viewable_impression_id
            from 
                canonical.iceberg_log_telemetry_ads_impressions_immutable
            where 
                yyyymmdd = '{date}'
                and os = 'android'
                and responsetype = '{response_type}'
                and eventname = 'Ad_Viewable_Impression'
                and pagename = '{pagename}'
                and format = '{format}'
                and regexp_like(metadata1, '{campaign_name}')
            ),
            
            click as (
            
            select
                distinct
                yyyymmdd,
                userid,
                coalesce(aduuid, adid) click_id
            from 
                canonical.iceberg_log_telemetry_ads_impressions_immutable
            where 
                yyyymmdd = '{date}'
                and os = 'android'
                and responsetype = '{response_type}'
                and eventname = 'Ad_Click'
                and pagename = '{pagename}'
                and format = '{format}'
            )
            
            select
                a.*,
                impression_id,
                coalesce(click_id, viewable_impression_id) viewable_impression_id,
                click_id
            from 
                response a
            left join 
                impression b
                on a.yyyymmdd = b.yyyymmdd
                and a.userid = b.userid
                and a.response_id = b.impression_id
            left join 
                viewable_impression c
                on b.yyyymmdd = c.yyyymmdd
                and b.userid = c.userid
                and b.impression_id = c.viewable_impression_id
            left join 
                click d
                on b.yyyymmdd = d.yyyymmdd
                and b.userid = d.userid
                and b.impression_id = d.click_id
        """
        
        df = pd.read_sql(customer_metadata, connection)
        all_df.append(df)
        df.to_parquet(local_dataset + '/data_dump/{}_{}.parquet'.format(campaign_name, date), index=False)
    
    # Concatenate all DataFrames
    final_df = pd.concat(all_df, ignore_index=True)

    return final_df


# df_data = get_customer_metadata(date_range)

# %%
def get_customer_segment():    
    
    customer_segment = f"""
    
        with response as (

            select
                distinct
                userid
            from 
                canonical.iceberg_log_telemetry_ads_impressions_immutable
            where 
                yyyymmdd >= '{start_date}'
                and yyyymmdd <= '{end_date}'
                and os = 'android'
                and responsetype = '{response_type}'
                and eventname = 'Ad_Response'
                and pagename = '{pagename}'
                and format = '{format}'
                and regexp_like(metadata1, '{campaign_name}')
            ),

            segment as (
    
            select
                customer_id,
                gender_tag,
                taxi_ltr_segment,
                taxi_retention_segments,
                taxi_regularity_segment,
                taxi_fe_regularity_segment,
                taxi_income_segment,
                taxi_service_affinity,
                taxi_gc_tag
            from 
                datasets.iallocator_customer_segments
            where 
                run_date = '2025-01-29'
            )
            
            select
                userid,
                coalesce(gender_tag, 'UNKNOWN') gender,
                coalesce(taxi_ltr_segment, 'NEW') ltr_segment,
                coalesce(taxi_retention_segments, 'UNKNOWN') retention_segments,
                coalesce(taxi_regularity_segment, 'UNKNOWN') regularity_segment,
                coalesce(taxi_fe_regularity_segment, 'UNKNOWN') fe_regularity_segment,
                coalesce(taxi_income_segment, 'UNKNOWN') income_segment,
                coalesce(taxi_service_affinity, 'UNKNOWN') service_affinity,
                coalesce(taxi_gc_tag, 'UNKNOWN') gc_tag
            from 
                response
            left join 
                segment
                on userid = customer_id
            
    """
    
    df = pd.read_sql(customer_segment, connection)
    df.to_parquet(local_dataset + '/Exp3_customer_segment.parquet', index=False)

    return df

# df_data = get_customer_segment()

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# ## Load data
# </div>

# %%
def get_customer_metadata(prefix):
    
    parquet_files = glob.glob(os.path.join(local_dataset + '/data_dump/', f'{prefix}*.parquet'))
    
    customer_metadata = pd.concat([pd.read_parquet(file) for file in parquet_files], ignore_index=True)
    customer_segment = pd.read_parquet(local_dataset + f'/{prefix}_customer_segment.parquet')
    
    df = pd.merge(customer_metadata, customer_segment, how='left', on = 'userid')
    return df

# %%
df_exp1 = get_customer_metadata('Exp1')
df_exp2 = get_customer_metadata('Exp2')
df_exp3 = get_customer_metadata('Exp3')

# %%
df_exp1['Experiment'] = 'Experiment-1'
df_exp2['Experiment'] = 'Experiment-2'
df_exp3['Experiment'] = 'Experiment-3'

# %%
frames = [df_exp1, df_exp2, df_exp3]
df_data = pd.concat(frames)

# %%
df_data.head(2)
# Out:
#    yyyymmdd          campaignName          slotUnitId       city       os  \
# 0  20250115  Exp1_MaxBanner_Zepto   PostOrderArrived3  Bangalore  android
# 1  20250115  Exp1_MaxBanner_Zepto  PostOrderOnTheWay3  Bangalore  android
#
#                      userid service orderstatus  \
# 0  5e5f1abf32e3140a0beaf16d    Auto     arrived
# 1  676c0d81a353a7da26899fd1    Auto    onTheWay
#
#                                          response_id  \
# 0  b57dbc1c-b86e-4519-a460-30a5478d9cd65e5f1abf32...
# 1  b8e7c852-d0f3-488f-af24-f3f415854597676c0d81a3...
#
#                                        impression_id  \
# 0  b57dbc1c-b86e-4519-a460-30a5478d9cd65e5f1abf32...
# 1  b8e7c852-d0f3-488f-af24-f3f415854597676c0d81a3...
#
#                               viewable_impression_id click_id  gender  \
# 0  b57dbc1c-b86e-4519-a460-30a5478d9cd65e5f1abf32...     None  FEMALE
# 1                                               None     None    MALE
#
#   ltr_segment retention_segments regularity_segment fe_regularity_segment  \
# 0         PHH           PLATINUM              DAILY                 DAILY
# 1         PHH               GOLD          BI_WEEKLY               MONTHLY
#
#   income_segment service_affinity   gc_tag    Experiment
# 0  MEDIUM_INCOME        ONLY_AUTO  UNKNOWN  Experiment-1
# 1        UNKNOWN        ONLY_LINK  UNKNOWN  Experiment-1

# %%
df_data['yyyymmdd'].value_counts().sort_index(ascending=True)
# Out:
# yyyymmdd
# 20250115    219413
# 20250116    232757
# 20250117    252570
# 20250118         9
# 20250119        29
# 20250120    278302
# 20250121    281593
# 20250122    288297
# 20250123    263244
# 20250124    269672
# 20250125    257098
# 20250126    261591
# 20250127    267431
# 20250128    275983
# 20250129    278864
# 20250130    289245
# 20250131    291791
# 20250201    270462
# 20250202    274591
# 20250203    285253
# 20250204    292258
# 20250205    302847
# Name: count, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# ## Funnel Func
# </div>

# %%
def get_funnel(df, groupby):

    df_temp = df\
                .groupby(groupby)\
                .agg(responses = ('response_id', 'nunique'),
                     impression = ('impression_id', 'nunique'),
                     viewable_impression = ('viewable_impression_id', 'nunique'),
                     click = ('click_id', 'nunique'),
                    )\
                .reset_index()

    df_temp['% render rate'] = (df_temp['impression']*100.00/df_temp['responses']).round(2)
    df_temp['% view'] = (df_temp['viewable_impression']*100.00/df_temp['impression']).round(2)
    df_temp['% ctr'] = (df_temp['click']*100.00/df_temp['viewable_impression']).round(2)

    df_temp['format'] = format
    
    columns = ['format'] + groupby + ['responses', 'impression', 'viewable_impression', 'click', '% render rate', '% view', '% ctr']
    
    return df_temp[columns].sort_values(by=['Experiment', '% ctr'], ascending=[True, False])

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ## Analysis
# </div>

# %%
df_data.head(5)
# Out:
#    yyyymmdd          campaignName          slotUnitId       city       os  \
# 0  20250115  Exp1_MaxBanner_Zepto   PostOrderArrived3  Bangalore  android
# 1  20250115  Exp1_MaxBanner_Zepto  PostOrderOnTheWay3  Bangalore  android
# 2  20250115  Exp1_MaxBanner_Zepto  PostOrderOnTheWay3    Kolkata  android
# 3  20250115  Exp1_MaxBanner_Zepto   PostOrderArrived3      Delhi  android
# 4  20250115  Exp1_MaxBanner_Zepto  PostOrderOnTheWay3    Chennai  android
#
#                      userid    service orderstatus  \
# 0  5e5f1abf32e3140a0beaf16d       Auto     arrived
# 1  676c0d81a353a7da26899fd1       Auto    onTheWay
# 2  5d0a2fae1c64cc470f63ece1       Link    onTheWay
# 3  656adcfd044b093882cd1ff5  Bike Lite     arrived
# 4  6439178ecc7cb24c047ba197       Auto    onTheWay
#
#                                          response_id  \
# 0  b57dbc1c-b86e-4519-a460-30a5478d9cd65e5f1abf32...
# 1  b8e7c852-d0f3-488f-af24-f3f415854597676c0d81a3...
# 2  b07442b2-3166-4233-b884-90f6803d1bfd5d0a2fae1c...
# 3  849da0b9-fd51-4047-9d7d-6fcd709b820e656adcfd04...
# 4  a516d02e-d1f5-40e5-b957-a2e7251be96c6439178ecc...
#
#                                        impression_id  \
# 0  b57dbc1c-b86e-4519-a460-30a5478d9cd65e5f1abf32...
# 1  b8e7c852-d0f3-488f-af24-f3f415854597676c0d81a3...
# 2  b07442b2-3166-4233-b884-90f6803d1bfd5d0a2fae1c...
# 3  849da0b9-fd51-4047-9d7d-6fcd709b820e656adcfd04...
# 4  a516d02e-d1f5-40e5-b957-a2e7251be96c6439178ecc...
#
#                               viewable_impression_id click_id  gender  \
# 0  b57dbc1c-b86e-4519-a460-30a5478d9cd65e5f1abf32...     None  FEMALE
# 1                                               None     None    MALE
# 2  b07442b2-3166-4233-b884-90f6803d1bfd5d0a2fae1c...     None    MALE
# 3  849da0b9-fd51-4047-9d7d-6fcd709b820e656adcfd04...     None  FEMALE
# 4  a516d02e-d1f5-40e5-b957-a2e7251be96c6439178ecc...     None  FEMALE
#
#   ltr_segment retention_segments regularity_segment fe_regularity_segment  \
# 0         PHH           PLATINUM              DAILY                 DAILY
# 1         PHH               GOLD          BI_WEEKLY               MONTHLY
# 2         PHH              PRIME              DAILY                 DAILY
# 3         PHH              ELITE              DAILY                 DAILY
# 4         PHH               GOLD          BI_WEEKLY               MONTHLY
#
#   income_segment service_affinity   gc_tag    Experiment
# 0  MEDIUM_INCOME        ONLY_AUTO  UNKNOWN  Experiment-1
# 1        UNKNOWN        ONLY_LINK  UNKNOWN  Experiment-1
# 2  MEDIUM_INCOME        ONLY_LINK   NON_GC  Experiment-1
# 3  MEDIUM_INCOME        ONLY_LINK  UNKNOWN  Experiment-1
# 4     LOW_INCOME          UNKNOWN  UNKNOWN  Experiment-1

# %% [markdown]
# #### Bivariate data

# %%
get_funnel(df_data, ['Experiment', 'os']).pivot(index = ['Experiment'] , 
                                                columns = ['os'] , 
                                                values =['% render rate', '% view',	'% ctr', 'impression', 'viewable_impression', 'click'])
# Out:
#              % render rate  % view   % ctr impression viewable_impression  \
# os                 android android android    android             android
# Experiment
# Experiment-1         75.79   76.89    0.25  1176952.0            905003.0
# Experiment-2         79.59   75.15    0.03  1491501.0           1120818.0
# Experiment-3         81.63   76.74    0.58  1637780.0           1256800.0
#
#                click
# os           android
# Experiment
# Experiment-1  2250.0
# Experiment-2   375.0
# Experiment-3  7297.0

# %%
display(get_funnel(df_data, ['Experiment', 'yyyymmdd']))
# Out:
#        format    Experiment  yyyymmdd  responses  % render rate  % view  % ctr
# 4   maxBanner  Experiment-1  20250119         29          96.55   82.14   4.35
# 5   maxBanner  Experiment-1  20250120     278302          84.01   83.41   0.75
# 0   maxBanner  Experiment-1  20250115     219413          81.52   79.73   0.17
# 6   maxBanner  Experiment-1  20250121     281593          72.69   74.86   0.10
# 7   maxBanner  Experiment-1  20250122     288297          72.64   75.25   0.10
# 2   maxBanner  Experiment-1  20250117     252570          72.17   73.32   0.09
# 1   maxBanner  Experiment-1  20250116     232757          72.12   73.21   0.08
# 3   maxBanner  Experiment-1  20250118          9         100.00   88.89   0.00
# 8   maxBanner  Experiment-2  20250123     263244          79.49   74.95   0.04
# 14  maxBanner  Experiment-2  20250129     278864          80.75   76.56   0.04
# 9   maxBanner  Experiment-2  20250124     269672          79.59   75.41   0.03
# 10  maxBanner  Experiment-2  20250125     257098          78.90   74.25   0.03
# 11  maxBanner  Experiment-2  20250126     261591          79.18   73.60   0.03
# 12  maxBanner  Experiment-2  20250127     267431          78.98   74.92   0.03
# 13  maxBanner  Experiment-2  20250128     275983          80.16   76.13   0.03
# 21  maxBanner  Experiment-3  20250205     302847          83.57   82.19   0.91
# 18  maxBanner  Experiment-3  20250202     274591          81.22   74.82   0.55
# 17  maxBanner  Experiment-3  20250201     270462          80.24   74.81   0.53
# 16  maxBanner  Experiment-3  20250131     291791          81.74   76.46   0.51
# 19  maxBanner  Experiment-3  20250203     285253          81.12   75.28   0.51
# 15  maxBanner  Experiment-3  20250130     289245          81.88   77.29   0.50
# 20  maxBanner  Experiment-3  20250204     292258          81.42   75.65   0.49

# %%
display(get_funnel(df_data, ['Experiment', 'slotUnitId']))
# Out:
#       format    Experiment          slotUnitId  responses  impression  \
# 2  maxBanner  Experiment-1   PostOrderStarted3     388903      308473
# 1  maxBanner  Experiment-1  PostOrderOnTheWay3     799900      579343
# 0  maxBanner  Experiment-1   PostOrderArrived3     364167      289136
# 5  maxBanner  Experiment-2   PostOrderStarted4     456807      360236
# 4  maxBanner  Experiment-2  PostOrderOnTheWay4     977185      785984
# 3  maxBanner  Experiment-2   PostOrderArrived4     439891      345281
# 8  maxBanner  Experiment-3   PostOrderStarted1     492692      397748
# 6  maxBanner  Experiment-3   PostOrderArrived1     455180      362680
# 7  maxBanner  Experiment-3  PostOrderOnTheWay1    1058575      877352
#
#    viewable_impression  click  % render rate  % view  % ctr
# 2               250117   1043          79.32   81.08   0.42
# 1               408202    865          72.43   70.46   0.21
# 0               246684    342          79.40   85.32   0.14
# 5               289376    160          78.86   80.33   0.06
# 4               542797    172          80.43   69.06   0.03
# 3               288645     43          78.49   83.60   0.01
# 8               324409   4018          80.73   81.56   1.24
# 6               308560   1505          79.68   85.08   0.49
# 7               623831   1774          82.88   71.10   0.28

# %%
display(get_funnel(df_data, ['Experiment', 'service']))
# Out:
#        format    Experiment      service  responses  % render rate  % view  \
# 4   maxBanner  Experiment-1    Auto Pool        302          81.13   75.92
# 3   maxBanner  Experiment-1     Auto Pet        389          46.79   73.08
# 7   maxBanner  Experiment-1    Bike Pink        213          86.38   85.33
# 10  maxBanner  Experiment-1   CabPremium      29739          74.11   68.93
# 11  maxBanner  Experiment-1   E rickshaw       2237          82.12   79.70
# 5   maxBanner  Experiment-1    Bike Lite     102943          83.13   80.61
# 8   maxBanner  Experiment-1          C2C      12239          79.91   82.68
# 0   maxBanner  Experiment-1         Auto     570793          74.49   77.77
# 2   maxBanner  Experiment-1     Auto NCR       2265          81.02   78.64
# 6   maxBanner  Experiment-1   Bike Metro      28306          80.82   79.62
# 12  maxBanner  Experiment-1         Link     474259          76.37   77.56
# 1   maxBanner  Experiment-1     Auto C2C        812          82.88   80.53
# 9   maxBanner  Experiment-1   CabEconomy     328473          74.39   73.26
# 22  maxBanner  Experiment-2      Cab SUV        886          81.04   66.57
# 24  maxBanner  Experiment-2   CabPremium      45596          79.36   68.83
# 21  maxBanner  Experiment-2          C2C       6279          77.89   73.81
# 23  maxBanner  Experiment-2   CabEconomy     500381          78.47   73.13
# 18  maxBanner  Experiment-2    Bike Lite      56499          81.68   76.79
# 26  maxBanner  Experiment-2         Link     670843          80.43   76.45
# 13  maxBanner  Experiment-2         Auto     558262          79.38   75.59
# 19  maxBanner  Experiment-2   Bike Metro      30547          80.16   77.83
# 14  maxBanner  Experiment-2     Auto C2C        381          80.58   75.57
# 15  maxBanner  Experiment-2     Auto NCR       2204          81.03   73.96
# 16  maxBanner  Experiment-2     Auto Pet        540          82.96   62.72
# 17  maxBanner  Experiment-2    Auto Pool         30          70.00   66.67
# 20  maxBanner  Experiment-2    Bike Pink        108          78.70   74.12
# 25  maxBanner  Experiment-2   E rickshaw       1327          80.18   77.91
# 30  maxBanner  Experiment-3     Auto Pet        777          84.43   66.77
# 28  maxBanner  Experiment-3     Auto C2C        709          82.37   80.82
# 32  maxBanner  Experiment-3  AutoPremium        366          80.87   71.96
# 33  maxBanner  Experiment-3    Bike Lite     101340          83.51   79.78
# 27  maxBanner  Experiment-3         Auto     559680          81.49   77.23
# 39  maxBanner  Experiment-3   E rickshaw       1798          82.31   77.03
# 36  maxBanner  Experiment-3          C2C      11829          80.53   79.50
# 38  maxBanner  Experiment-3   CabEconomy     496677          80.69   75.29
# 40  maxBanner  Experiment-3         Link     797705          82.04   76.85
# 29  maxBanner  Experiment-3     Auto NCR       2274          83.20   76.74
# 37  maxBanner  Experiment-3      Cab SUV       9965          81.66   73.10
# 34  maxBanner  Experiment-3   Bike Metro      23121          82.47   78.65
# 35  maxBanner  Experiment-3    Bike Pink        205          83.90   84.30
# 31  maxBanner  Experiment-3    Auto Pool          1           0.00     NaN
#
#     % ctr
# 4    1.08
# 3    0.75
# 7    0.64
# 10   0.64
# 11   0.48
# 5    0.38
# 8    0.36
# 0    0.28
# 2    0.28
# 6    0.24
# 12   0.21
# 1    0.18
# 9    0.16
# 22   0.21
# 24   0.14
# 21   0.11
# 23   0.04
# 18   0.03
# 26   0.03
# 13   0.02
# 19   0.02
# 14   0.00
# 15   0.00
# 16   0.00
# 17   0.00
# 20   0.00
# 25   0.00
# 30   1.14
# 28   1.06
# 32   0.94
# 33   0.65
# 27   0.61
# 39   0.61
# 36   0.59
# 38   0.57
# 40   0.56
# 29   0.55
# 37   0.54
# 34   0.50
# 35   0.00
# 31    NaN

# %%
display(get_funnel(df_data, ['Experiment', 'gender']))
# Out:
#        format    Experiment   gender  responses  % render rate  % view  % ctr
# 3   maxBanner  Experiment-1  UNKNOWN     117418          78.34   74.87   0.35
# 2   maxBanner  Experiment-1   OTHERS       6570          79.22   72.70   0.34
# 0   maxBanner  Experiment-1   FEMALE     427815          76.32   78.03   0.29
# 1   maxBanner  Experiment-1     MALE    1001167          75.24   76.68   0.22
# 6   maxBanner  Experiment-2   OTHERS       8592          81.81   70.76   0.08
# 7   maxBanner  Experiment-2  UNKNOWN     131286          81.59   73.96   0.04
# 4   maxBanner  Experiment-2   FEMALE     434611          80.23   76.17   0.03
# 5   maxBanner  Experiment-2     MALE    1299394          79.16   74.95   0.03
# 11  maxBanner  Experiment-3  UNKNOWN     158018          83.11   74.70   0.78
# 10  maxBanner  Experiment-3   OTHERS       8183          84.81   72.90   0.75
# 8   maxBanner  Experiment-3   FEMALE     406246          82.32   77.58   0.67
# 9   maxBanner  Experiment-3     MALE    1434000          81.25   76.75   0.53

# %%
display(get_funnel(df_data, ['Experiment', 'ltr_segment']))
# Out:
#        format    Experiment ltr_segment  responses  % render rate  % view  \
# 1   maxBanner  Experiment-1         NEW      84914          79.42   73.89
# 3   maxBanner  Experiment-1     UNKNOWN      21365          78.46   68.10
# 0   maxBanner  Experiment-1          HH     152742          77.67   75.00
# 2   maxBanner  Experiment-1         PHH    1293949          75.28   77.48
# 7   maxBanner  Experiment-2     UNKNOWN      28617          82.05   64.64
# 4   maxBanner  Experiment-2          HH     193557          80.56   73.21
# 5   maxBanner  Experiment-2         NEW      93298          82.28   73.07
# 6   maxBanner  Experiment-2         PHH    1558411          79.27   75.72
# 9   maxBanner  Experiment-3         NEW     118913          83.66   73.86
# 11  maxBanner  Experiment-3     UNKNOWN      34306          83.60   67.74
# 8   maxBanner  Experiment-3          HH     233424          82.19   74.85
# 10  maxBanner  Experiment-3         PHH    1619804          81.35   77.43
#
#     % ctr
# 1    0.40
# 3    0.35
# 0    0.30
# 2    0.23
# 7    0.06
# 4    0.05
# 5    0.04
# 6    0.03
# 9    0.82
# 11   0.76
# 8    0.67
# 10   0.55

# %%
display(get_funnel(df_data, ['Experiment', 'retention_segments']))
# Out:
#        format    Experiment retention_segments  responses  % render rate  \
# 8   maxBanner  Experiment-1            UNKNOWN     106279          79.23
# 4   maxBanner  Experiment-1           INACTIVE      88779          77.29
# 0   maxBanner  Experiment-1            DORMANT     209425          75.76
# 3   maxBanner  Experiment-1                 HH      71293          77.63
# 5   maxBanner  Experiment-1           PLATINUM     298541          75.35
# 2   maxBanner  Experiment-1               GOLD     217031          75.69
# 7   maxBanner  Experiment-1             SILVER     105899          76.05
# 1   maxBanner  Experiment-1              ELITE     439886          74.70
# 6   maxBanner  Experiment-1              PRIME      15837          74.45
# 13  maxBanner  Experiment-2           INACTIVE     108800          79.96
# 9   maxBanner  Experiment-2            DORMANT     255839          79.24
# 12  maxBanner  Experiment-2                 HH      91331          80.64
# 16  maxBanner  Experiment-2             SILVER     132710          78.82
# 17  maxBanner  Experiment-2            UNKNOWN     121915          82.23
# 11  maxBanner  Experiment-2               GOLD     271559          79.26
# 14  maxBanner  Experiment-2           PLATINUM     364266          79.13
# 15  maxBanner  Experiment-2              PRIME      18558          78.67
# 10  maxBanner  Experiment-2              ELITE     508905          79.62
# 26  maxBanner  Experiment-3            UNKNOWN     153219          83.65
# 22  maxBanner  Experiment-3           INACTIVE     134312          81.86
# 21  maxBanner  Experiment-3                 HH     106953          82.27
# 18  maxBanner  Experiment-3            DORMANT     302468          81.41
# 25  maxBanner  Experiment-3             SILVER     155215          81.24
# 20  maxBanner  Experiment-3               GOLD     298308          81.21
# 23  maxBanner  Experiment-3           PLATINUM     378558          81.23
# 24  maxBanner  Experiment-3              PRIME      14768          80.44
# 19  maxBanner  Experiment-3              ELITE     462646          81.64
#
#     % view  % ctr
# 8    72.74   0.39
# 4    76.08   0.32
# 0    76.79   0.29
# 3    74.91   0.25
# 5    77.62   0.24
# 2    77.23   0.23
# 7    76.77   0.22
# 1    77.82   0.21
# 6    78.44   0.17
# 13   74.03   0.05
# 9    74.88   0.04
# 12   73.26   0.04
# 16   75.29   0.04
# 17   71.09   0.04
# 11   75.51   0.03
# 14   75.97   0.03
# 15   77.49   0.03
# 10   75.97   0.02
# 26   72.49   0.81
# 22   75.77   0.70
# 21   75.21   0.66
# 18   76.67   0.58
# 25   77.06   0.58
# 20   77.47   0.56
# 23   77.82   0.54
# 24   78.70   0.51
# 19   77.34   0.50

# %%
display(get_funnel(df_data, ['Experiment', 'regularity_segment']))
# Out:
#        format    Experiment regularity_segment  responses  % render rate  \
# 4   maxBanner  Experiment-1            UNKNOWN     259021          78.31
# 2   maxBanner  Experiment-1            MONTHLY     140102          75.93
# 3   maxBanner  Experiment-1          RARE_NEED     140347          76.13
# 0   maxBanner  Experiment-1          BI_WEEKLY     273190          75.75
# 5   maxBanner  Experiment-1             WEEKLY     374110          75.05
# 1   maxBanner  Experiment-1              DAILY     366200          74.60
# 9   maxBanner  Experiment-2          RARE_NEED     172596          79.39
# 10  maxBanner  Experiment-2            UNKNOWN     315472          81.20
# 8   maxBanner  Experiment-2            MONTHLY     172777          78.88
# 6   maxBanner  Experiment-2          BI_WEEKLY     339298          79.19
# 11  maxBanner  Experiment-2             WEEKLY     446347          79.03
# 7   maxBanner  Experiment-2              DAILY     427393          79.68
# 16  maxBanner  Experiment-3            UNKNOWN     386643          82.77
# 15  maxBanner  Experiment-3          RARE_NEED     203543          81.43
# 14  maxBanner  Experiment-3            MONTHLY     201541          81.20
# 12  maxBanner  Experiment-3          BI_WEEKLY     376668          81.26
# 17  maxBanner  Experiment-3             WEEKLY     467651          81.17
# 13  maxBanner  Experiment-3              DAILY     370401          81.72
#
#     % view  % ctr
# 4    74.06   0.34
# 2    77.45   0.26
# 3    77.37   0.26
# 0    77.21   0.24
# 5    77.76   0.24
# 1    77.46   0.20
# 9    75.75   0.05
# 10   72.38   0.05
# 8    75.61   0.04
# 6    75.70   0.03
# 11   75.94   0.03
# 7    75.54   0.02
# 16   73.90   0.72
# 15   77.53   0.65
# 14   77.32   0.58
# 12   77.44   0.55
# 17   77.87   0.53
# 13   76.86   0.49

# %%
display(get_funnel(df_data, ['Experiment', 'fe_regularity_segment']))
# Out:
#        format    Experiment fe_regularity_segment  responses  % render rate  \
# 4   maxBanner  Experiment-1               UNKNOWN     275021          77.61
# 2   maxBanner  Experiment-1               MONTHLY     200163          76.28
# 0   maxBanner  Experiment-1             BI_WEEKLY     357895          75.63
# 5   maxBanner  Experiment-1                WEEKLY     247981          75.20
# 3   maxBanner  Experiment-1             RARE_NEED      74406          75.93
# 1   maxBanner  Experiment-1                 DAILY     397504          74.75
# 10  maxBanner  Experiment-2               UNKNOWN     323640          80.52
# 8   maxBanner  Experiment-2               MONTHLY     252649          79.46
# 9   maxBanner  Experiment-2             RARE_NEED      95309          79.81
# 6   maxBanner  Experiment-2             BI_WEEKLY     441893          79.27
# 11  maxBanner  Experiment-2                WEEKLY     295561          78.99
# 7   maxBanner  Experiment-2                 DAILY     464831          79.67
# 16  maxBanner  Experiment-3               UNKNOWN     404302          82.30
# 14  maxBanner  Experiment-3               MONTHLY     290719          81.46
# 15  maxBanner  Experiment-3             RARE_NEED     109658          81.76
# 12  maxBanner  Experiment-3             BI_WEEKLY     484683          81.27
# 17  maxBanner  Experiment-3                WEEKLY     307628          81.22
# 13  maxBanner  Experiment-3                 DAILY     409457          81.78
#
#     % view  % ctr
# 4    75.72   0.33
# 2    76.69   0.26
# 0    77.20   0.24
# 5    77.61   0.24
# 3    75.66   0.23
# 1    77.35   0.20
# 10   74.39   0.05
# 8    74.77   0.04
# 9    74.02   0.04
# 6    75.40   0.03
# 11   75.89   0.03
# 7    75.41   0.02
# 16   75.57   0.73
# 14   76.77   0.60
# 15   75.77   0.59
# 12   77.23   0.56
# 17   77.85   0.53
# 13   76.73   0.48

# %%
display(get_funnel(df_data, ['Experiment', 'income_segment']))
# Out:
#        format    Experiment income_segment  responses  % render rate  % view  \
# 3   maxBanner  Experiment-1        UNKNOWN     360197          75.58   75.79
# 1   maxBanner  Experiment-1     LOW_INCOME      81883          81.89   78.13
# 2   maxBanner  Experiment-1  MEDIUM_INCOME     496059          80.77   78.26
# 0   maxBanner  Experiment-1    HIGH_INCOME     614831          71.08   76.14
# 5   maxBanner  Experiment-2     LOW_INCOME     105907          86.23   76.36
# 7   maxBanner  Experiment-2        UNKNOWN     434379          78.92   74.24
# 4   maxBanner  Experiment-2    HIGH_INCOME     731296          74.78   73.82
# 6   maxBanner  Experiment-2  MEDIUM_INCOME     602301          84.75   76.96
# 11  maxBanner  Experiment-3        UNKNOWN     503720          80.90   75.66
# 10  maxBanner  Experiment-3  MEDIUM_INCOME     637432          86.19   78.25
# 9   maxBanner  Experiment-3     LOW_INCOME     111079          87.43   77.86
# 8   maxBanner  Experiment-3    HIGH_INCOME     754216          77.40   75.89
#
#     % ctr
# 3    0.30
# 1    0.28
# 2    0.26
# 0    0.20
# 5    0.04
# 7    0.04
# 4    0.03
# 6    0.03
# 11   0.68
# 10   0.59
# 9    0.56
# 8    0.50

# %%
display(get_funnel(df_data, ['Experiment', 'service_affinity']))
# Out:
#        format    Experiment service_affinity  responses  % render rate  \
# 7   maxBanner  Experiment-1          UNKNOWN     705023          76.66
# 4   maxBanner  Experiment-1        ONLY_AUTO     285642          72.65
# 0   maxBanner  Experiment-1         AUTO_CAB      22686          72.67
# 1   maxBanner  Experiment-1        LINK_AUTO      44260          74.67
# 3   maxBanner  Experiment-1      NO_AFFINITY     104799          72.96
# 6   maxBanner  Experiment-1        ONLY_LINK     319264          78.15
# 5   maxBanner  Experiment-1         ONLY_CAB      62700          74.46
# 2   maxBanner  Experiment-1         LINK_CAB       8596          79.11
# 15  maxBanner  Experiment-2          UNKNOWN     868344          79.69
# 11  maxBanner  Experiment-2      NO_AFFINITY     136414          79.12
# 13  maxBanner  Experiment-2         ONLY_CAB      81971          77.28
# 12  maxBanner  Experiment-2        ONLY_AUTO     297193          79.02
# 14  maxBanner  Experiment-2        ONLY_LINK     398372          80.57
# 8   maxBanner  Experiment-2         AUTO_CAB      27385          76.81
# 9   maxBanner  Experiment-2        LINK_AUTO      51356          80.21
# 10  maxBanner  Experiment-2         LINK_CAB      12848          79.67
# 23  maxBanner  Experiment-3          UNKNOWN    1037517          81.67
# 21  maxBanner  Experiment-3         ONLY_CAB      73415          79.93
# 20  maxBanner  Experiment-3        ONLY_AUTO     248562          80.91
# 16  maxBanner  Experiment-3         AUTO_CAB      23161          79.31
# 17  maxBanner  Experiment-3        LINK_AUTO      54454          81.79
# 19  maxBanner  Experiment-3      NO_AFFINITY     129737          81.37
# 22  maxBanner  Experiment-3        ONLY_LINK     424573          82.39
# 18  maxBanner  Experiment-3         LINK_CAB      15028          81.95
#
#     % view  % ctr
# 7    76.23   0.28
# 4    78.44   0.27
# 0    76.07   0.26
# 1    78.40   0.22
# 3    76.42   0.21
# 6    77.76   0.20
# 5    73.50   0.19
# 2    74.09   0.14
# 15   74.66   0.04
# 11   74.52   0.03
# 13   71.78   0.03
# 12   75.91   0.02
# 14   76.36   0.02
# 8    75.31   0.01
# 9    77.11   0.01
# 10   71.60   0.00
# 23   76.30   0.64
# 21   74.92   0.58
# 20   77.78   0.56
# 16   77.27   0.54
# 17   78.38   0.54
# 19   76.23   0.49
# 22   77.47   0.49
# 18   75.38   0.48

# %%
display(get_funnel(df_data, ['Experiment', 'gc_tag']))
# Out:
#       format    Experiment   gc_tag  responses  % render rate  % view  % ctr
# 2  maxBanner  Experiment-1  UNKNOWN    1238371          75.95   76.75   0.26
# 1  maxBanner  Experiment-1   NON_GC     283779          75.02   77.35   0.20
# 0  maxBanner  Experiment-1       GC      30820          76.21   78.60   0.17
# 4  maxBanner  Experiment-2   NON_GC     347083          78.47   75.37   0.04
# 5  maxBanner  Experiment-2  UNKNOWN    1491294          79.85   75.07   0.03
# 3  maxBanner  Experiment-2       GC      35506          79.76   76.40   0.02
# 8  maxBanner  Experiment-3  UNKNOWN    1600628          81.84   76.57   0.60
# 7  maxBanner  Experiment-3   NON_GC     373794          80.73   77.30   0.50
# 6  maxBanner  Experiment-3       GC      32025          81.65   78.38   0.43

# %% [markdown]
# #### Multivariate data

# %%
get_funnel(df_data, ['Experiment', 'slotUnitId', 'os']).pivot(index = ['slotUnitId', 'Experiment'] , 
                                                columns = ['os'] , 
                                                values =['% render rate', '% view',	'% ctr'])
# Out:
#                                 % render rate  % view   % ctr
# os                                    android android android
# slotUnitId         Experiment
# PostOrderArrived1  Experiment-3         79.68   85.08    0.49
# PostOrderArrived3  Experiment-1         79.40   85.32    0.14
# PostOrderArrived4  Experiment-2         78.49   83.60    0.01
# PostOrderOnTheWay1 Experiment-3         82.88   71.10    0.28
# PostOrderOnTheWay3 Experiment-1         72.43   70.46    0.21
# PostOrderOnTheWay4 Experiment-2         80.43   69.06    0.03
# PostOrderStarted1  Experiment-3         80.73   81.56    1.24
# PostOrderStarted3  Experiment-1         79.32   81.08    0.42
# PostOrderStarted4  Experiment-2         78.86   80.33    0.06

# %%
display(get_funnel(df_data, ['Experiment', 'yyyymmdd', 'slotUnitId']))
# Out:
#        format    Experiment  yyyymmdd          slotUnitId  responses  \
# 13  maxBanner  Experiment-1  20250119  PostOrderOnTheWay3         17
# 17  maxBanner  Experiment-1  20250120   PostOrderStarted3      75653
# 16  maxBanner  Experiment-1  20250120  PostOrderOnTheWay3     136172
# 15  maxBanner  Experiment-1  20250120   PostOrderArrived3      66477
# 2   maxBanner  Experiment-1  20250115   PostOrderStarted3      55374
# 20  maxBanner  Experiment-1  20250121   PostOrderStarted3      68826
# 23  maxBanner  Experiment-1  20250122   PostOrderStarted3      70619
# 8   maxBanner  Experiment-1  20250117   PostOrderStarted3      61748
# 1   maxBanner  Experiment-1  20250115  PostOrderOnTheWay3     113140
# 5   maxBanner  Experiment-1  20250116   PostOrderStarted3      56671
# 0   maxBanner  Experiment-1  20250115   PostOrderArrived3      50899
# 7   maxBanner  Experiment-1  20250117  PostOrderOnTheWay3     131840
# 22  maxBanner  Experiment-1  20250122  PostOrderOnTheWay3     149433
# 19  maxBanner  Experiment-1  20250121  PostOrderOnTheWay3     146181
# 3   maxBanner  Experiment-1  20250116   PostOrderArrived3      52972
# 4   maxBanner  Experiment-1  20250116  PostOrderOnTheWay3     123114
# 18  maxBanner  Experiment-1  20250121   PostOrderArrived3      66586
# 21  maxBanner  Experiment-1  20250122   PostOrderArrived3      68245
# 6   maxBanner  Experiment-1  20250117   PostOrderArrived3      58982
# 9   maxBanner  Experiment-1  20250118   PostOrderArrived3          1
# 10  maxBanner  Experiment-1  20250118  PostOrderOnTheWay3          3
# 11  maxBanner  Experiment-1  20250118   PostOrderStarted3          5
# 12  maxBanner  Experiment-1  20250119   PostOrderArrived3          5
# 14  maxBanner  Experiment-1  20250119   PostOrderStarted3          7
# 44  maxBanner  Experiment-2  20250129   PostOrderStarted4      67412
# 32  maxBanner  Experiment-2  20250125   PostOrderStarted4      63526
# 35  maxBanner  Experiment-2  20250126   PostOrderStarted4      63666
# 38  maxBanner  Experiment-2  20250127   PostOrderStarted4      65431
# 26  maxBanner  Experiment-2  20250123   PostOrderStarted4      64453
# 25  maxBanner  Experiment-2  20250123  PostOrderOnTheWay4     137004
# 28  maxBanner  Experiment-2  20250124  PostOrderOnTheWay4     140000
# 29  maxBanner  Experiment-2  20250124   PostOrderStarted4      65479
# 41  maxBanner  Experiment-2  20250128   PostOrderStarted4      66840
# 31  maxBanner  Experiment-2  20250125  PostOrderOnTheWay4     133552
# 34  maxBanner  Experiment-2  20250126  PostOrderOnTheWay4     138351
# 37  maxBanner  Experiment-2  20250127  PostOrderOnTheWay4     138853
# 39  maxBanner  Experiment-2  20250128   PostOrderArrived4      64984
# 40  maxBanner  Experiment-2  20250128  PostOrderOnTheWay4     144159
# 43  maxBanner  Experiment-2  20250129  PostOrderOnTheWay4     145266
# 30  maxBanner  Experiment-2  20250125   PostOrderArrived4      60020
# 33  maxBanner  Experiment-2  20250126   PostOrderArrived4      59574
# 42  maxBanner  Experiment-2  20250129   PostOrderArrived4      66186
# 24  maxBanner  Experiment-2  20250123   PostOrderArrived4      61787
# 27  maxBanner  Experiment-2  20250124   PostOrderArrived4      64193
# 36  maxBanner  Experiment-2  20250127   PostOrderArrived4      63147
# 65  maxBanner  Experiment-3  20250205   PostOrderStarted1      79258
# 53  maxBanner  Experiment-3  20250201   PostOrderStarted1      66271
# 50  maxBanner  Experiment-3  20250131   PostOrderStarted1      70380
# 47  maxBanner  Experiment-3  20250130   PostOrderStarted1      69009
# 59  maxBanner  Experiment-3  20250203   PostOrderStarted1      70046
# 56  maxBanner  Experiment-3  20250202   PostOrderStarted1      66185
# 62  maxBanner  Experiment-3  20250204   PostOrderStarted1      71543
# 64  maxBanner  Experiment-3  20250205  PostOrderOnTheWay1     152961
# 54  maxBanner  Experiment-3  20250202   PostOrderArrived1      61401
# 51  maxBanner  Experiment-3  20250201   PostOrderArrived1      61150
# 45  maxBanner  Experiment-3  20250130   PostOrderArrived1      65906
# 48  maxBanner  Experiment-3  20250131   PostOrderArrived1      66230
# 57  maxBanner  Experiment-3  20250203   PostOrderArrived1      63509
# 60  maxBanner  Experiment-3  20250204   PostOrderArrived1      66356
# 63  maxBanner  Experiment-3  20250205   PostOrderArrived1      70628
# 55  maxBanner  Experiment-3  20250202  PostOrderOnTheWay1     147005
# 52  maxBanner  Experiment-3  20250201  PostOrderOnTheWay1     143041
# 58  maxBanner  Experiment-3  20250203  PostOrderOnTheWay1     151698
# 61  maxBanner  Experiment-3  20250204  PostOrderOnTheWay1     154359
# 46  maxBanner  Experiment-3  20250130  PostOrderOnTheWay1     154330
# 49  maxBanner  Experiment-3  20250131  PostOrderOnTheWay1     155181
#
#     % render rate  % view  % ctr
# 13         100.00   88.24   6.67
# 17          82.96   86.44   1.21
# 16          85.24   77.87   0.65
# 15          82.69   91.65   0.45
# 2           80.59   84.04   0.31
# 20          78.43   79.62   0.19
# 23          78.26   79.53   0.18
# 8           77.62   77.57   0.16
# 1           82.61   73.45   0.14
# 5           77.45   78.00   0.13
# 0           80.10   89.43   0.09
# 7           67.02   66.77   0.08
# 22          67.25   68.37   0.08
# 19          67.29   67.68   0.07
# 3           78.15   81.56   0.06
# 4           67.07   66.47   0.06
# 18          78.60   83.44   0.06
# 21          78.61   83.73   0.05
# 6           77.99   81.49   0.04
# 9          100.00  100.00   0.00
# 10         100.00  100.00   0.00
# 11         100.00   80.00   0.00
# 12          80.00   50.00   0.00
# 14         100.00   85.71   0.00
# 44          79.82   81.12   0.07
# 32          78.28   79.74   0.06
# 35          78.69   79.26   0.06
# 38          78.37   80.66   0.06
# 26          78.59   79.90   0.05
# 25          80.35   69.03   0.04
# 28          80.44   69.48   0.04
# 29          78.93   80.39   0.04
# 41          79.27   81.11   0.04
# 31          79.64   67.95   0.03
# 34          79.89   67.17   0.03
# 37          79.67   68.45   0.03
# 39          79.08   84.30   0.03
# 40          81.07   70.28   0.03
# 43          81.84   70.82   0.03
# 30          77.89   82.75   0.02
# 33          78.06   82.79   0.02
# 42          79.32   84.88   0.02
# 24          78.51   83.20   0.01
# 27          78.40   83.57   0.01
# 36          78.07   83.47   0.01
# 65          82.61   85.16   1.35
# 53          79.50   80.39   1.26
# 50          80.81   80.83   1.25
# 47          80.64   81.90   1.24
# 59          80.25   80.61   1.19
# 56          80.42   80.69   1.18
# 62          80.55   80.67   1.18
# 64          85.12   77.22   0.90
# 54          79.40   83.21   0.61
# 51          78.68   83.64   0.50
# 45          79.55   85.08   0.48
# 48          79.51   84.93   0.48
# 57          79.35   83.78   0.47
# 60          79.74   84.06   0.45
# 63          81.30   90.08   0.43
# 55          82.33   68.85   0.20
# 52          81.24   68.62   0.17
# 58          82.26   69.44   0.17
# 61          82.54   69.90   0.16
# 46          83.42   72.12   0.15
# 49          83.11   71.07   0.15
