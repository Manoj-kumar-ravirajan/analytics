# %% [markdown]
# ## Import

# %%
import re
import os 
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from pyhive import presto
from datetime import date
from collections import Counter

from scipy import stats
from pyhive import presto
from datetime import datetime, timedelta

presto_port = '80'
username = 'manoj.ravirajan@rapido.bike'

conn=presto.connect('presto-gateway.processing.data.production.internal',presto_port,username)

connection1 = presto.connect('bi-presto.serving.data.production.internal', presto_port, username)
connection2 = presto.connect('bi-trino-2.serving.data.production.internal', presto_port, username)
connection3= presto.connect('processing-2.processing.data.production.internal',presto_port,username)
connection4= presto.connect('processing.processing.data.production.internal',presto_port,username)


pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Overall

# %%
overall_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916' 
        and event_props_campaign_id = '1725970812' 
),

merge as(
        select rr_net.*,view_tbl.event_type,click_tbl.click_type
        from rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        )

SELECT
        test_group,
        -- event_type,
        -- click_type,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            -- event_type,
            -- click_type,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1
        )
    ORDER BY 1
    
    
"""
overall=pd.read_sql(overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62370/2770846961.py:154: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall=pd.read_sql(overall_query,conn)

# %%
overall
# Out:
#   test_group  customers  gross_count  net_count    g2n    aor  \
# 0    control     426083      1495502     726604  48.59  66.94
# 1       test     426987      1499498     726049  48.42  66.75
#
#    median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0                106                132                310
# 1                106                131                311
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       174                      14     1.63    20.10
# 1                       174                      14     1.63    20.14
#
#    % ocara  % expired  cobrm   cobra   ocara  expired
# 0    17.98      11.31  24367  300574  268872   169149
# 1    17.95      11.46  24489  302038  269165   171869

# %%
overall.to_clipboard(index=False)

# %% [markdown]
# ## Level 1 breakdown

# %%
overall_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916' 
        and event_props_campaign_id = '1725970812' 
),

merge as(
        select rr_net.*,view_tbl.event_type,click_tbl.click_type
        from rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        )

SELECT
        test_group,
        event_type,
        click_type,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3

    
    
    
    
"""
overall1=pd.read_sql(overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62370/3292753032.py:157: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall1=pd.read_sql(overall_query,conn)

# %%
overall1
# Out:
#   test_group event_type   click_type  customers  gross_count  net_count  \
# 0    control       None         None     426083      1495502     726604
# 1       test     viewed  close_click     315748       826810     400370
# 2       test     viewed   play_click      32360        68335      30131
# 3       test     viewed         None      10982        22090      11297
# 4       test       None         None     200427       582671     284380
#
#      g2n    aor  median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0  48.59  66.94                106                132                310
# 1  48.42  66.68                112                134                319
# 2  44.09  63.98                104                130                319
# 3  51.14  72.39                110                132                315
# 4  48.81  66.94                 98                128                300
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       174                      14     1.63    20.10
# 1                       178                      14     1.58    20.10
# 2                       172                      15     1.94    20.71
# 3                       191                      12     1.16    15.00
# 4                       167                      14     1.69    20.34
#
#    % ocara  % expired  cobrm   cobra   ocara  expired
# 0    17.98      11.31  24367  300574  268872   169149
# 1    17.88      11.63  13062  166171  147818    96118
# 2    19.46      13.34   1327   14152   13301     9118
# 3    20.79      11.41    257    3314    4593     2520
# 4    17.77      11.02   9851  118510  103539    64186

# %%
overall1.to_clipboard(index=False)

# %% [markdown]
# ## Pre-Post

# %%
overall_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240910'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240905' AND yyyymmdd <= '20240910'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240905' AND yyyymmdd <= '20240910'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240905' AND yyyymmdd <= '20240910' 
        and event_props_campaign_id = '1725970812' 
),

merge as(
        select rr_net.*,view_tbl.event_type,click_tbl.click_type
        from rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        )

SELECT
        test_group,
        -- event_type,
        -- click_type,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            -- event_type,
            -- click_type,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1
        )
    ORDER BY 1
    
    
"""
pre_overall=pd.read_sql(overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62370/2275741643.py:154: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pre_overall=pd.read_sql(overall_query,conn)

# %%
pre_overall
# Out:
#   test_group  customers  gross_count  net_count    g2n    aor  \
# 0    control     378291      1291512     695940  53.89  73.18
# 1       test     377944      1289573     695496  53.93  73.13
#
#    median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0                104                128                299
# 1                104                128                302
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       177                      13     1.16    16.99
# 1                       178                      14     1.10    17.01
#
#    % ocara  % expired  cobrm   cobra   ocara  expired
# 0    18.89       8.66  14974  219455  243923   111799
# 1    18.81       8.74  14159  219396  242615   112735

# %%
pre_overall.to_clipboard(index=False)

# %% [markdown]
# ## Cobra distr

# %%
overall_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916' 
        and event_props_campaign_id = '1725970812' 
),

merge as(
        select rr_net.*,view_tbl.event_type,click_tbl.click_type
        from rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        )

SELECT
        test_group,
        -- event_type,
        -- click_type,
        cobra_ttc_bucket,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            -- event_type,
            -- click_type,


            CASE 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec <= 15 THEN 'a. 0-15 sec' 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec BETWEEN 16 AND 30 THEN 'b. 16-30 sec' 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec BETWEEN 31 AND 60 THEN 'c. 31-60 sec' 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec BETWEEN 61 AND 180 THEN 'd. 61-180 sec' 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec > 180 THEN 'e. 180+ sec' 
            WHEN modified_order_status != 'COBRA' THEN 'f. NO COBRA'
            ELSE 'Check' END cobra_ttc_bucket,
            
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)

           and click_type = 'play_click'

           
        GROUP BY 1,2
        )
    ORDER BY 1,2
    
    
"""
overall_ttc_breakup=pd.read_sql(overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62370/543812215.py:170: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_ttc_breakup=pd.read_sql(overall_query,conn)

# %%
overall_ttc_breakup
# Out:
#   test_group cobra_ttc_bucket  customers  gross_count  net_count    g2n  \
# 0       test      a. 0-15 sec        650          701          0   0.00
# 1       test     b. 16-30 sec        774          823          0   0.00
# 2       test     c. 31-60 sec       1299         1527          0   0.00
# 3       test    d. 61-180 sec       4432         6538          0   0.00
# 4       test      e. 180+ sec       3577         4563          0   0.00
# 5       test      f. NO COBRA      30317        54183      30131  55.61
#
#      aor  median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0   0.00                NaN               11.0                NaN
# 1   0.00                NaN               22.0                NaN
# 2   0.00                NaN               46.0                NaN
# 3   0.00                NaN              116.0                NaN
# 4   0.00                NaN              251.0                NaN
# 5  80.69              104.0                NaN              318.0
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                        11                     NaN     0.00    100.0
# 1                        22                     NaN     0.00    100.0
# 2                        46                     NaN     0.00    100.0
# 3                       116                     NaN     0.00    100.0
# 4                       251                     NaN     0.00    100.0
# 5                       281                    15.0     2.45      0.0
#
#    % ocara  % expired  cobrm  cobra  ocara  expired
# 0     0.00       0.00      0    701      0        0
# 1     0.00       0.00      0    823      0        0
# 2     0.00       0.00      0   1527      0        0
# 3     0.00       0.00      0   6538      0        0
# 4     0.00       0.00      0   4563      0        0
# 5    24.55      16.83   1327      0  13301     9118

# %%
overall_ttc_breakup.gross_count.sum()
# Out:
# 68335

# %%
68335-54183
# Out:
# 14152

# %%
overall_ttc_breakup.to_clipboard(index=False)

# %% [markdown]
# ## Other

# %%
overall_daywise_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916' 
        and event_props_campaign_id = '1725970812' 
),

merge as(
        select rr_net.*,view_tbl.event_type,click_tbl.click_type
        from rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        )

SELECT
        yyyymmdd,
        test_group,
        event_type,
        click_type,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            yyyymmdd,
            test_group,
            event_type,
            click_type,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

    
    
    
    
"""
overall_daywise_df=pd.read_sql(overall_daywise_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/3833155388.py:159: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_daywise_df=pd.read_sql(overall_daywise_query,conn)

# %%
overall_daywise_df
# Out:
#     yyyymmdd test_group event_type   click_type  customers  gross_count  \
# 0   20240911    control       None         None     132673       248221
# 1   20240911       test     viewed  close_click      76793       140182
# 2   20240911       test     viewed   play_click       6688        12582
# 3   20240911       test     viewed         None       2323         4137
# 4   20240911       test       None         None      46714        91191
# 5   20240912    control       None         None     131658       263152
# 6   20240912       test     viewed  close_click      66587       132937
# 7   20240912       test     viewed   play_click       5880        12103
# 8   20240912       test     viewed         None       1872         3681
# 9   20240912       test       None         None      57945       117056
# 10  20240913    control       None         None     155042       378008
# 11  20240913       test     viewed  close_click      87946       209827
# 12  20240913       test     viewed   play_click       7435        17952
# 13  20240913       test     viewed         None       2255         5107
# 14  20240913       test       None         None      58083       147477
# 15  20240914    control       None         None     118930       214882
# 16  20240914       test     viewed  close_click      64584       115918
# 17  20240914       test     viewed   play_click       5007         9126
# 18  20240914       test     viewed         None       1707         3007
# 19  20240914       test       None         None      47201        86648
# 20  20240915    control       None         None      99911       180491
# 21  20240915       test     viewed  close_click      56453       100564
# 22  20240915       test     viewed   play_click       4288         7876
# 23  20240915       test     viewed         None       1431         2562
# 24  20240915       test       None         None      37888        69542
# 25  20240916    control       None         None     120915       210466
# 26  20240916       test     viewed  close_click      73314       127287
# 27  20240916       test     viewed   play_click       4912         8690
# 28  20240916       test     viewed         None       2031         3588
# 29  20240916       test       None         None      40480        70477
#
#     net_count    g2n    aor  median_cobrm_time  median_cobra_time  \
# 0      135276  54.50  73.96                100                124
# 1       76298  54.43  73.71                115                127
# 2        6363  50.57  71.67                 98                116
# 3        2446  59.12  79.79                116                128
# 4       49892  54.71  74.19                 92                121
# 5      122118  46.41  65.24                103                127
# 6       60498  45.51  64.54                109                129
# 7        5069  41.88  62.51                104                126
# 8        1721  46.75  68.57                119                131
# 9       55593  47.49  65.79                 98                125
# 10     111480  29.49  44.30                108                141
# 11      60969  29.06  43.73                110                142
# 12       4744  26.43  41.68                101                142
# 13       1686  33.01  51.07                107                142
# 14      44199  29.97  44.53                106                137
# 15     123076  57.28  77.42                109                126
# 16      66494  57.36  77.16                119                129
# 17       4843  53.07  74.88                101                120
# 18       1776  59.06  81.94                147                126
# 19      49430  57.05  76.93                 93                122
# 20     103536  57.36  77.60                106                125
# 21      56890  56.57  76.84                112                129
# 22       4120  52.31  75.06                112                127
# 23       1421  55.46  80.25                126                116
# 24      40873  58.77  78.91                 95                122
# 25     130982  62.23  81.61                105                124
# 26      79168  62.20  81.40                107                127
# 27       4989  57.41  79.41                130                119
# 28       2244  62.54  84.42                 91                117
# 29      44287  62.84  82.30                 92                120
#
#     median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                 297                       174                      14
# 1                 308                       177                      13
# 2                 289                       166                      15
# 3                 297                       192                      12
# 4                 290                       170                      15
# 5                 313                       169                      17
# 6                 322                       173                      17
# 7                 315                       167                      18
# 8                 323                       188                      15
# 9                 294                       163                      17
# 10                345                       169                      23
# 11                353                       171                      23
# 12                360                       171                      23
# 13                359                       187                      17
# 14                338                       164                      24
# 15                301                       183                      12
# 16                315                       187                      12
# 17                306                       180                      13
# 18                314                       203                      11
# 19                285                       171                      12
# 20                294                       179                      11
# 21                304                       183                      11
# 22                322                       180                      12
# 23                302                       193                      10
# 24                285                       174                      11
# 25                293                       185                      11
# 26                295                       186                      11
# 27                311                       185                      11
# 28                273                       185                      10
# 29                281                       178                      11
#
#     % cobrm  % cobra  % ocara  % expired  cobrm   cobra  ocara  expired
# 0      1.18    16.82    19.04       8.02   2934   41763  47257    19906
# 1      1.20    17.10    18.90       7.98   1686   23968  26499    11181
# 2      1.24    17.95    20.73       9.14    156    2258   2608     1150
# 3      0.70    11.48    20.23       7.98     29     475    837      330
# 4      1.28    16.85    19.06       7.66   1165   15368  17378     6989
# 5      1.60    22.36    18.46      10.78   4202   58828  48589    28369
# 6      1.57    22.53    18.64      11.35   2082   29950  24774    15083
# 7      1.85    22.75    20.17      12.85    224    2753   2441     1555
# 8      1.28    18.28    21.49      11.84     47     673    791      436
# 9      1.54    22.55    17.94      10.11   1807   26391  21001    11833
# 10     2.20    31.88    14.54      21.61   8313  120504  54967    81688
# 11     2.18    31.68    14.41      22.40   4574   66467  30241    46991
# 12     2.85    30.73    14.95      24.70    512    5517   2684     4434
# 13     1.39    24.55    17.68      22.97     71    1254    903     1173
# 14     2.06    32.06    14.28      21.34   3045   47280  21066    31468
# 15     1.56    13.95    19.70       7.04   3350   29977  42340    15136
# 16     1.53    14.04    19.36       7.25   1773   16274  22440     8401
# 17     1.81    14.94    21.31       8.33    165    1363   1945      760
# 18     0.86    10.18    22.02       6.98     26     306    662      210
# 19     1.88    14.38    19.54       6.79   1627   12457  16935     5885
# 20     1.69    13.61    19.82       7.09   3044   24561  35768    12792
# 21     1.51    14.11    19.82       7.53   1515   14186  19929     7572
# 22     1.92    14.72    22.27       8.30    151    1159   1754      654
# 23     1.52    11.05    24.32       7.10     39     283    623      182
# 24     1.90    12.76    19.72       6.41   1323    8877  13713     4460
# 25     1.20    11.82    18.96       5.34   2517   24871  39902    11236
# 26     1.12    12.03    18.78       5.41   1430   15318  23906     6887
# 27     1.36    12.68    21.51       6.49    118    1102   1869      564
# 28     1.25     9.03    21.52       5.24     45     324    772      188
# 29     1.24    11.41    19.01       5.00    877    8043  13397     3524

# %%
overall_daywise_df.to_clipboard(index=False)

# %%
overall_daywise_df.to_csv('overall_daywise_df.csv',index=False)

# %%
session_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916' 
        and event_props_campaign_id = '1725970812' 
),

merge as(
        select rr_net.*,view_tbl.event_type,click_tbl.click_type
        from rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        )

SELECT
        test_group,
        event_type,
        click_type,
        time_period,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

    
    
    
    
"""
session_df=pd.read_sql(session_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/3233821542.py:165: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   session_df=pd.read_sql(session_query,conn)

# %%
session_df
# Out:
#    test_group event_type   click_type   time_period  customers  gross_count  \
# 0     control       None         None     afternoon     205733       438073
# 1     control       None         None       evening     193280       478646
# 2     control       None         None       morning     133869       299946
# 3     control       None         None  rest_evening      74195       137305
# 4     control       None         None  rest_morning      69515       141250
# 5        test     viewed  close_click     afternoon     139382       252121
# 6        test     viewed  close_click       evening     130781       266185
# 7        test     viewed  close_click       morning      89817       158865
# 8        test     viewed  close_click  rest_evening      45878        74289
# 9        test     viewed  close_click  rest_morning      42764        75255
# 10       test     viewed   play_click     afternoon      12758        20845
# 11       test     viewed   play_click       evening      12422        22728
# 12       test     viewed   play_click       morning       7596        11849
# 13       test     viewed   play_click  rest_evening       4467         6765
# 14       test     viewed   play_click  rest_morning       3530         6142
# 15       test     viewed         None     afternoon       4437         6774
# 16       test     viewed         None       evening       4206         7147
# 17       test     viewed         None       morning       3170         4396
# 18       test     viewed         None  rest_evening       1378         2016
# 19       test     viewed         None  rest_morning       1182         1749
# 20       test       None         None     afternoon      85386       160163
# 21       test       None         None       evening      82940       184813
# 22       test       None         None       morning      66077       125961
# 23       test       None         None  rest_evening      30578        53143
# 24       test       None         None  rest_morning      31428        58311
#
#     net_count    g2n    aor  median_cobrm_time  median_cobra_time  \
# 0      250827  57.26  76.61                105                127
# 1      187429  39.16  56.51                103                132
# 2      158523  52.85  69.56                107                132
# 3       64916  47.28  69.02                 97                128
# 4       64773  45.86  64.72                113                139
# 5      143576  56.95  76.14                115                130
# 6      103082  38.73  56.05                109                134
# 7       83933  52.83  69.48                113                134
# 8       34999  47.11  68.55                 97                130
# 9       34727  46.15  64.76                118                141
# 10      10970  52.63  74.00                101                125
# 11       8155  35.88  54.12                103                133
# 12       5578  47.08  65.20                116                127
# 13       3017  44.60  67.46                 82                124
# 14       2408  39.21  60.24                117                136
# 15       3998  59.02  80.94                124                127
# 16       2984  41.75  62.32                 96                131
# 17       2530  57.55  76.68                147                137
# 18        925  45.88  70.39                111                122
# 19        857  49.00  71.76                 98                139
# 20      92576  57.80  77.23                 94                121
# 21      72665  39.32  56.37                 96                130
# 22      67004  53.19  69.59                107                131
# 23      25392  47.78  68.80                 90                124
# 24      26637  45.68  64.75                102                133
#
#     median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                 309                       183                      11
# 1                 322                       169                      16
# 2                 286                       168                      15
# 3                 323                       180                      16
# 4                 308                       173                      12
# 5                 318                       187                      11
# 6                 328                       172                      15
# 7                 292                       170                      15
# 8                 331                       183                      16
# 9                 326                       178                      12
# 10                320                       184                      12
# 11                322                       168                      17
# 12                287                       160                      16
# 13                343                       187                      19
# 14                320                       174                      14
# 15                300                       201                      10
# 16                332                       183                      14
# 17                280                       185                      12
# 18                337                       197                      14
# 19                358                       190                      10
# 20                294                       174                      11
# 21                312                       166                      17
# 22                276                       163                      16
# 23                315                       172                      16
# 24                302                       165                      13
#
#     % cobrm  % cobra  % ocara  % expired  cobrm   cobra  ocara  expired
# 0      1.25    14.22    18.96       7.91   5494   62300  83060    34667
# 1      1.53    25.31    17.01      16.63   7301  121148  81417    79600
# 2      1.10    20.12    16.42       9.22   3295   60354  49255    27641
# 3      1.84    19.88    21.10       9.13   2528   27293  28978    12531
# 4      4.07    20.82    18.49      10.40   5742   29409  26113    14688
# 5      1.15    14.48    18.80       8.23   2906   36504  47396    20737
# 6      1.54    25.31    16.98      17.08   4104   67368  45211    45453
# 7      1.06    20.08    16.35       9.38   1677   31903  25980    14909
# 8      1.90    19.85    20.80       9.57   1408   14745  15452     7106
# 9      3.94    20.79    18.27      10.51   2965   15643  13750     7910
# 10     1.50    15.06    20.97       9.44    312    3139   4371     1968
# 11     1.84    25.20    17.87      18.80    418    5728   4061     4273
# 12     1.31    22.53    17.83      10.97    155    2669   2113     1300
# 13     2.28    18.99    22.14      11.12    154    1285   1498      752
# 14     4.67    21.67    20.48      13.42    287    1331   1258      824
# 15     0.71    10.33    21.39       8.02     48     700   1449      543
# 16     1.20    19.55    20.12      16.87     86    1397   1438     1206
# 17     0.64    14.01    18.88       8.67     28     616    830      381
# 18     2.18    16.87    23.66      10.32     44     340    477      208
# 19     2.92    14.98    22.53      10.35     51     262    394      181
# 20     1.31    14.10    19.04       7.35   2098   22589  30497    11773
# 21     1.52    25.59    16.76      16.49   2804   47294  30974    30482
# 22     1.02    20.38    16.10       9.01   1284   25665  20275    11347
# 23     2.16    20.09    20.41       8.86   1147   10675  10849     4707
# 24     4.31    20.91    18.68      10.03   2511   12193  10895     5850

# %%
session_df.to_clipboard(index=False)

# %%
session_df.to_csv('session_df.csv',index=False)

# %%
ltr_segment_games_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240915' 
        and event_props_campaign_id = '1725970812' 
),

segment AS (
    
    SELECT
        customer_id,
        taxi_ltr_segment ltr_segment,
        taxi_retention_segments retention_segment,
        taxi_lifetime_stage lifetime_stage,
        taxi_service_affinity service_affinity,
        gender_tag gender
    FROM
        datasets.iallocator_customer_segments
    WHERE 
        run_date = '2024-09-11'
    
),

merge as(
        select rr_net.*,
        view_tbl.event_type,
        click_tbl.click_type,
        segment.ltr_segment
        from 
            rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        LEFT JOIN 
            segment
        ON rr_net.customer_id=segment.customer_id
        )

SELECT
        test_group,
        event_type,
        click_type,
        ltr_segment,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            ltr_segment,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

    
    
    
    
"""
ltr_segment_games_df=pd.read_sql(ltr_segment_games_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/3587971687.py:182: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ltr_segment_games_df=pd.read_sql(ltr_segment_games_query,conn)

# %%
ltr_segment_games_df
# Out:
#    test_group event_type   click_type ltr_segment  customers  gross_count  \
# 0     control       None         None          HH      64553       149254
# 1     control       None         None         PHH     285313      1050787
# 2     control       None         None     UNKNOWN       9526        24583
# 3     control       None         None        None      20818        45829
# 4        test     viewed  close_click          HH      48780        97137
# 5        test     viewed  close_click         PHH     214492       560687
# 6        test     viewed  close_click     UNKNOWN       5578        12573
# 7        test     viewed  close_click        None      11718        25010
# 8        test     viewed   play_click          HH       4707         8819
# 9        test     viewed   play_click         PHH      21236        46149
# 10       test     viewed   play_click     UNKNOWN        688         1470
# 11       test     viewed   play_click        None       1279         2813
# 12       test     viewed         None          HH       1072         1834
# 13       test     viewed         None         PHH       7653        15767
# 14       test     viewed         None     UNKNOWN        136          289
# 15       test     viewed         None        None        264          498
# 16       test       None         None          HH      21442        42754
# 17       test       None         None         PHH     141410       431537
# 18       test       None         None     UNKNOWN       4492        10246
# 19       test       None         None        None       9961        18036
#
#     net_count    g2n    aor  median_cobrm_time  median_cobra_time  \
# 0       63920  42.83  62.85                114                144
# 1      499143  47.50  65.02                105                130
# 2        5458  22.20  55.38                 86                133
# 3       18648  40.69  62.22                116                147
# 4       41451  42.67  62.48                127                145
# 5      264166  47.11  64.52                111                132
# 6        3028  24.08  55.58                 90                139
# 7        9913  39.64  60.94                111                150
# 8        3482  39.48  61.75                138                143
# 9       20212  43.80  62.10                104                127
# 10        275  18.71  57.82                 78                135
# 11        952  33.84  56.99                 68                141
# 12        742  40.46  66.47                140                122
# 13       8050  51.06  70.91                118                135
# 14         36  12.46  58.13                 65                112
# 15        143  28.71  59.04                114                120
# 16      19383  45.34  65.50                114                140
# 17     205620  47.65  64.89                103                127
# 18       2191  21.38  56.88                 75                125
# 19       7516  41.67  63.55                 87                142
#
#     median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                 361                       190                      15
# 1                 302                       170                      14
# 2                 304                       168                      14
# 3                 437                       213                      14
# 4                 370                       195                      14
# 5                 311                       172                      15
# 6                 269                       162                      13
# 7                 414                       210                      14
# 8                 392                       203                      15
# 9                 300                       164                      16
# 10                290                       177                      13
# 11                439                       191                      14
# 12                386                       203                      12
# 13                311                       189                      13
# 14                350                       175                      10
# 15                565                       223                      16
# 16                343                       185                      13
# 17                292                       164                      15
# 18                337                       164                      14
# 19                414                       193                      13
#
#     % cobrm  % cobra  % ocara  % expired  cobrm   cobra   ocara  expired
# 0      2.23    20.46    19.54      14.43   3335   30531   29163    21530
# 1      1.44    21.81    17.19      11.71  15154  229144  180613   123061
# 2      7.75    19.54    32.59      17.30   1906    4803    8011     4252
# 3      2.71    18.73    20.87      16.30   1243    8584    9565     7469
# 4      2.17    20.10    19.35      15.21   2105   19526   18793    14776
# 5      1.43    21.99    17.07      12.04   8035  123306   95736    67506
# 6      5.78    20.09    30.85      18.50    727    2526    3879     2326
# 7      2.85    19.36    20.68      16.82    713    4841    5173     4207
# 8      2.36    19.65    21.65      16.20    208    1733    1909     1429
# 9      1.61    22.64    17.96      13.62    743   10447    8290     6287
# 10     5.78    18.78    38.78      17.62     85     276     570      259
# 11     5.79    18.88    22.36      18.31    163     531     629      515
# 12     1.91    14.45    25.30      17.01     35     265     464      312
# 13     0.93    16.41    19.45      11.71    146    2587    3067     1847
# 14     6.92    15.92    45.67      19.03     20      46     132       55
# 15     2.21    16.27    28.92      22.29     11      81     144      111
# 16     2.11    19.50    19.69      12.85    903    8337    8418     5494
# 17     1.39    22.14    16.93      11.55   6014   95544   73052    49863
# 18     9.64    18.21    34.97      15.24    988    1866    3583     1562
# 19     5.12    16.59    21.41      14.70    924    2993    3861     2652

# %%
retention_segment_games_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240915' 
        and event_props_campaign_id = '1725970812' 
),

segment AS (
    
    SELECT
        customer_id,
        taxi_ltr_segment ltr_segment,
        taxi_retention_segments retention_segment,
        taxi_lifetime_stage lifetime_stage,
        taxi_service_affinity service_affinity,
        gender_tag gender
    FROM
        datasets.iallocator_customer_segments
    WHERE 
        run_date = '2024-09-11'
    
),

merge as(
        select rr_net.*,
        view_tbl.event_type,
        click_tbl.click_type,
        segment.retention_segment
        from 
            rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        LEFT JOIN 
            segment
        ON rr_net.customer_id=segment.customer_id
        )

SELECT
        test_group,
        event_type,
        click_type,
        retention_segment,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            retention_segment,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

    
    
    
    
"""
retention_segment_games_df=pd.read_sql(retention_segment_games_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/3682328015.py:182: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   retention_segment_games_df=pd.read_sql(retention_segment_games_query,conn)

# %%
retention_segment_games_df
# Out:
#    test_group event_type   click_type retention_segment  customers  \
# 0     control       None         None           DORMANT      53528
# 1     control       None         None             ELITE      61979
# 2     control       None         None              GOLD      64497
# 3     control       None         None                HH      36905
# 4     control       None         None          INACTIVE      25267
# 5     control       None         None          PLATINUM      68828
# 6     control       None         None             PRIME       3418
# 7     control       None         None            SILVER      35444
# 8     control       None         None           UNKNOWN       9526
# 9     control       None         None              None      20818
# 10       test     viewed  close_click           DORMANT      39107
# 11       test     viewed  close_click             ELITE      48361
# 12       test     viewed  close_click              GOLD      48993
# 13       test     viewed  close_click                HH      28717
# 14       test     viewed  close_click          INACTIVE      17149
# 15       test     viewed  close_click          PLATINUM      52566
# 16       test     viewed  close_click             PRIME       2666
# 17       test     viewed  close_click            SILVER      25713
# 18       test     viewed  close_click           UNKNOWN       5578
# 19       test     viewed  close_click              None      11718
# 20       test     viewed   play_click           DORMANT       3540
# 21       test     viewed   play_click             ELITE       5790
# 22       test     viewed   play_click              GOLD       4368
# 23       test     viewed   play_click                HH       2789
# 24       test     viewed   play_click          INACTIVE       1635
# 25       test     viewed   play_click          PLATINUM       5245
# 26       test     viewed   play_click             PRIME        393
# 27       test     viewed   play_click            SILVER       2183
# 28       test     viewed   play_click           UNKNOWN        688
# 29       test     viewed   play_click              None       1279
# 30       test     viewed         None           DORMANT        852
# 31       test     viewed         None             ELITE       2742
# 32       test     viewed         None              GOLD       1442
# 33       test     viewed         None                HH        671
# 34       test     viewed         None          INACTIVE        354
# 35       test     viewed         None          PLATINUM       1939
# 36       test     viewed         None             PRIME        132
# 37       test     viewed         None            SILVER        593
# 38       test     viewed         None           UNKNOWN        136
# 39       test     viewed         None              None        264
# 40       test       None         None           DORMANT      16665
# 41       test       None         None             ELITE      45400
# 42       test       None         None              GOLD      27165
# 43       test       None         None                HH      13434
# 44       test       None         None          INACTIVE       8339
# 45       test       None         None          PLATINUM      35898
# 46       test       None         None             PRIME       2707
# 47       test       None         None            SILVER      13244
# 48       test       None         None           UNKNOWN       4492
# 49       test       None         None              None       9961
#
#     gross_count  net_count    g2n    aor  median_cobrm_time  \
# 0        112442      44427  39.51  60.25              117.0
# 1        387715     194261  50.10  66.84               97.0
# 2        189977      88117  46.38  64.21              110.0
# 3         93157      43364  46.55  64.91              114.0
# 4         50782      19305  38.02  60.09              110.0
# 5        259935     121979  46.93  64.32              102.0
# 6         23178      12582  54.28  70.48               97.0
# 19   4841   5173     4207
# 20   1407   1398     1179
# 21   3454   2489     1799
# 22   1850   1548     1139
# 23   1032   1061      828
# 24    633    693      561
# 25   2803   2089     1519
# 26    196    148       83
# 27    805    773      608
# 28    276    570      259
# 29    531    629      515
# 30    263    365      192
# 31   1022   1169      708
# 32    434    524      294
# 33    160    263      191
# 34     90    173      126
# 35    686    738      479
# 36     51     52       13
# 37    146    247      156
# 38     46    132       55
# 39     81    144      111
# 40   6613   6430     4578
# 41  41866  30655    19823
# 42  14610  11485     8367
# 43   5624   4870     3365
# 44   2948   3460     2312
# 45  23756  17683    12271
# 46   2913   1920      997
# 47   5551   4967     3644
# 48   1866   3583     1562
# 49   2993   3861     2652

# %%
service_games_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240915' 
        and event_props_campaign_id = '1725970812' 
),

segment AS (
    
    SELECT
        customer_id,
        taxi_ltr_segment ltr_segment,
        taxi_retention_segments retention_segment,
        taxi_lifetime_stage lifetime_stage,
        taxi_service_affinity service_affinity,
        gender_tag gender
    FROM
        datasets.iallocator_customer_segments
    WHERE 
        run_date = '2024-09-11'
    
),

merge as(
        select rr_net.*,
        view_tbl.event_type,
        click_tbl.click_type,
        segment.retention_segment
        from 
            rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        LEFT JOIN 
            segment
        ON rr_net.customer_id=segment.customer_id
        )

SELECT
        test_group,
        event_type,
        click_type,
        service_category,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            service_category,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

    
    
    
    
"""
service_games_df=pd.read_sql(service_games_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/1397612730.py:188: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   service_games_df=pd.read_sql(service_games_query,conn)

# %%
service_games_df
# Out:
#    test_group event_type   click_type service_category  customers  \
# 0     control       None         None             auto     159326
# 1     control       None         None             bike     235395
# 2     control       None         None              cab     106732
# 3        test     viewed  close_click             auto     110778
# 4        test     viewed  close_click             bike     164673
# 5        test     viewed  close_click              cab      71323
# 6        test     viewed   play_click             auto       9908
# 7        test     viewed   play_click             bike      16615
# 8        test     viewed   play_click              cab       6225
# 9        test     viewed         None             auto       3084
# 10       test     viewed         None             bike       5464
# 11       test     viewed         None              cab       1975
# 12       test       None         None             auto      68654
# 13       test       None         None             bike     111244
# 14       test       None         None              cab      43725
#
#     gross_count  net_count    g2n    aor  median_cobrm_time  \
# 0        405395     136774  33.74  47.64                112
# 1        625683     353743  56.54  76.42                104
# 2        239375      96652  40.38  61.77                 81
# 3        230277      77616  33.71  47.52                116
# 4        327911     185867  56.68  76.62                112
# 5        137219      55075  40.14  61.19                 92
# 6         18947       5713  30.15  44.29                111
# 7         28989      15159  52.29  74.17                 97
# 8         11315       4049  35.78  58.91                 58
# 9          5616       2118  37.71  53.85                121
# 10         9407       5393  57.33  79.89                110
# 11         3365       1460  43.39  69.03                 83
# 12       154679      52506  33.95  47.86                108
# 13       259831     146145  56.25  75.56                 91
# 14        88063      36059  40.95  62.44                 81
#
#     median_cobra_time  median_ocara_time  median_cancellation_time  \
# 0                 129                289                       153
# 1                 128                314                       184
# 2                 147                340                       196
# 3                 131                297                       155
# 4                 130                326                       188
# 5                 151                354                       203
# 6                 129                295                       151
# 7                 123                324                       182
# 8                 149                337                       200
# 9                 134                294                       164
# 10                126                329                       203
# 11                146                342                       227
# 12                127                276                       148
# 13                126                304                       175
# 14                143                330                       192
#
#     median_acceptance_time  % cobrm  % cobra  % ocara  % expired  cobrm  \
# 0                       15     2.91    27.80    13.86      21.64  11789
# 1                       15     1.13    17.04    19.22       5.39   7056
# 2                       13     1.17    22.44    21.26      14.57   2793
# 3                       15     2.98    27.56    13.77      21.94   6862
# 4                       15     1.03    16.85    19.26       5.47   3374
# 5                       14     0.98    22.95    20.93      14.83   1344
# 6                       15     3.44    27.82    14.07      24.44    651
# 7                       16     1.43    17.96    21.13       6.42    415
# 8                       14     1.18    22.19    23.04      17.66    133
# 9                       13     1.98    21.37    16.04      22.79    111
# 10                      12     0.82    13.55    21.80       5.72     77
# 11                      12     0.71    14.98    25.41      15.07     24
# 12                      15     2.82    28.21    13.87      21.11   4364
# 13                      15     1.32    17.61    18.72       5.49   3438
# 14                      13     1.17    21.97    21.37      14.39   1027
#
#      cobra   ocara  expired
# 0   112712   56197    87719
# 1   106629  120262    33714
# 2    53721   50893    34879
# 3    63453   31707    50519
# 4    55258   63154    17948
# 5    31488   28720    20348
# 6     5271    2665     4631
# 7     5205    6126     1861
# 8     2511    2607     1998
# 9     1200     901     1280
# 10    1275    2051      538
# 11     504     855      507
# 12   43633   21452    32649
# 13   45757   48640    14253
# 14   19350   18822    12669

# %%
overall_cluster_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN pickup_cluster IN (              
                'Gurgaon Rural', 
                'NCR N sec 6354', 
                'Dashrathpuri_Del_East', 
                'NCR N sec 2262', 
                'NCR N Sharda University 2', 
                'NCR N Gharoli', 
                'NCR G Vijay Nagar 2', 
                'NCR N Venice Mall', 
                'Dwarka_Del', 
                'NCR N WaveCity Center'
            ) THEN pickup_cluster
            ELSE 'Other_clusters'
        END AS cluster_name,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916' 
        and event_props_campaign_id = '1725970812' 
),

merge as(
        select rr_net.*,view_tbl.event_type,click_tbl.click_type
        from rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        )

SELECT
        test_group,
        event_type,
        click_type,
        cluster_name,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            cluster_name,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

                    
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4   
    
"""
overall_cluster=pd.read_sql(overall_cluster_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/4261486077.py:168: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_cluster=pd.read_sql(overall_cluster_query,conn)

# %%
overall_cluster
# Out:
#    test_group event_type  click_type               cluster_name  customers  \
# 18       test     viewed  play_click      Dashrathpuri_Del_East        696
# 19       test     viewed  play_click                 Dwarka_Del        213
# 20       test     viewed  play_click              Gurgaon Rural        316
# 21       test     viewed  play_click        NCR G Vijay Nagar 2        474
# 22       test     viewed  play_click              NCR N Gharoli        673
# 23       test     viewed  play_click  NCR N Sharda University 2        536
# 24       test     viewed  play_click          NCR N Venice Mall        377
# 25       test     viewed  play_click      NCR N WaveCity Center        273
# 26       test     viewed  play_click             Other_clusters      30158
#
#     gross_count  net_count    g2n    aor  median_cobrm_time  \
# 18         1195        530  44.35  66.03              178.0
# 19          315        159  50.48  67.94              201.0
# 20          554        238  42.96  60.65               37.0
# 21          640        408  63.75  81.09                NaN
# 22          972        540  55.56  77.26               76.0
# 23         1054        299  28.37  43.64               58.0
# 24          866        280  32.33  46.88              145.0
# 25          394        216  54.82  78.43              188.0
# 26        62339      27458  44.05  64.05              103.0
#
#     median_cobra_time  median_ocara_time  median_cancellation_time  \
# 18                143                342                       194
# 19                124                204                       145
# 20                141                317                       176
# 21                126                283                       176
# 22                135                367                       214
# 23                107                296                       123
# 24                121                255                       143
# 25                121                377                       211
# 26                130                318                       174
#
#     median_acceptance_time  % cobrm  % cobra  % ocara  % expired  cobrm  \
# 18                      19     0.42    24.02    21.34       9.54      5
# 19                      12     0.63    17.46    16.19      13.97      2
# 20                      14     0.18    25.81    17.51      13.36      1
# 21                      12     0.00    15.00    17.19       3.91      0
# 22                      15     0.62    14.09    21.09       8.02      6
# 23                      10     1.23    40.80    14.99      14.33     13
# 24                      10     7.27    33.60    13.97      12.24     63
# 25                      12     0.25    15.48    22.84       5.84      1
# 26                      15     1.98    20.30    19.59      13.64   1235
#
#     cobra  ocara  expired
# 18    287    255      114
# 19     55     51       44
# 20    143     97       74
# 21     96    110       25
# 22    137    205       78
# 23    430    158      151
# 24    291    121      106
# 25     61     90       23
# 26  12652  12214     8502

# %%
overall_cluster=overall_cluster[overall_cluster['click_type']=='play_click']

# %%
overall_cluster.to_clipboard(index=False)

# %%
overall_cluster_session_query=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN pickup_cluster IN (
                'Gurgaon Rural', 
                'NCR N sec 6354', 
                'Dashrathpuri_Del_East', 
                'NCR N sec 2262', 
                'NCR N Sharda University 2', 
                'NCR N Gharoli', 
                'NCR G Vijay Nagar 2', 
                'NCR N Venice Mall', 
                'Dwarka_Del', 
                'NCR N WaveCity Center'
            ) THEN pickup_cluster
            ELSE 'Other_clusters'
        END AS cluster_name,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
),





view_tbl as(
        select 
            profile_identity as user_id,
            yyyymmdd,
            'viewed' as event_type
        from
            clevertap.customer_notification_viewed_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        and event_props_campaign_id = '1725970812' 

),

click_tbl as(
        select
            profile_identity as user_id,
            CASE
                when event_props_wzrk_c2a='Button 2' then 'play_click'
                else 'close_click'
            end as click_type,
            yyyymmdd
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916' 
        and event_props_campaign_id = '1725970812' 
),

merge as(
        select rr_net.*,view_tbl.event_type,click_tbl.click_type
        from rr_net
        left join 
            view_tbl
                on rr_net.customer_id=view_tbl.user_id
                and rr_net.yyyymmdd=view_tbl.yyyymmdd
        left join 
            click_tbl
            on view_tbl.user_id=click_tbl.user_id
            and view_tbl.yyyymmdd=click_tbl.yyyymmdd
        )

SELECT
        test_group,
        event_type,
        click_type,
        time_period,
        cluster_name,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            cluster_name,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

                    
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4,5
        )
    ORDER BY 1,2,3,4,5  
    
"""
overall_cluster_session=pd.read_sql(overall_cluster_session_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/1746420347.py:176: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_cluster_session=pd.read_sql(overall_cluster_session_query,conn)

# %%
overall_cluster_session=overall_cluster_session[overall_cluster_session['click_type']=='play_click']

# %%
overall_cluster_session
# Out:
#     test_group event_type  click_type   time_period  \
# 90        test     viewed  play_click     afternoon
# 91        test     viewed  play_click     afternoon
# 92        test     viewed  play_click     afternoon
# 93        test     viewed  play_click     afternoon
# 94        test     viewed  play_click     afternoon
# 95        test     viewed  play_click     afternoon
# 96        test     viewed  play_click     afternoon
# 97        test     viewed  play_click     afternoon
# 98        test     viewed  play_click     afternoon
# 99        test     viewed  play_click       evening
# 100       test     viewed  play_click       evening
# 101       test     viewed  play_click       evening
# 102       test     viewed  play_click       evening
# 103       test     viewed  play_click       evening
# 104       test     viewed  play_click       evening
# 105       test     viewed  play_click       evening
# 106       test     viewed  play_click       evening
# 107       test     viewed  play_click       evening
# 108       test     viewed  play_click       morning
# 109       test     viewed  play_click       morning
# 110       test     viewed  play_click       morning
# 111       test     viewed  play_click       morning
# 112       test     viewed  play_click       morning
# 113       test     viewed  play_click       morning
# 114       test     viewed  play_click       morning
# 115       test     viewed  play_click       morning
# 116       test     viewed  play_click       morning
# 117       test     viewed  play_click  rest_evening
# 118       test     viewed  play_click  rest_evening
# 119       test     viewed  play_click  rest_evening
# 120       test     viewed  play_click  rest_evening
# 121       test     viewed  play_click  rest_evening
# 122       test     viewed  play_click  rest_evening
# 123       test     viewed  play_click  rest_evening
# 124       test     viewed  play_click  rest_evening
# 125       test     viewed  play_click  rest_evening
# 126       test     viewed  play_click  rest_morning
# 127       test     viewed  play_click  rest_morning
# 128       test     viewed  play_click  rest_morning
# 129       test     viewed  play_click  rest_morning
# 130       test     viewed  play_click  rest_morning
# 131       test     viewed  play_click  rest_morning
# 132       test     viewed  play_click  rest_morning
# 133       test     viewed  play_click  rest_morning
# 134       test     viewed  play_click  rest_morning
#
#                   cluster_name  customers  gross_count  net_count    g2n  \
# 90       Dashrathpuri_Del_East        262          440        192  43.64
# 91                  Dwarka_Del         79           99         62  62.63
# 92               Gurgaon Rural        134          221         93  42.08
# 93         NCR G Vijay Nagar 2        170          196        162  82.65
# 94               NCR N Gharoli        220          269        182  67.66
# 95   NCR N Sharda University 2        287          498        154  30.92
# 96           NCR N Venice Mall        153          263        117  44.49
# 97       NCR N WaveCity Center         77           97         67  69.07
# 98              Other_clusters      11680        18762       9941  52.98
# 99       Dashrathpuri_Del_East        192          309        122  39.48
# 100                 Dwarka_Del         66          104         38  36.54
# 101              Gurgaon Rural         96          143         72  50.35
# 102        NCR G Vijay Nagar 2        116          142         88  61.97
# 103              NCR N Gharoli        191          295        137  46.44
# 104  NCR N Sharda University 2        202          410         73  17.80
# 105          NCR N Venice Mall        143          257         85  33.07
# 106      NCR N WaveCity Center         71           85         50  58.82
# 107             Other_clusters      11541        20983       7490  35.70
# 108      Dashrathpuri_Del_East        145          193         91  47.15
# 109                 Dwarka_Del         33           43         30  69.77
# 110              Gurgaon Rural         76          127         44  34.65
# 111        NCR G Vijay Nagar 2        131          175         89  50.86
# 112              NCR N Gharoli        151          191        118  61.78
# 113  NCR N Sharda University 2         88          120         61  50.83
# 114          NCR N Venice Mall         89          245         51  20.82
# 115      NCR N WaveCity Center         89          142         61  42.96
# 116             Other_clusters       6853        10613       5033  47.42
# 117      Dashrathpuri_Del_East         87          125         59  47.20
# 118                 Dwarka_Del         28           41         18  43.90
# 119              Gurgaon Rural         24           32         14  43.75
f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN pickup_cluster IN (
                'Gurgaon Rural', 
                'NCR N sec 6354', 
                'Dashrathpuri_Del_East', 
                'NCR N sec 2262', 
                'NCR N Sharda University 2', 
                'NCR N Gharoli', 
                'NCR G Vijay Nagar 2', 
                'NCR N Venice Mall', 
                'Dwarka_Del', 
                'NCR N WaveCity Center'
            ) THEN pickup_cluster
            ELSE 'Other_clusters'
        END AS cluster_name,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
)








SELECT
        
        cluster_name,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            cluster_name,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

                    
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            rr_net
        where 
            yyyymmdd is not null
           
        GROUP BY 1
        )
    ORDER BY 1
    
"""

city_benchmark_df=pd.read_sql(city_benchmark,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/3457448014.py:127: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   city_benchmark_df=pd.read_sql(city_benchmark,conn)

# %%
city_benchmark_df
# Out:
#                 cluster_name  customers  gross_count  net_count    g2n    aor  \
# 0      Dashrathpuri_Del_East      21963        49745      24594  49.44  68.05
# 1                 Dwarka_Del       6807        14768       8369  56.67  72.68
# 2              Gurgaon Rural      10184        24206      11306  46.71  63.46
# 3        NCR G Vijay Nagar 2      15108        31759      20789  65.46  82.94
# 4              NCR N Gharoli      20586        43528      25924  59.56  79.88
# 5  NCR N Sharda University 2      16499        47285      14783  31.26  44.85
# 6          NCR N Venice Mall      11798        33623      13178  39.19  54.00
# 7      NCR N WaveCity Center       8797        17596      10641  60.47  80.77
# 8             Other_clusters     808280      2732646    1323003  48.41  66.87
#
#    median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0                110                136                343
# 1                116                141                318
# 2                 99                132                306
# 3                 82                132                276
# 4                101                130                321
# 5                 82                109                264
# 6                100                118                282
# 7                 98                127                306
# 8                107                132                311
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       186                      18     0.59    21.09
# 1                       182                      12     0.91    17.65
# 2                       169                      15     0.43    23.08
# 3                       179                      11     0.68    12.49
# 4                       199                      14     0.54    14.03
# 5                       126                      10     1.30    37.65
# 6                       138                       9     5.81    27.90
# 7                       192                      11     0.83    13.40
# 8                       176                      14     1.65    19.92
#
#    % ocara  % expired  cobrm   cobra   ocara  expired
# 0    18.30      10.26    293   10489    9103     5104
# 1    15.59       8.71    134    2607    2303     1287
# 2    16.56      13.02    103    5587    4008     3152
# 3    17.05       3.88    216    3967    5414     1233
# 4    19.86       5.53    237    6106    8644     2409
# 5    13.19      16.19    616   17801    6238     7657
# 6    14.27      12.29   1952    9380    4799     4131
# 7    19.93       4.99    146    2357    3507      878
# 8    18.08      11.54  45170  544351  494092   315265

# %%
city_benchmark_df.to_clipboard(index=False)

# %%
city_benchmark_s_c=f"""
with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN pickup_cluster IN (
                'Gurgaon Rural', 
                'NCR N sec 6354', 
                'Dashrathpuri_Del_East', 
                'NCR N sec 2262', 
                'NCR N Sharda University 2', 
                'NCR N Gharoli', 
                'NCR G Vijay Nagar 2', 
                'NCR N Venice Mall', 
                'Dwarka_Del', 
                'NCR N WaveCity Center'
            ) THEN pickup_cluster
            ELSE 'Other_clusters'
        END AS cluster_name,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        case when SUBSTR(customer_id, -1) in ('1','3','5','7','9','e','a','d') then 'test' else 'control' end as test_group
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Delhi'
            and platform='Android'
            and app_version>='8.30.0'
            
            
            )
)



SELECT
        time_period,
        cluster_name,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            cluster_name,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

                    
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            rr_net
        where 
            yyyymmdd is not null
           
        GROUP BY 1,2
        )
    ORDER BY 1,2
    
"""

city_benchmark_s_c_df=pd.read_sql(city_benchmark_s_c,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_31458/3988337630.py:129: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   city_benchmark_s_c_df=pd.read_sql(city_benchmark_s_c,conn)

# %%
city_benchmark_s_c_df
# Out:
#      time_period               cluster_name  customers  gross_count  \
# 0      afternoon              Gurgaon Rural       4683         8827
# 1      afternoon              NCR N Gharoli       7834        11781
# 2      afternoon  NCR N Sharda University 2       9633        20524
# 3      afternoon            NCR N sec 22/62       5217         7748
# 4      afternoon             Other_clusters     382059       791101
# 5      afternoon                    Sec-10A       3659         6938
# 6      afternoon                     Sec-39       4393         7301
# 7      afternoon                     Sec-55       3681         6365
# 8      afternoon                     Sec-57       5709         9801
# 9      afternoon               Sector 45-46       4835         7691
# 10       evening              Gurgaon Rural       3159         5680
# 11       evening              NCR N Gharoli       6953        13150
# 12       evening  NCR N Sharda University 2       7481        19014
# 13       evening            NCR N sec 22/62       6257        13669
# 14       evening             Other_clusters     357749       860545
# 15       evening                    Sec-10A       2429         4448
# 16       evening                     Sec-39       4355        10017
# 17       evening                     Sec-55       3865         9397
# 18       evening                     Sec-57       5017        10924
# 19       evening               Sector 45-46       5841        12817
# 20       morning              Gurgaon Rural       2881         6450
# 21       morning              NCR N Gharoli       5414        10915
# 22       morning  NCR N Sharda University 2       3044         5160
# 23       morning            NCR N sec 22/62       3351         7632
# 24       morning             Other_clusters     240723       529861
# 25       morning                    Sec-10A       2587         5097
# 26       morning                     Sec-39       3666         8379
# 27       morning                     Sec-55       2701         6129
# 28       morning                     Sec-57       4330        11055
# 29       morning               Sector 45-46       4300        10395
# 30  rest_evening              Gurgaon Rural        866         1410
# 31  rest_evening              NCR N Gharoli       2214         3389
# 32  rest_evening  NCR N Sharda University 2        839         1353
# 33  rest_evening            NCR N sec 22/62       1300         2144
# 34  rest_evening             Other_clusters     139691       255474
# 35  rest_evening                    Sec-10A        717         1231
# 36  rest_evening                     Sec-39       1240         1989
# 37  rest_evening                     Sec-55       1115         1802
# 38  rest_evening                     Sec-57       1381         2257
# 39  rest_evening               Sector 45-46       1524         2513
# 40  rest_morning              Gurgaon Rural        967         1839
# 41  rest_morning              NCR N Gharoli       2414         4293
# 42  rest_morning  NCR N Sharda University 2        633         1234
# 43  rest_morning            NCR N sec 22/62       1303         2507
# 44  rest_morning             Other_clusters     129607       261217
# 45  rest_morning                    Sec-10A        919         1795
# 46  rest_morning                     Sec-39       1254         2358
# 47  rest_morning                     Sec-55       1075         2181
# 48  rest_morning                     Sec-57       1439         2748
# 49  rest_morning               Sector 45-46       1341         2611
# 47     5.23    19.99    15.96       8.99    114     436     348      196
# 48     4.84    18.34    15.32       8.44    133     504     421      232
# 49     2.87    22.06    15.66       8.92     75     576     409      233

# %%
city_benchmark_s_c_df.to_clipboard(index=False)

# %%
click_bucket=f"""
with olf as (

    SELECT
        yyyymmdd,
        customer_id,
        order_id,
        order_requested_epoch,
        customer_cancelled_epoch,
        dropped_epoch,
        expired_epoch,
        rider_accepted_epoch
        
    FROM 
        orders.order_logs_fact
    WHERE
        yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        
    ),




click as(
select
           yyyymmdd,
           profile_identity as user_id,
            epoch as click_epoch
        from
            clevertap.customer_notification_clicked_immutable 
        where yyyymmdd >= '20240911' AND yyyymmdd <= '20240916' 
        and event_props_wzrk_c2a='Button 2'
        and event_props_campaign_id = '1725970812' 
        
        -- group by 1,2
        
),


merge AS (
    
    SELECT 
        olf.*,
        click_epoch,
        (click_epoch / 1000 - order_requested_epoch / 1000) time_to_click
        --row_number() over(partition by olf.yyyymmdd,olf.customer_id,olf.order_id order by click_epoch) seq_no
    FROM 
        olf
    JOIN 
        click
        on olf.yyyymmdd = click.yyyymmdd
        and olf.customer_id = click.user_id
        and olf.order_requested_epoch < click.click_epoch
        and (olf.customer_cancelled_epoch > click.click_epoch or dropped_epoch > click.click_epoch or 
        expired_epoch > click.click_epoch or rider_accepted_epoch> click.click_epoch)
    )
    
    
   
    
    
    SELECT
        
        case 
        when time_to_click <= 15 then 'a. 15 Sec'
        when time_to_click between 16 and 30 then 'b. 16-30 Sec'
        when time_to_click between 31 and 60 then 'c. 30-60 Sec'
        when time_to_click between 61 and 120 then 'd. 1-2 min'
        when time_to_click between 121 and 240 then 'e. 3-4 min'
        when time_to_click > 240 then 'f. 4+ min' 
        else 'check' end as click_bucket,
        count(distinct customer_id) customers
    FROM 
        merge
    -- WHERE 
    --     --seq_no = 1
    GROUP BY 1
    ORDER BY 1

"""
click_bucket_df = pd.read_sql(click_bucket,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62370/3278354793.py:84: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   click_bucket_df = pd.read_sql(click_bucket,conn)

# %%
click_bucket_df
# Out:
#    click_bucket  customers
# 0     a. 15 Sec      27299
# 1  b. 16-30 Sec       3613
# 2  c. 30-60 Sec       1438
# 3    d. 1-2 min        865
# 4    e. 3-4 min        659
# 5     f. 4+ min        519

# %%
click_bucket_df.to_clipboard(index=False)

# %%
32360-34393
# Out:
# -2033

# %%
27299-2033
# Out:
# 25266

# %%
click_bucket_df.customers.sum()
# Out:
# 34393

# %%
total_customers = click_bucket_df['customers'].sum()

# Calculate the percentage of customers for each click_bucket
click_bucket_df['customer_percentage'] = (click_bucket_df['customers'] / total_customers) * 100

# Round the percentage to 2 decimal places
click_bucket_df['customer_percentage'] = click_bucket_df['customer_percentage'].round(2)
