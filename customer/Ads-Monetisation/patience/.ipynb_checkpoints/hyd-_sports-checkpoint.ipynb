# %%
import re
import os 
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from pyhive import presto
from datetime import date
from collections import Counter

from scipy import stats
from pyhive import presto
from datetime import datetime, timedelta

presto_port = '80'
username = 'manoj.ravirajan@rapido.bike'

conn=presto.connect('presto-gateway.processing.data.production.internal',presto_port,username)

connection1 = presto.connect('bi-presto.serving.data.production.internal', presto_port, username)
connection2 = presto.connect('bi-trino-2.serving.data.production.internal', presto_port, username)
connection3= presto.connect('processing-2.processing.data.production.internal',presto_port,username)
connection4= presto.connect('processing.processing.data.production.internal',presto_port,username)


pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Overall

# %%
overall_query=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),
merge as(
    select exp_category.*,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd

)

SELECT
        test_group,
        -- event_type,
        -- click_type,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            -- event_type,
            -- click_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1
        )
    ORDER BY 1,2,3

"""

overall_sports=pd.read_sql(overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62376/2332381144.py:179: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_sports=pd.read_sql(overall_query,conn)

# %%
overall_sports
# Out:
#   test_group  customers  gross_count  net_count    g2n    aor  \
# 0    control      49649       146295     100582  68.75  85.58
# 1       test      49282       148749     102576  68.96  85.71
#
#    median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0                 83                108                255
# 1                 66                108                245
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       159                      10     0.59    10.66
# 1                       157                      10     0.63    10.45
#
#    % ocara  % expired  cobrm  cobra  ocara  expired
# 0    16.39       3.16    860  15601  23981     4628
# 1    16.32       3.20    941  15538  24271     4761

# %%
overall_sports.to_clipboard(index=False)

# %%
overall_query=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),
merge as(
    select exp_category.*,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd

)

SELECT
        test_group,
        event_type,
        click_type,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3

"""

overall_sportsl1=pd.read_sql(overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62376/3688866530.py:179: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_sportsl1=pd.read_sql(overall_query,conn)

# %%
overall_sportsl1
# Out:
#   test_group event_type   click_type  customers  gross_count  net_count  \
# 0    control       None         None      49649       146295     100582
# 1       test     viewed  close_click      36440       104935      72217
# 2       test     viewed   play_click       2178         4092       2498
# 3       test     viewed         None       1396         2740       1784
# 4       test       None         None      15462        37054      26100
#
#      g2n    aor  median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0  68.75  85.58                 83                108                255
# 1  68.82  85.41                 67                109                247
# 2  61.05  81.84                 39                 97                203
# 3  65.11  86.75                 41                108                183
# 4  70.44  86.90                 75                106                248
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# ...

# %%
overall_sportsl1.to_clipboard(index=False)

# %%
overall_sports.to_csv('overall_sports.csv',index=False)

# %% [markdown]
# ## Pre-post

# %%
overall_query=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240910'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240905' AND yyyymmdd <= '20240910'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240905' AND yyyymmdd <= '20240910'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240905' AND yyyymmdd <= '20240910'
    and event_props_campaign_id = '1725971334'

),
merge as(
    select exp_category.*,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd

)

SELECT
        test_group,
        -- event_type,
        -- click_type,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            -- event_type,
            -- click_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1
        )
    ORDER BY 1,2,3

"""

overall_sportspre=pd.read_sql(overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62376/3545597203.py:179: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_sportspre=pd.read_sql(overall_query,conn)

# %%
overall_sportspre
# Out:
#   test_group  customers  gross_count  net_count    g2n    aor  \
# 0    control      48765       154753      90750  58.64  74.62
# 1       test      48702       156637      92985  59.36  75.22
#
#    median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0                 67                117                259
# 1                 74                117                259
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       150                      11     0.66    18.21
# 1                       150                      12     0.70    17.73
#
#    % ocara  % expired  cobrm  cobra  ocara  expired
# 0    15.61       6.51   1026  28176  24158    10076
# 1    15.47       6.34   1096  27769  24234     9935

# %%
overall_sportspre.to_clipboard(index=False)

# %% [markdown]
# ## COBRA TTC

# %%
overall_query=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),
merge as(
    select exp_category.*,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd

)

SELECT
        test_group,
        -- event_type,
        -- click_type,
        cobra_ttc_bucket,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            -- event_type,
            -- click_type,

            CASE 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec <= 15 THEN 'a. 0-15 sec' 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec BETWEEN 16 AND 30 THEN 'b. 16-30 sec' 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec BETWEEN 31 AND 60 THEN 'c. 31-60 sec' 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec BETWEEN 61 AND 180 THEN 'd. 61-180 sec' 
            WHEN modified_order_status = 'COBRA' AND time_spent_in_sec > 180 THEN 'e. 180+ sec' 
            WHEN modified_order_status != 'COBRA' THEN 'f. NO COBRA'
            ELSE 'Check' END cobra_ttc_bucket,
            
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)

           and click_type = 'play_click'
           
        GROUP BY 1,2
        )
    ORDER BY 1,2

"""

overall_sports_ttc=pd.read_sql(overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62376/2534316204.py:193: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_sports_ttc=pd.read_sql(overall_query,conn)

# %%
overall_sports_ttc
# Out:
#   test_group cobra_ttc_bucket  customers  gross_count  net_count    g2n  \
# 0       test      a. 0-15 sec         46           52          0   0.00
# 1       test     b. 16-30 sec         56           58          0   0.00
# 2       test     c. 31-60 sec         61           69          0   0.00
# 3       test    d. 61-180 sec        175          258          0   0.00
# 4       test      e. 180+ sec         95          112          0   0.00
# 5       test      f. NO COBRA       2080         3543       2498  70.51
#
#      aor  median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0   0.00                NaN               11.0                NaN
# 1   0.00                NaN               22.0                NaN
# 2   0.00                NaN               47.0                NaN
# 3   0.00                NaN              112.0                NaN
# 4   0.00                NaN              225.0                NaN
# ...

# %%
overall_sports_ttc.to_clipboard(index=False)

# %% [markdown]
# ## other

# %%
overall_query_daywise=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
                from 
                    clevertap.clevertap_customer_order_activity
                where 
                    yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
                    AND order_activity_source = 'appOpen'
                    and current_city = 'Hyderabad'
                    and platform='Android'
                    and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),
merge as(
    select exp_category.*,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd

)

SELECT
        yyyymmdd,
        test_group,
        event_type,
        click_type,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            yyyymmdd,
            test_group,
            event_type,
            click_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

"""

overall_sports_daywise=pd.read_sql(overall_query_daywise,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/2737540206.py:181: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   overall_sports_daywise=pd.read_sql(overall_query_daywise,conn)

# %%
overall_sports_daywise
# Out:
#     yyyymmdd test_group event_type   click_type  customers  gross_count  \
# 0   20240911    control       None         None      14510        24860
# 1   20240911       test     viewed  close_click       7130        13061
# 2   20240911       test     viewed   play_click        306          637
# 3   20240911       test     viewed         None        216          391
# 4   20240911       test       None         None       7048        11347
# 5   20240912    control       None         None      14706        24791
# 6   20240912       test     viewed  close_click      10648        18566
# 7   20240912       test     viewed   play_click        405          679
# 8   20240912       test     viewed         None        289          508
# 9   20240912       test       None         None       3428         5547
# 10  20240913    control       None         None      15140        25235
# 11  20240913       test     viewed  close_click      11346        19524
# ...

# %%
overall_sports_daywise.to_clipboard(index=False)

# %%
overall_sports_daywise.to_csv('overall_sports_daywise.csv',index=False)

# %%
session_query=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android' 
        AND customer_id in (
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_campaign_id = '1725971334'

),
merge as(
    select exp_category.*,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on rr_net.customer_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd

)

SELECT
        test_group,
        event_type,
        click_type,
        time_period,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

"""

session_sports=pd.read_sql(session_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/2198619014.py:187: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   session_sports=pd.read_sql(session_query,conn)

# %%
session_sports
# Out:
#    test_group event_type   click_type   time_period  customers  gross_count  \
# 0     control       None         None     afternoon      25543        48700
# 1     control       None         None       evening      21187        39943
# 2     control       None         None       morning      14611        27422
# 3     control       None         None  rest_evening       9964        16277
# 4     control       None         None  rest_morning       8736        13907
# 5        test     viewed  close_click     afternoon      18578        34991
# 6        test     viewed  close_click       evening      15335        28553
# 7        test     viewed  close_click       morning      10732        20439
# 8        test     viewed  close_click  rest_evening       7120        11573
# 9        test     viewed  close_click  rest_morning       5959         9363
# 10       test     viewed   play_click     afternoon        886         1360
# ...

# %%
session_sports.to_clipboard(index=False)

# %%
session_sports.to_csv('session_sports.csv',index=False)

# %%
ltr_segment_query=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),

segment AS (
    
    SELECT
        customer_id,
        taxi_ltr_segment ltr_segment,
        taxi_retention_segments retention_segment,
        taxi_lifetime_stage lifetime_stage,
        taxi_service_affinity service_affinity,
        gender_tag gender
    FROM
        datasets.iallocator_customer_segments
    WHERE 
        run_date = '2024-09-11'
    
),


merge as(
    select exp_category.*,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type,
            segment.ltr_segment
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd
    LEFT JOIN 
            segment
        ON rr_net.customer_id=segment.customer_id

)

SELECT
        test_group,
        event_type,
        click_type,
        ltr_segment,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            ltr_segment,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

"""

ltr_segment_sports=pd.read_sql(ltr_segment_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/657598224.py:203: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ltr_segment_sports=pd.read_sql(ltr_segment_query,conn)

# %%
ltr_segment_sports
# Out:
#    test_group event_type   click_type ltr_segment  customers  gross_count  \
# 0     control       None         None          HH       2092         3980
# 1     control       None         None         PHH      41446       114664
# 2     control       None         None     UNKNOWN        125          357
# 3     control       None         None        None          6            6
# 4        test     viewed  close_click          HH       1634         3201
# 5        test     viewed  close_click         PHH      29901        81419
# 6        test     viewed  close_click     UNKNOWN         83          227
# 7        test     viewed   play_click          HH        120          225
# 8        test     viewed   play_click         PHH       1687         3121
# 9        test     viewed   play_click     UNKNOWN         10           32
# 10       test     viewed   play_click        None          1            1
# 11       test     viewed         None          HH         34           72
# ...

# %%
retention_segment_query=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),

segment AS (
    
    SELECT
        customer_id,
        taxi_ltr_segment ltr_segment,
        taxi_retention_segments retention_segment,
        taxi_lifetime_stage lifetime_stage,
        taxi_service_affinity service_affinity,
        gender_tag gender
    FROM
        datasets.iallocator_customer_segments
    WHERE 
        run_date = '2024-09-11'
    
),


merge as(
    select exp_category.*,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type,
            segment.retention_segment
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd
    LEFT JOIN 
            segment
        ON rr_net.customer_id=segment.customer_id

)

SELECT
        test_group,
        event_type,
        click_type,
        retention_segment,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            retention_segment,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

"""

retention_segment_sports=pd.read_sql(retention_segment_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/1887586811.py:203: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   retention_segment_sports=pd.read_sql(retention_segment_query,conn)

# %%
retention_segment_sports
# Out:
#    test_group event_type   click_type retention_segment  customers  \
# 0     control       None         None           DORMANT       5676
# 1     control       None         None             ELITE       8758
# 2     control       None         None              GOLD      10313
# 3     control       None         None                HH       1431
# 4     control       None         None          INACTIVE        384
# 5     control       None         None          PLATINUM      12023
# 6     control       None         None             PRIME        445
# 7     control       None         None            SILVER       4508
# 8     control       None         None           UNKNOWN        125
# 9     control       None         None              None          6
# 10       test     viewed  close_click           DORMANT       4070
# 11       test     viewed  close_click             ELITE       6684
# 12       test     viewed  close_click              GOLD       6979
# ...

# %%
service_query=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),

segment AS (
    
    SELECT
        customer_id,
        taxi_ltr_segment ltr_segment,
        taxi_retention_segments retention_segment,
        taxi_lifetime_stage lifetime_stage,
        taxi_service_affinity service_affinity,
        gender_tag gender
    FROM
        datasets.iallocator_customer_segments
    WHERE 
        run_date = '2024-09-11'
    
),


merge as(
    select exp_category.*,
            rr_net.service_category,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type,
            segment.retention_segment
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd
    LEFT JOIN 
            segment
        ON rr_net.customer_id=segment.customer_id

)

SELECT
        test_group,
        event_type,
        click_type,
        service_category,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            service_category,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

"""

service_sports=pd.read_sql(service_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/728547421.py:210: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   service_sports=pd.read_sql(service_query,conn)

# %%
service_sports
# Out:
#    test_group event_type   click_type service_category  customers  \
# 0     control       None         None             auto      21232
# 1     control       None         None             bike      27130
# 2     control       None         None              cab       5089
# 3        test     viewed  close_click             auto      15504
# 4        test     viewed  close_click             bike      19189
# 5        test     viewed  close_click              cab       3712
# 6        test     viewed   play_click             auto        715
# 7        test     viewed   play_click             bike       1160
# 8        test     viewed   play_click              cab        151
# 9        test     viewed         None             auto        494
# 10       test     viewed         None             bike        698
# 11       test     viewed         None              cab         94
# 12       test       None         None             auto       5764
# ...

# %%
cluster_level=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN pickup_cluster IN (              
                'Hitech City', 
                'Shamshabad', 
                'Kukatpally 3', 
                'Bodduppal', 
                'Mehedipatnam', 
                'Kothaguda 2', 
                'Mothinagar', 
                'Banjara Hills', 
                'Gandipet', 
                'Manikonda',
                'Marredpally'
            ) THEN pickup_cluster
            ELSE 'Other_clusters'
        END AS cluster_name,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),



merge as(
    select exp_category.*,
            rr_net.service_category,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.cluster_name,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type
            
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd
    
)

SELECT
        test_group,
        event_type,
        click_type,
        cluster_name,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            cluster_name,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4

"""

cluster_sports=pd.read_sql(cluster_level,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/1617297090.py:209: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cluster_sports=pd.read_sql(cluster_level,conn)

# %%
cluster_sports=cluster_sports[cluster_sports['click_type']=='play_click']

# %%
cluster_sports
# Out:
#    test_group event_type  click_type    cluster_name  customers  gross_count  \
# 24       test     viewed  play_click   Banjara Hills         45           68
# 25       test     viewed  play_click       Bodduppal         48           72
# 26       test     viewed  play_click        Gandipet         32           46
# 27       test     viewed  play_click     Hitech City         97          135
# 28       test     viewed  play_click     Kothaguda 2         40           59
# 29       test     viewed  play_click    Kukatpally 3         54          102
# 30       test     viewed  play_click       Manikonda         36           54
# 31       test     viewed  play_click     Marredpally         30           37
# 32       test     viewed  play_click    Mehedipatnam         43           65
# 33       test     viewed  play_click      Mothinagar         31           45
# 34       test     viewed  play_click  Other_clusters       1494         2616
# ...

# %%
cluster_sports.to_clipboard(index=False)

# %%
city_cluster_level=f"""


with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN pickup_cluster IN (              
                'Hitech City', 
                'Shamshabad', 
                'Kukatpally 3', 
                'Bodduppal', 
                'Mehedipatnam', 
                'Kothaguda 2', 
                'Mothinagar', 
                'Banjara Hills', 
                'Gandipet', 
                'Manikonda',
                'Marredpally'
            ) THEN pickup_cluster
            ELSE 'Other_clusters'
        END AS cluster_name,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
)



SELECT
        
        cluster_name,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            
            cluster_name,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            rr_net
        where 
            yyyymmdd is not null
           
        GROUP BY 1
        )
    ORDER BY 1

"""

city_cluster_level_sports=pd.read_sql(city_cluster_level,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/1215307344.py:133: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   city_cluster_level_sports=pd.read_sql(city_cluster_level,conn)

# %%
city_cluster_level_sports
# Out:
#       cluster_name  customers  gross_count  net_count    g2n    aor  \
# 0    Banjara Hills      26839        48199      30155  62.56  81.51
# 1        Bodduppal      17235        29578      23840  80.60  94.70
# 2         Gandipet       5888        11493       6298  54.80  74.66
# 3      Hitech City      48650        93937      58193  61.95  79.71
# 4      Kothaguda 2      15429        28542      18166  63.65  81.43
# 5     Kukatpally 3      23890        39811      29656  74.49  91.20
# 6        Manikonda      15328        28261      19683  69.65  87.18
# 7      Marredpally      14962        24039      17707  73.66  90.17
# 8     Mehedipatnam      26973        48199      33653  69.82  87.44
# 9       Mothinagar      14314        26627      17350  65.16  83.74
# 10  Other_clusters     758227      1839171    1269662  69.03  86.29
# 11      Shamshabad      40218        69883      51090  73.11  91.68
#
#     median_cobrm_time  median_cobra_time  median_ocara_time  \
# ...

# %%
city_cluster_level_sports.to_clipboard(index=False)

# %%
cluster_session_level=f"""
with exp_category as(
select
    userid as user_id,
    case    when name='CaptainSearchSportsNewsTest' then 'test' 
            else 'control'
    end as test_group
from
   canonical.user_selector
where
    yyyymmdd = '20240905'
    and selectorid in ('66d9e70d8e21590001b635ac','66d9e97fdac1090001c05d83')

),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN pickup_cluster IN (              
                'Hitech City', 
                'Shamshabad', 
                'Kukatpally 3', 
                'Bodduppal', 
                'Mehedipatnam', 
                'Kothaguda 2', 
                'Mothinagar', 
                'Banjara Hills', 
                'Gandipet', 
                'Manikonda',
                'Marredpally'
            ) THEN pickup_cluster
            ELSE 'Other_clusters'
        END AS cluster_name,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
),

view_tbl as(

    select
        yyyymmdd,
        profile_identity as user_id,
        'viewed' as event_type
    from 
        clevertap.customer_notification_viewed_immutable 
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),

click_tbl as(
    select
        yyyymmdd,
        profile_identity as user_id,
        CASE
                    when event_props_wzrk_c2a='Button 2' then 'play_click'
                    else 'close_click'
        end as click_type
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240915'
    and event_props_campaign_id = '1725971334'

),



merge as(
    select exp_category.*,
            rr_net.service_category,
            rr_net.yyyymmdd,
            rr_net.order_id,
            rr_net.cluster_name,
            rr_net.order_status,
            rr_net.modified_order_status,
            rr_net.spd_fraud_flag,
            rr_net.quarter_hour,
            rr_net.time_spent_in_sec,
            rr_net.time_taken_to_accp,
            view_tbl.event_type,
            click_tbl.click_type
            
    from
        exp_category
    left join 
            rr_net 
        on exp_category.user_id=rr_net.customer_id
    left join
            view_tbl
        on rr_net.customer_id=view_tbl.user_id
           and rr_net.yyyymmdd=view_tbl.yyyymmdd
    left join
            click_tbl
        on view_tbl.user_id=click_tbl.user_id
        and view_tbl.yyyymmdd=click_tbl.yyyymmdd
    
)

SELECT
        test_group,
        event_type,
        click_type,
        time_period,
        cluster_name,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            test_group,
            event_type,
            click_type,
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            cluster_name,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
           and NOT (test_group = 'control' AND event_type IS NOT NULL)
           and NOT (event_type IS NULL AND click_type IS NOT NULL)
        GROUP BY 1,2,3,4,5
        )
    ORDER BY 1,2,3,4,5

"""

cluster_session_level_sports=pd.read_sql(cluster_session_level,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/290345653.py:217: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   cluster_session_level_sports=pd.read_sql(cluster_session_level,conn)

# %%
cluster_session_level_sports
# Out:
#     test_group event_type  click_type   time_period    cluster_name  \
# 120       test     viewed  play_click     afternoon   Banjara Hills
# 121       test     viewed  play_click     afternoon       Bodduppal
# 122       test     viewed  play_click     afternoon        Gandipet
# 123       test     viewed  play_click     afternoon     Hitech City
# 124       test     viewed  play_click     afternoon     Kothaguda 2
# 125       test     viewed  play_click     afternoon    Kukatpally 3
# 126       test     viewed  play_click     afternoon       Manikonda
# 127       test     viewed  play_click     afternoon     Marredpally
# 128       test     viewed  play_click     afternoon    Mehedipatnam
# 129       test     viewed  play_click     afternoon      Mothinagar
# 130       test     viewed  play_click     afternoon  Other_clusters
# 131       test     viewed  play_click     afternoon      Shamshabad
# 132       test     viewed  play_click       evening   Banjara Hills
# ...

# %%
cluster_session_level_sports=cluster_session_level_sports[cluster_session_level_sports['click_type']=='play_click']

# %%
cluster_session_level_sports.to_clipboard(index=False)

# %%
city_cluster_level_benchmark=f"""


with rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN pickup_cluster IN (              
                'Hitech City', 
                'Shamshabad', 
                'Kukatpally 3', 
                'Bodduppal', 
                'Mehedipatnam', 
                'Kothaguda 2', 
                'Mothinagar', 
                'Banjara Hills', 
                'Gandipet', 
                'Manikonda',
                'Marredpally'
            ) THEN pickup_cluster
            ELSE 'Other_clusters'
        END AS cluster_name,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
        and customer_id in(
                select
                    user_id
        from 
            clevertap.clevertap_customer_order_activity
        where 
            yyyymmdd >= '20240911' AND yyyymmdd <= '20240915'
            AND order_activity_source = 'appOpen'
            and current_city = 'Hyderabad'
            and platform='Android'
            and app_version>='8.30.0'           
            )
         
)



SELECT
        time_period,
        cluster_name,
        customers,

        gross_count,
        net_count,
        
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",
        
        
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            cluster_name,
            COUNT(DISTINCT customer_id) customers,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,

        
           
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            rr_net
        where 
            yyyymmdd is not null
           
        GROUP BY 1,2
        )
    ORDER BY 1,2

"""

city_cluster_level_sports_benchmark=pd.read_sql(city_cluster_level_benchmark,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_49271/2430106976.py:139: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   city_cluster_level_sports_benchmark=pd.read_sql(city_cluster_level_benchmark,conn)

# %%
city_cluster_level_sports_benchmark
# Out:
#      time_period    cluster_name  customers  gross_count  net_count    g2n  \
# 0      afternoon   Banjara Hills      12097        17456      12200  69.89
# 1      afternoon       Bodduppal       7836        11007       9144  83.07
# 2      afternoon        Gandipet       2627         4144       2443  58.95
# 3      afternoon     Hitech City      19223        27480      20754  75.52
# 4      afternoon     Kothaguda 2       6412         9064       6757  74.55
# 5      afternoon    Kukatpally 3      10241        14279      11130  77.95
# 6      afternoon       Manikonda       6549         9624       7187  74.68
# 7      afternoon     Marredpally       6938         9748       7139  73.24
# 8      afternoon    Mehedipatnam      12660        19227      13793  71.74
# 9      afternoon      Mothinagar       5884         8567       6220  72.60
# 10     afternoon  Other_clusters     381829       670013     486446  72.60
# ...

# %%
city_cluster_level_sports_benchmark.to_clipboard(index=False)

# %%
click_bucket=f"""
with olf as (

    SELECT
        yyyymmdd,
        customer_id,
        order_id,
        order_requested_epoch,
        customer_cancelled_epoch,
        dropped_epoch,
        expired_epoch,
        rider_accepted_epoch
        
    FROM 
        orders.order_logs_fact
    WHERE
        yyyymmdd >= '20240911' AND yyyymmdd <= '20240916'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Hyderabad'
        
    ),




click as(
    select
        yyyymmdd,
        profile_identity as user_id,
        epoch as click_epoch
    from 
        clevertap.customer_notification_clicked_immutable
    where yyyymmdd >= '20240911' and yyyymmdd<='20240916'
    and event_props_wzrk_c2a='Button 2'
    and event_props_campaign_id = '1725971334'

),


merge AS (
    
    SELECT 
        olf.*,
        click_epoch,
        (click_epoch / 1000 - order_requested_epoch / 1000) time_to_click
        --row_number() over(partition by olf.yyyymmdd,olf.customer_id,olf.order_id order by click_epoch) seq_no
    FROM 
        olf
    JOIN 
        click
        on olf.yyyymmdd = click.yyyymmdd
        and olf.customer_id = click.user_id
        and olf.order_requested_epoch < click.click_epoch
        and (olf.customer_cancelled_epoch > click.click_epoch or dropped_epoch > click.click_epoch or 
        expired_epoch > click.click_epoch or rider_accepted_epoch> click.click_epoch)
    )
    
    
   
    
    
    SELECT
        
        case 
        when time_to_click <= 15 then 'a. 15 Sec'
        when time_to_click between 16 and 30 then 'b. 16-30 Sec'
        when time_to_click between 31 and 60 then 'c. 30-60 Sec'
        when time_to_click between 61 and 120 then 'd. 1-2 min'
        when time_to_click between 121 and 240 then 'e. 3-4 min'
        when time_to_click > 240 then 'f. 4+ min' 
        else 'check' end as click_bucket,
        count(distinct customer_id) customers
    FROM 
        merge
    -- WHERE 
    --     --seq_no = 1
    GROUP BY 1
    ORDER BY 1

"""
click_bucket_df = pd.read_sql(click_bucket,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62376/650900096.py:82: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   click_bucket_df = pd.read_sql(click_bucket,conn)

# %%
click_bucket_df
# Out:
#    click_bucket  customers
# 0     a. 15 Sec       1737
# 1  b. 16-30 Sec        274
# 2  c. 30-60 Sec        123
# 3    d. 1-2 min         81
# 4    e. 3-4 min         35
# 5     f. 4+ min         33

# %%
click_bucket_df.customers.sum()
# Out:
# 2283

# %%
2178-2283
# Out:
# -105

# %%
1737-105
# Out:
# 1632

# %%
click_bucket_df.to_clipboard(index=False)

# %%
total_customers = click_bucket_df['customers'].sum()

# Calculate the percentage of customers for each click_bucket
click_bucket_df['customer_percentage'] = (click_bucket_df['customers'] / total_customers) * 100

# Round the percentage to 2 decimal places
click_bucket_df['customer_percentage'] = click_bucket_df['customer_percentage'].round(2)

# %%
click_bucket_df.to_clipboard(index=False)
