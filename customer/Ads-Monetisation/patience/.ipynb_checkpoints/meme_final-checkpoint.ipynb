# %% [markdown]
# ## Import

# %%
import re
import os 
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from pyhive import presto
from datetime import date
from collections import Counter

from scipy import stats
from pyhive import presto
from datetime import datetime, timedelta

presto_port = '80'
username = 'manoj.ravirajan@rapido.bike'

conn=presto.connect('presto-gateway.processing.data.production.internal',presto_port,username)

connection1 = presto.connect('bi-presto.serving.data.production.internal', presto_port, username)
connection2 = presto.connect('bi-trino-2.serving.data.production.internal', presto_port, username)
connection3= presto.connect('processing-2.processing.data.production.internal',presto_port,username)
connection4= presto.connect('processing.processing.data.production.internal',presto_port,username)


pd.set_option('display.max_columns', None)

# %%
pd.set_option('display.max_rows', None)

# %%
curr_overall_query1=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        --user_type,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            --user_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1
        )
    ORDER BY 1


"""
curr_overall_df1=pd.read_sql(curr_overall_query1,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/1418172729.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_overall_df1=pd.read_sql(curr_overall_query1,conn)

# %%
curr_overall_df1
# Out:
#   sample_category  customers  fe_count  gross_count  net_count  fe2rr    g2n  \
# 0         control     504812   3089512      1083433     600497  35.07  55.43
# 1            test     493942   3011917      1057775     586378  35.12  55.44
#
#    fe2net    aor  impression_count  click_count   ctr  median_cobrm_time  \
# 0   19.44  74.17            194251         3543  1.82                108
# 1   19.47  74.21            107238         3066  2.86                107
#
#    median_cobra_time  median_ocara_time  median_cancellation_time  \
# 0                128                297                       171
# 1                128                302                       172
#
#    median_acceptance_time  % cobrm  % cobra  % ocara  % expired  cobrm  \
# 0                      14     1.02    16.21    18.37       8.59  11019
# 1                      14     0.98    16.21    18.40       8.58  10401
#
#     cobra   ocara  expired
# 0  175669  199042    93025
# 1  171455  194645    90715

# %%
curr_overall_df1.to_csv('curr_overall_df1.csv',index=False)

# %%
curr_overall_df1
# Out:
#   sample_category  customers  fe_count  gross_count  net_count  fe2rr    g2n  \
# 0         control     504812   3089512      1083433     600497  35.07  55.43
# 1            test     493942   3011917      1057775     586378  35.12  55.44
#
#    fe2net    aor  median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0   19.44  74.17                109                128                295
# 1   19.47  74.21                107                128                300
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       171                      13     1.02    16.21
# 1                       172                      14     0.98    16.21
#
#    % ocara  % expired  cobrm   cobra   ocara  expired
# 0    18.37       8.59  11019  175669  199042    93025
# 1    18.40       8.58  10401  171455  194645    90715

# %%
curr_overall_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2
        )
    ORDER BY 1,2


"""
curr_overall_df=pd.read_sql(curr_overall_query,conn)

# %%
pd.set_option('display.max_columns', None)

# %%
curr_overall_df
# Out:
#   sample_category      user_type  customers  fe_count  gross_count  net_count  \
# 0         control  clicked_users       3523     24983        12010       2510
# 1         control           None     503398   3064529      1071423     597987
# 2            test  clicked_users       3041     23245        11735       2249
# 3            test           None     492990   2988672      1046040     584129
#
#    fe2rr    g2n  fe2net    aor  median_cobrm_time  median_cobra_time  \
# 0  48.07  20.90   10.05  34.88                173                157
# 1  34.96  55.81   19.51  74.61                108                127
# 2  50.48  19.16    9.68  31.80                127                156
# 3  35.00  55.84   19.54  74.69                106                127
#
#    median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                343                       181                      38
# 1                298                       170                      14
# 2                381                       180                      36
# 3                298                       172                      14
#
#    % cobrm  % cobra  % ocara  % expired  cobrm   cobra   ocara  expired
# 0     1.88    31.87    13.83      31.34    226    3827    1661     3764
# 1     1.01    16.04    18.42       8.33  10793  171842  197381    89261
# 2     1.96    34.67    12.50      31.56    230    4069    1467     3704
# 3     0.97    16.00    18.47       8.32  10171  167386  193178    87011

# %%
curr_session_query1=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        --user_type,
        time_period,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            --user_type,
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2
        )
    ORDER BY 1,2


"""
curr_session_df1=pd.read_sql(curr_session_query1,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/1120065599.py:230: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_session_df1=pd.read_sql(curr_session_query1,conn)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 230
#       1 curr_session_query1=f"""
#       2 WITH exp_category AS (
#       3     SELECT
#    (...)
#     228
#     229 """
# --> 230 curr_session_df1=pd.read_sql(curr_session_query1,conn)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:654, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652 with pandasSQL_builder(con) as pandas_sql:
#     653     if isinstance(pandas_sql, SQLiteDatabase):
# --> 654         return pandas_sql.read_query(
#     655             sql,
#     656             index_col=index_col,
#     657             params=params,
#     658             coerce_float=coerce_float,
#     659             parse_dates=parse_dates,
#     660             chunksize=chunksize,
#     661             dtype_backend=dtype_backend,
#     662             dtype=dtype,
#     663         )
#     665     try:
#     666         _is_table_name = pandas_sql.has_table(sql)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2327, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2315 def read_query(
#    2316     self,
#    2317     sql,
#    (...)
#    2324     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2325 ) -> DataFrame | Iterator[DataFrame]:
#    2326     cursor = self.execute(sql, params)
# -> 2327     columns = [col_desc[0] for col_desc in cursor.description]
#    2329     if chunksize is not None:
#    2330         return self._query_iterator(
#    2331             cursor,
#    2332             chunksize,
#    (...)
#    2338             dtype_backend=dtype_backend,
#    2339         )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/presto.py:232, in Cursor.description(self)
#     216 """This read-only attribute is a sequence of 7-item sequences.
#     217
#     218 Each of these sequences contains information describing one result column:
#    (...)
#     229 section below.
#     230 """
#     231 # Sleep until we're done or we got the columns
# --> 232 self._fetch_while(
#     233     lambda: self._columns is None and
#     234     self._state not in (self._STATE_NONE, self._STATE_FINISHED)
#     235 )
#     236 if self._columns is None:
#     237     return None
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/common.py:51, in DBAPICursor._fetch_while(self, fn)
#      49 def _fetch_while(self, fn):
#      50     while fn():
# ---> 51         self._fetch_more()
#      52         if fn():
#      53             time.sleep(self._poll_interval)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/presto.py:315, in Cursor._fetch_more(self)
#     313 def _fetch_more(self):
#     314     """Fetch the next URI and update state"""
# --> 315     self._process_response(self._requests_session.get(self._nextUri, **self._requests_kwargs))
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File /opt/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
curr_session_df1
# Out:
#   sample_category   time_period  customers  fe_count  gross_count  net_count  \
# 0         control     afternoon     257219    963651       323284     207470
# 1         control       evening     231767    901414       318271     159062
# 2         control       morning     173623    682231       252696     126095
# 3         control  rest_evening      97627    274962        95083      56459
# 4         control  rest_morning      84986    267254        94099      51411
# 5            test     afternoon     252139    942152       316307     203245
# 6            test       evening     226505    879927       312204     155645
# 7            test       morning     169819    662030       244649     122377
# 8            test  rest_evening      95470    268686        93204      55396
# 9            test  rest_morning      82786    259122        91411      49715
#
#    fe2rr    g2n  fe2net    aor  median_cobrm_time  median_cobra_time  \
# 0  33.55  64.18   21.53  83.41                110                119
# 1  35.31  49.98   17.65  69.80                105                127
# 2  37.04  49.90   18.48  64.92                112                137
# 3  34.58  59.38   20.53  81.10                106                116
# 4  35.21  54.64   19.24  75.00                108                130
# 5  33.57  64.26   21.57  83.54                109                119
# 6  35.48  49.85   17.69  69.78                104                125
# 7  36.95  50.02   18.49  64.91                104                137
# 8  34.69  59.44   20.62  81.22                 98                115
# 9  35.28  54.39   19.19  74.83                111                134
#
#    median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                295                       179                      11
# 1                309                       169                      18
# 2                287                       163                      17
# 3                300                       180                      15
# 4                261                       160                      11
# 5                296                       181                      11
# 6                311                       170                      17
# 7                292                       164                      16
# 8                301                       180                      14
# 9                283                       170                      11
#
#    % cobrm  % cobra  % ocara  % expired  cobrm  cobra  ocara  expired
# 0     0.79    10.54    18.84       5.26   2567  34070  60906    16997
# 1     0.79    19.55    19.46       9.83   2516  62219  61945    31290
# 2     0.80    21.46    14.79      12.81   2033  54240  37365    32375
# 3     1.19    12.23    21.11       5.38   1135  11630  20069     5116
# 4     2.94    14.36    19.93       7.70   2768  13510  18757     7247
# 5     0.80    10.41    18.87       5.24   2546  32942  59698    16575
# 6     0.76    19.53    19.56       9.91   2364  60979  61054    30924
# 7     0.78    21.60    14.64      12.70   1912  52848  35809    31077
# 8     1.13    12.14    21.21       5.39   1057  11316  19766     5025
# 9     2.76    14.63    20.04       7.78   2522  13370  18318     7114

# %%
curr_session_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        time_period,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
curr_session_df=pd.read_sql(curr_session_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/4216387126.py:230: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_session_df=pd.read_sql(curr_session_query,conn)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 230
#       1 curr_session_query=f"""
#       2 WITH exp_category AS (
#       3     SELECT
#    (...)
#     228
#     229 """
# --> 230 curr_session_df=pd.read_sql(curr_session_query,conn)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:654, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652 with pandasSQL_builder(con) as pandas_sql:
#     653     if isinstance(pandas_sql, SQLiteDatabase):
# --> 654         return pandas_sql.read_query(
#     655             sql,
#     656             index_col=index_col,
#     657             params=params,
#     658             coerce_float=coerce_float,
#     659             parse_dates=parse_dates,
#     660             chunksize=chunksize,
#     661             dtype_backend=dtype_backend,
#     662             dtype=dtype,
#     663         )
#     665     try:
#     666         _is_table_name = pandas_sql.has_table(sql)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2327, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2315 def read_query(
#    2316     self,
#    2317     sql,
#    (...)
#    2324     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2325 ) -> DataFrame | Iterator[DataFrame]:
#    2326     cursor = self.execute(sql, params)
# -> 2327     columns = [col_desc[0] for col_desc in cursor.description]
#    2329     if chunksize is not None:
#    2330         return self._query_iterator(
#    2331             cursor,
#    2332             chunksize,
#    (...)
#    2338             dtype_backend=dtype_backend,
#    2339         )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/presto.py:232, in Cursor.description(self)
#     216 """This read-only attribute is a sequence of 7-item sequences.
#     217
#     218 Each of these sequences contains information describing one result column:
#    (...)
#     229 section below.
#     230 """
#     231 # Sleep until we're done or we got the columns
# --> 232 self._fetch_while(
#     233     lambda: self._columns is None and
#     234     self._state not in (self._STATE_NONE, self._STATE_FINISHED)
#     235 )
#     236 if self._columns is None:
#     237     return None
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/common.py:51, in DBAPICursor._fetch_while(self, fn)
#      49 def _fetch_while(self, fn):
#      50     while fn():
# ---> 51         self._fetch_more()
#      52         if fn():
#      53             time.sleep(self._poll_interval)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/presto.py:315, in Cursor._fetch_more(self)
#     313 def _fetch_more(self):
#     314     """Fetch the next URI and update state"""
# --> 315     self._process_response(self._requests_session.get(self._nextUri, **self._requests_kwargs))
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File /opt/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
curr_session_df
# Out:
#    sample_category      user_type   time_period  customers  fe_count  \
# 0          control  clicked_users     afternoon       1332      5781
# 1          control  clicked_users       evening       1785      8426
# 2          control  clicked_users       morning       1415      7342
# 3          control  clicked_users  rest_evening        459      1586
# 4          control  clicked_users  rest_morning        507      1848
# 5          control           None     afternoon     256397    957870
# 6          control           None       evening     230761    892988
# 7          control           None       morning     172890    674889
# 8          control           None  rest_evening      97291    273376
# 9          control           None  rest_morning      84622    265406
# 10            test  clicked_users     afternoon       1058      4704
# 11            test  clicked_users       evening       1538      7631
# 12            test  clicked_users       morning       1505      8200
# 13            test  clicked_users  rest_evening        343      1009
# 14            test  clicked_users  rest_morning        443      1701
# 15            test           None     afternoon     251608    937448
# 16            test           None       evening     225780    872296
# 17            test           None       morning     169134    653830
# 18            test           None  rest_evening      95247    267677
f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN pickup_cluster = 'NCR N Gharoli' THEN 'NCR N Gharoli'
            WHEN pickup_cluster = 'Dashrathpuri_Del_East' THEN 'Dashrathpuri_Del_East'
            WHEN pickup_cluster = 'Sec-57' THEN 'Sec-57'
            WHEN pickup_cluster = 'Sector 45-46' THEN 'Sector 45-46'
            WHEN pickup_cluster = 'NCR N sec 22/62' THEN 'NCR N sec 22/62'
            WHEN pickup_cluster = 'G Sadar Bazar' THEN 'G Sadar Bazar'
            WHEN pickup_cluster = 'Sec-39' THEN 'Sec-39'
            WHEN pickup_cluster = 'NCR N Sharda University 2' THEN 'NCR N Sharda University 2'
            WHEN pickup_cluster = 'Gurgaon Rural' THEN 'Gurgaon Rural'
            WHEN pickup_cluster = 'NCR N Venice Mall' THEN 'NCR N Venice Mall'
            WHEN pickup_cluster = 'NCR G Vijay Nagar 2' THEN 'NCR G Vijay Nagar 2'
            ELSE 'Other_clusters'
        END AS cluster_name
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        rr_net.cluster_name,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        --user_type,
        time_period,
        cluster_name,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            --user_type,
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            cluster_name,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
curr_session_cluseter_df1=pd.read_sql(curr_session_cluseter_query1,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/1205394103.py:247: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_session_cluseter_df1=pd.read_sql(curr_session_cluseter_query1,conn)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 247
#       1 curr_session_cluseter_query1=f"""
#       2 WITH exp_category AS (
#       3     SELECT
#    (...)
#     245
#     246 """
# --> 247 curr_session_cluseter_df1=pd.read_sql(curr_session_cluseter_query1,conn)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:654, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     652 with pandasSQL_builder(con) as pandas_sql:
#     653     if isinstance(pandas_sql, SQLiteDatabase):
# --> 654         return pandas_sql.read_query(
#     655             sql,
#     656             index_col=index_col,
#     657             params=params,
#     658             coerce_float=coerce_float,
#     659             parse_dates=parse_dates,
#     660             chunksize=chunksize,
#     661             dtype_backend=dtype_backend,
#     662             dtype=dtype,
#     663         )
#     665     try:
#     666         _is_table_name = pandas_sql.has_table(sql)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/io/sql.py:2327, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2315 def read_query(
#    2316     self,
#    2317     sql,
#    (...)
#    2324     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2325 ) -> DataFrame | Iterator[DataFrame]:
#    2326     cursor = self.execute(sql, params)
# -> 2327     columns = [col_desc[0] for col_desc in cursor.description]
#    2329     if chunksize is not None:
#    2330         return self._query_iterator(
#    2331             cursor,
#    2332             chunksize,
#    (...)
#    2338             dtype_backend=dtype_backend,
#    2339         )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/presto.py:232, in Cursor.description(self)
#     216 """This read-only attribute is a sequence of 7-item sequences.
#     217
#     218 Each of these sequences contains information describing one result column:
#    (...)
#     229 section below.
#     230 """
#     231 # Sleep until we're done or we got the columns
# --> 232 self._fetch_while(
#     233     lambda: self._columns is None and
#     234     self._state not in (self._STATE_NONE, self._STATE_FINISHED)
#     235 )
#     236 if self._columns is None:
#     237     return None
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/common.py:51, in DBAPICursor._fetch_while(self, fn)
#      49 def _fetch_while(self, fn):
#      50     while fn():
# ---> 51         self._fetch_more()
#      52         if fn():
#      53             time.sleep(self._poll_interval)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pyhive/presto.py:315, in Cursor._fetch_more(self)
#     313 def _fetch_more(self):
#     314     """Fetch the next URI and update state"""
# --> 315     self._process_response(self._requests_session.get(self._nextUri, **self._requests_kwargs))
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/anaconda3/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/anaconda3/lib/python3.11/http/client.py:1386, in HTTPConnection.getresponse(self)
#    1384 try:
#    1385     try:
# -> 1386         response.begin()
#    1387     except ConnectionError:
#    1388         self.close()
#
# File /opt/anaconda3/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File /opt/anaconda3/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File /opt/anaconda3/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
curr_session_cluseter_df
# Out:
#     sample_category   time_period               cluster_name  customers  \
# 0           control     afternoon      Dashrathpuri_Del_East       3680
# 1           control     afternoon              Gurgaon Rural       1926
# 2           control     afternoon        NCR G Vijay Nagar 2       2562
# 3           control     afternoon              NCR N Gharoli       3318
# 4           control     afternoon  NCR N Sharda University 2       3301
# 5           control     afternoon          NCR N Venice Mall       1993
# 6           control     afternoon            NCR N sec 22/62       2213
# 7           control     afternoon             Other_clusters     152536
# 8           control     afternoon                     Sec-39       1843
# 9           control     afternoon                     Sec-57       2294
# 10          control     afternoon               Sector 45-46       2001
# 11          control     afternoon                       None     221334
# 12          control       evening      Dashrathpuri_Del_East       2704
# 13          control       evening              Gurgaon Rural       1214
# 14          control       evening        NCR G Vijay Nagar 2       1822
# 15          control       evening              NCR N Gharoli       3172
# 16          control       evening  NCR N Sharda University 2       2343
# 17          control       evening          NCR N Venice Mall       1808
# 18          control       evening            NCR N sec 22/62       3008
# 19          control       evening             Other_clusters     139009
# 20          control       evening                     Sec-39       1770
# 21          control       evening                     Sec-57       1991
# 22          control       evening               Sector 45-46       2288
# 23          control       evening                       None     200751
# 24          control       morning      Dashrathpuri_Del_East       2222
# 25          control       morning              Gurgaon Rural       1554
# 26          control       morning        NCR G Vijay Nagar 2       1911
# 27          control       morning              NCR N Gharoli       2215
# 28          control       morning  NCR N Sharda University 2       1009
# 29          control       morning          NCR N Venice Mall       1355
# 30          control       morning            NCR N sec 22/62       1343
# 31          control       morning             Other_clusters     100845
# 32          control       morning                     Sec-39       2057
# 33          control       morning                     Sec-57       2187
# 34          control       morning               Sector 45-46       2305
# 35          control       morning                       None     148083
# 36          control  rest_evening      Dashrathpuri_Del_East       1066
# 37          control  rest_evening              Gurgaon Rural        338
# 38          control  rest_evening        NCR G Vijay Nagar 2        678
# 39          control  rest_evening              NCR N Gharoli        901
# 40          control  rest_evening  NCR N Sharda University 2        328
# 41          control  rest_evening          NCR N Venice Mall        429
# 42          control  rest_evening            NCR N sec 22/62        576
# 43          control  rest_evening             Other_clusters      54340
# 44          control  rest_evening                     Sec-39        473
# 45          control  rest_evening                     Sec-57        559
# 46          control  rest_evening               Sector 45-46        644
# 47          control  rest_evening                       None      79000
# 48          control  rest_morning      Dashrathpuri_Del_East       1212
# 49          control  rest_morning              Gurgaon Rural        476
# 50          control  rest_morning        NCR G Vijay Nagar 2        726
# 51          control  rest_morning              NCR N Gharoli        900
# 52          control  rest_morning  NCR N Sharda University 2        163
# 53          control  rest_morning          NCR N Venice Mall        569
# 54          control  rest_morning            NCR N sec 22/62        462
# 55          control  rest_morning             Other_clusters      47690
# 56          control  rest_morning                     Sec-39        572
# 57          control  rest_morning                     Sec-57        586
# 58          control  rest_morning               Sector 45-46        610
# 59          control  rest_morning                       None      70505
# 60             test     afternoon      Dashrathpuri_Del_East       3592
# 61             test     afternoon              Gurgaon Rural       1830
# 62             test     afternoon        NCR G Vijay Nagar 2       2442
# 63             test     afternoon              NCR N Gharoli       3257
# 64             test     afternoon  NCR N Sharda University 2       3200
# 65             test     afternoon          NCR N Venice Mall       2093
# 66             test     afternoon            NCR N sec 22/62       2319
# 67             test     afternoon             Other_clusters     149783
# 68             test     afternoon                     Sec-39       1733
# 69             test     afternoon                     Sec-57       2248
# 70             test     afternoon               Sector 45-46       1917
# 71             test     afternoon                       None     216734
# 72             test       evening      Dashrathpuri_Del_East       2608
# 73             test       evening              Gurgaon Rural       1195
# 74             test       evening        NCR G Vijay Nagar 2       1727
# 75             test       evening              NCR N Gharoli       3230
# 76             test       evening  NCR N Sharda University 2       2287
# 77             test       evening          NCR N Venice Mall       1745
# 78             test       evening            NCR N sec 22/62       3033
# 79             test       evening             Other_clusters     135448
# 80             test       evening                     Sec-39       1645
# 81             test       evening                     Sec-57       1980
# 82             test       evening               Sector 45-46       2208
# 83             test       evening                       None     196229
# 84             test       morning      Dashrathpuri_Del_East       2037
# 85             test       morning              Gurgaon Rural       1446
# 86             test       morning        NCR G Vijay Nagar 2       1845
# 87             test       morning              NCR N Gharoli       2142
# 88             test       morning  NCR N Sharda University 2       1047
# 89             test       morning          NCR N Venice Mall       1321
# 90             test       morning            NCR N sec 22/62       1304
# 91             test       morning             Other_clusters      98473
# 92             test       morning                     Sec-39       1902
# 93             test       morning                     Sec-57       2099
# 94             test       morning               Sector 45-46       2262
# 95             test       morning                       None     145047
# 96             test  rest_evening      Dashrathpuri_Del_East       1126
# 97             test  rest_evening              Gurgaon Rural        307
# 98             test  rest_evening        NCR G Vijay Nagar 2        681
# 99             test  rest_evening              NCR N Gharoli        929
# 100            test  rest_evening  NCR N Sharda University 2        331
# 101            test  rest_evening          NCR N Venice Mall        379
# 102            test  rest_evening            NCR N sec 22/62        555
# 103            test  rest_evening             Other_clusters      52939
# 104            test  rest_evening                     Sec-39        465
# 105            test  rest_evening                     Sec-57        525
# 106            test  rest_evening               Sector 45-46        607
f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour,
        CASE 
            WHEN pickup_cluster = 'NCR N Gharoli' THEN 'NCR N Gharoli'
            WHEN pickup_cluster = 'Dashrathpuri_Del_East' THEN 'Dashrathpuri_Del_East'
            WHEN pickup_cluster = 'Sec-57' THEN 'Sec-57'
            WHEN pickup_cluster = 'Sector 45-46' THEN 'Sector 45-46'
            WHEN pickup_cluster = 'NCR N sec 22/62' THEN 'NCR N sec 22/62'
            WHEN pickup_cluster = 'G Sadar Bazar' THEN 'G Sadar Bazar'
            WHEN pickup_cluster = 'Sec-39' THEN 'Sec-39'
            WHEN pickup_cluster = 'NCR N Sharda University 2' THEN 'NCR N Sharda University 2'
            WHEN pickup_cluster = 'Gurgaon Rural' THEN 'Gurgaon Rural'
            WHEN pickup_cluster = 'NCR N Venice Mall' THEN 'NCR N Venice Mall'
            WHEN pickup_cluster = 'NCR G Vijay Nagar 2' THEN 'NCR G Vijay Nagar 2'
            ELSE 'Other_clusters'
        END AS cluster_name
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        time_period,
        cluster_name,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            case
                WHEN quarter_hour >= '0800' AND quarter_hour < '1100' THEN 'morning'
                WHEN quarter_hour >= '1100' AND quarter_hour < '1700' THEN 'afternoon'
                WHEN quarter_hour >= '1700' AND quarter_hour < '2100' THEN 'evening'
                WHEN quarter_hour >= '0000' AND quarter_hour < '0800' THEN 'rest_morning'
                ELSE 'rest_evening'
            end as time_period,
            cluster_name,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
            and cluster_name is not null
        
        GROUP BY 1,2,3,4
        )
    ORDER BY 1,2,3,4


"""
curr_session_cluseter_df=pd.read_sql(curr_session_cluseter_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/3332967694.py:249: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_session_cluseter_df=pd.read_sql(curr_session_cluseter_query,conn)

# %%
curr_session_cluseter_df
# Out:
#     sample_category      user_type   time_period               cluster_name  \
# 0           control  clicked_users     afternoon      Dashrathpuri_Del_East
# 1           control  clicked_users     afternoon              Gurgaon Rural
# 2           control  clicked_users     afternoon        NCR G Vijay Nagar 2
# 3           control  clicked_users     afternoon              NCR N Gharoli
# 4           control  clicked_users     afternoon  NCR N Sharda University 2
# 5           control  clicked_users     afternoon          NCR N Venice Mall
# 6           control  clicked_users     afternoon            NCR N sec 22/62
# 7           control  clicked_users     afternoon             Other_clusters
# 8           control  clicked_users     afternoon                     Sec-39
# 9           control  clicked_users     afternoon                     Sec-57
# 10          control  clicked_users     afternoon               Sector 45-46
# 11          control  clicked_users       evening      Dashrathpuri_Del_East
# 12          control  clicked_users       evening              Gurgaon Rural
# 13          control  clicked_users       evening        NCR G Vijay Nagar 2
# 14          control  clicked_users       evening              NCR N Gharoli
# 15          control  clicked_users       evening  NCR N Sharda University 2
# 16          control  clicked_users       evening          NCR N Venice Mall
# 17          control  clicked_users       evening            NCR N sec 22/62
# 18          control  clicked_users       evening             Other_clusters
# 19          control  clicked_users       evening                     Sec-39
# 20          control  clicked_users       evening                     Sec-57
# 21          control  clicked_users       evening               Sector 45-46
# 22          control  clicked_users       morning      Dashrathpuri_Del_East
# 23          control  clicked_users       morning              Gurgaon Rural
# 24          control  clicked_users       morning        NCR G Vijay Nagar 2
# 25          control  clicked_users       morning              NCR N Gharoli
# 26          control  clicked_users       morning  NCR N Sharda University 2
# 27          control  clicked_users       morning          NCR N Venice Mall
# 28          control  clicked_users       morning            NCR N sec 22/62
# 29          control  clicked_users       morning             Other_clusters
# 30          control  clicked_users       morning                     Sec-39
# 31          control  clicked_users       morning                     Sec-57
# 32          control  clicked_users       morning               Sector 45-46
# 33          control  clicked_users  rest_evening      Dashrathpuri_Del_East
# 34          control  clicked_users  rest_evening              Gurgaon Rural
# 35          control  clicked_users  rest_evening        NCR G Vijay Nagar 2
# 36          control  clicked_users  rest_evening              NCR N Gharoli
# 37          control  clicked_users  rest_evening  NCR N Sharda University 2
# 38          control  clicked_users  rest_evening          NCR N Venice Mall
# 39          control  clicked_users  rest_evening            NCR N sec 22/62
# 40          control  clicked_users  rest_evening             Other_clusters
# 41          control  clicked_users  rest_evening                     Sec-39
# 42          control  clicked_users  rest_evening                     Sec-57
# 43          control  clicked_users  rest_evening               Sector 45-46
# 44          control  clicked_users  rest_morning      Dashrathpuri_Del_East
# 45          control  clicked_users  rest_morning              Gurgaon Rural
# 46          control  clicked_users  rest_morning        NCR G Vijay Nagar 2
# 47          control  clicked_users  rest_morning              NCR N Gharoli
# 48          control  clicked_users  rest_morning  NCR N Sharda University 2
# 49          control  clicked_users  rest_morning          NCR N Venice Mall
# 50          control  clicked_users  rest_morning            NCR N sec 22/62
# 51          control  clicked_users  rest_morning             Other_clusters
# 52          control  clicked_users  rest_morning                     Sec-39
# 53          control  clicked_users  rest_morning                     Sec-57
# 54          control  clicked_users  rest_morning               Sector 45-46
# 55          control           None     afternoon      Dashrathpuri_Del_East
# 56          control           None     afternoon              Gurgaon Rural
# 57          control           None     afternoon        NCR G Vijay Nagar 2
# 58          control           None     afternoon              NCR N Gharoli
# 59          control           None     afternoon  NCR N Sharda University 2
# 60          control           None     afternoon          NCR N Venice Mall
# 61          control           None     afternoon            NCR N sec 22/62
# 62          control           None     afternoon             Other_clusters
# 63          control           None     afternoon                     Sec-39
# 64          control           None     afternoon                     Sec-57
# 65          control           None     afternoon               Sector 45-46
# 66          control           None       evening      Dashrathpuri_Del_East
# 67          control           None       evening              Gurgaon Rural
# 68          control           None       evening        NCR G Vijay Nagar 2
# 69          control           None       evening              NCR N Gharoli
# 70          control           None       evening  NCR N Sharda University 2
# 71          control           None       evening          NCR N Venice Mall
# 72          control           None       evening            NCR N sec 22/62
# 73          control           None       evening             Other_clusters
# 74          control           None       evening                     Sec-39
# 75          control           None       evening                     Sec-57
# 76          control           None       evening               Sector 45-46
# 77          control           None       morning      Dashrathpuri_Del_East
# 78          control           None       morning              Gurgaon Rural
# 79          control           None       morning        NCR G Vijay Nagar 2
# 80          control           None       morning              NCR N Gharoli
# 81          control           None       morning  NCR N Sharda University 2
# 82          control           None       morning          NCR N Venice Mall
# 83          control           None       morning            NCR N sec 22/62
# 84          control           None       morning             Other_clusters
# 85          control           None       morning                     Sec-39
# 86          control           None       morning                     Sec-57
# 87          control           None       morning               Sector 45-46
# 88          control           None  rest_evening      Dashrathpuri_Del_East
# 89          control           None  rest_evening              Gurgaon Rural
# 90          control           None  rest_evening        NCR G Vijay Nagar 2
# 91          control           None  rest_evening              NCR N Gharoli
# 92          control           None  rest_evening  NCR N Sharda University 2
# 93          control           None  rest_evening          NCR N Venice Mall
# 94          control           None  rest_evening            NCR N sec 22/62
# 95          control           None  rest_evening             Other_clusters
# 96          control           None  rest_evening                     Sec-39
# 97          control           None  rest_evening                     Sec-57
# 98          control           None  rest_evening               Sector 45-46
# 99          control           None  rest_morning      Dashrathpuri_Del_East
# 100         control           None  rest_morning              Gurgaon Rural
# 101         control           None  rest_morning        NCR G Vijay Nagar 2
# 102         control           None  rest_morning              NCR N Gharoli
# 103         control           None  rest_morning  NCR N Sharda University 2
# 104         control           None  rest_morning          NCR N Venice Mall
# 105         control           None  rest_morning            NCR N sec 22/62
# 106         control           None  rest_morning             Other_clusters
# 107         control           None  rest_morning                     Sec-39
# 108         control           None  rest_morning                     Sec-57
# 109         control           None  rest_morning               Sector 45-46
# 110            test  clicked_users     afternoon      Dashrathpuri_Del_East
# 111            test  clicked_users     afternoon              Gurgaon Rural
# 112            test  clicked_users     afternoon        NCR G Vijay Nagar 2
# 113            test  clicked_users     afternoon              NCR N Gharoli
# 114            test  clicked_users     afternoon  NCR N Sharda University 2
# 115            test  clicked_users     afternoon          NCR N Venice Mall
# 116            test  clicked_users     afternoon            NCR N sec 22/62
# 117            test  clicked_users     afternoon             Other_clusters
# 118            test  clicked_users     afternoon                     Sec-39
# 119            test  clicked_users     afternoon                     Sec-57
# 120            test  clicked_users     afternoon               Sector 45-46
# 121            test  clicked_users       evening      Dashrathpuri_Del_East
# 122            test  clicked_users       evening              Gurgaon Rural
# 123            test  clicked_users       evening        NCR G Vijay Nagar 2
# 124            test  clicked_users       evening              NCR N Gharoli
# 125            test  clicked_users       evening  NCR N Sharda University 2
# 126            test  clicked_users       evening          NCR N Venice Mall
# 127            test  clicked_users       evening            NCR N sec 22/62
# 128            test  clicked_users       evening             Other_clusters
# 129            test  clicked_users       evening                     Sec-39
# 130            test  clicked_users       evening                     Sec-57
# 131            test  clicked_users       evening               Sector 45-46
# 132            test  clicked_users       morning      Dashrathpuri_Del_East
# 133            test  clicked_users       morning              Gurgaon Rural
# 134            test  clicked_users       morning        NCR G Vijay Nagar 2
# 135            test  clicked_users       morning              NCR N Gharoli
# 136            test  clicked_users       morning  NCR N Sharda University 2
# 137            test  clicked_users       morning          NCR N Venice Mall
# 138            test  clicked_users       morning            NCR N sec 22/62
# 139            test  clicked_users       morning             Other_clusters
# 140            test  clicked_users       morning                     Sec-39
# 141            test  clicked_users       morning                     Sec-57
# 142            test  clicked_users       morning               Sector 45-46
# 143            test  clicked_users  rest_evening      Dashrathpuri_Del_East
# 144            test  clicked_users  rest_evening              Gurgaon Rural
# 145            test  clicked_users  rest_evening        NCR G Vijay Nagar 2
# 146            test  clicked_users  rest_evening              NCR N Gharoli
# 147            test  clicked_users  rest_evening          NCR N Venice Mall
# 148            test  clicked_users  rest_evening            NCR N sec 22/62
# 149            test  clicked_users  rest_evening             Other_clusters
# 150            test  clicked_users  rest_evening                     Sec-39
# 151            test  clicked_users  rest_evening                     Sec-57
# 152            test  clicked_users  rest_evening               Sector 45-46
# 153            test  clicked_users  rest_morning      Dashrathpuri_Del_East
# 154            test  clicked_users  rest_morning              Gurgaon Rural
# 155            test  clicked_users  rest_morning        NCR G Vijay Nagar 2
# 156            test  clicked_users  rest_morning              NCR N Gharoli
# 157            test  clicked_users  rest_morning  NCR N Sharda University 2
# 158            test  clicked_users  rest_morning          NCR N Venice Mall
# 159            test  clicked_users  rest_morning            NCR N sec 22/62
# 160            test  clicked_users  rest_morning             Other_clusters
# 161            test  clicked_users  rest_morning                     Sec-39
# 162            test  clicked_users  rest_morning                     Sec-57
# 163            test  clicked_users  rest_morning               Sector 45-46
# 164            test           None     afternoon      Dashrathpuri_Del_East
# 165            test           None     afternoon              Gurgaon Rural
# 166            test           None     afternoon        NCR G Vijay Nagar 2
# 167            test           None     afternoon              NCR N Gharoli
# 168            test           None     afternoon  NCR N Sharda University 2
# 169            test           None     afternoon          NCR N Venice Mall
# 170            test           None     afternoon            NCR N sec 22/62
# 171            test           None     afternoon             Other_clusters
# 172            test           None     afternoon                     Sec-39
# 173            test           None     afternoon                     Sec-57
# 174            test           None     afternoon               Sector 45-46
# 175            test           None       evening      Dashrathpuri_Del_East
# 176            test           None       evening              Gurgaon Rural
# 177            test           None       evening        NCR G Vijay Nagar 2
# 178            test           None       evening              NCR N Gharoli
# 179            test           None       evening  NCR N Sharda University 2
# 180            test           None       evening          NCR N Venice Mall
# 181            test           None       evening            NCR N sec 22/62
# 182            test           None       evening             Other_clusters
# 183            test           None       evening                     Sec-39
# 184            test           None       evening                     Sec-57
# 185            test           None       evening               Sector 45-46
# 186            test           None       morning      Dashrathpuri_Del_East
# 187            test           None       morning              Gurgaon Rural
# 188            test           None       morning        NCR G Vijay Nagar 2
# 189            test           None       morning              NCR N Gharoli
# 190            test           None       morning  NCR N Sharda University 2
# 191            test           None       morning          NCR N Venice Mall
# 192            test           None       morning            NCR N sec 22/62
# 193            test           None       morning             Other_clusters
# 194            test           None       morning                     Sec-39
# 195            test           None       morning                     Sec-57
# 196            test           None       morning               Sector 45-46
# 197            test           None  rest_evening      Dashrathpuri_Del_East
# 198            test           None  rest_evening              Gurgaon Rural
# 199            test           None  rest_evening        NCR G Vijay Nagar 2
# 200            test           None  rest_evening              NCR N Gharoli
# 201            test           None  rest_evening  NCR N Sharda University 2
# 202            test           None  rest_evening          NCR N Venice Mall
# 203            test           None  rest_evening            NCR N sec 22/62
# 204            test           None  rest_evening             Other_clusters
# 205            test           None  rest_evening                     Sec-39
# 202     84    119       31
# 203     57    120       18
# 204  10296  18019     4565
# 205     74    120       26
# 206    122    136       69
# 207    136    178       47
# 208    319    402       94
# 209    231    125      144
# 210     60    215       24
# 211     51    283       20
# 212     44     33       25
# 213    211    153      119
# 214     20    112       10
# 215  11459  16380     5943
# 216    157    111      112
# 217    318    176      194
# 218    238    209      126

# %%
curr_session_cluseter_df.to_csv('curr_session_cluseter_df.csv',index=False)

# %%
curr_overall_segment_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

segment AS (
    
    SELECT
        customer_id,
        taxi_ltr_segment ltr_segment,
        taxi_retention_segments retention_segment,
        taxi_lifetime_stage lifetime_stage,
        taxi_service_affinity service_affinity,
        gender_tag gender
    FROM
        datasets.iallocator_customer_segments
    WHERE 
        run_date = '2024-09-05'
    
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        segment.ltr_segment,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        segment
        ON exp_category.customer_id=segment.customer_id
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        ltr_segment,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            ltr_segment,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
curr_overall_segment_df=pd.read_sql(curr_overall_segment_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/3858488940.py:244: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_overall_segment_df=pd.read_sql(curr_overall_segment_query,conn)

# %%
curr_overall_segment_df.to_csv('curr_overall_segment_df.csv',index=False)

# %%
curr_overall_segment_df
# Out:
#    sample_category      user_type ltr_segment  customers  fe_count  \
# 0          control  clicked_users          HH        636      4256
# 1          control  clicked_users         PHH       2513     18101
# 2          control  clicked_users     UNKNOWN        114       696
# 3          control  clicked_users        None        260      1930
# 4          control           None          HH     100337    463794
# 5          control           None         PHH     347693   2320750
# 6          control           None     UNKNOWN      14813     72328
# 7          control           None        None      40583    207724
# 8             test  clicked_users          HH        519      3703
# 9             test  clicked_users         PHH       2319     18068
# 10            test  clicked_users     UNKNOWN         95       588
# 11            test  clicked_users        None        108       886
# 12            test           None          HH      98445    452785
# 13            test           None         PHH     339876   2261275
# 14            test           None     UNKNOWN      14523     69956
# 15            test           None        None      40172    204719
#
#     gross_count  net_count  fe2rr    g2n  fe2net    aor  impression_count  \
# 0          1886        364  44.31  19.30    8.55  35.21               699
# 1          9026       1952  49.86  21.63   10.78  35.44              2814
# 2           316         28  45.40   8.86    4.02  21.52               127
# 3           782        166  40.52  21.23    8.60  32.99               278
# 4        121378      65571  26.17  54.02   14.14  75.18             23573
# 5        892466     504646  38.46  56.55   21.74  74.50            157542
# 6         18158       5850  25.11  32.22    8.09  68.87              3513
# 7         39443      21937  18.99  55.62   10.56  77.83              6393
# 8          1652        305  44.61  18.46    8.24  31.66               563
# 9          9470       1867  52.41  19.71   10.33  32.30              2601
# 10          263         16  44.73   6.08    2.72  17.87               107
# 11          350         61  39.50  17.43    6.88  29.43               120
# 12       118304      64226  26.13  54.29   14.18  75.51             11710
# 13       870896     492363  38.51  56.54   21.77  74.60             89296
# 14        17077       5641  24.41  33.03    8.06  67.93              1736
# 15        39779      21911  19.43  55.08   10.70  77.03              1628
#
#     click_count    ctr  median_cobrm_time  median_cobra_time  \
# 0           638  91.27                165                166
# 1          2528  89.84                165                155
# 2           115  90.55                189                162
# 3           262  94.24                224                163
# 4             0   0.00                118                140
# 5             0   0.00                107                126
# 6             0   0.00                 88                116
# 7             0   0.00                115                143
# 8           526  93.43                139                168
# 9          2335  89.77                120                154
# 10           96  89.72                 78                178
# 11          109  90.83                173                157
# 12            0   0.00                114                139
# 13            0   0.00                106                125
# 14            0   0.00                100                133
# 15            0   0.00                 96                143
#
#     median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                 474                       208                      39
# 1                 297                       175                      36
# 2                 634                       196                     151
# 3                 595                       219                      65
# 4                 344                       191                      13
# 5                 291                       166                      14
# 6                 142                       122                      12
# 7                 403                       221                      12
# 8                 526                       194                      39
# 9                 356                       177                      35
# 10                328                       186                      82
# 11                479                       208                      36
# 12                353                       196                      13
# 13                289                       168                      14
# 14                245                       165                      12
# 15                396                       215                      13
#
#     % cobrm  % cobra  % ocara  % expired  cobrm   cobra   ocara  expired
# 0      3.45    27.78    15.85      33.46     65     524     299      631
# 1      1.34    33.88    13.65      29.33    121    3058    1232     2647
# 2      4.11    25.63    12.66      48.73     13      81      40      154
# 3      3.45    20.97    11.51      42.46     27     164      90      332
# 4      1.39    14.17    20.70       9.24   1688   17197   25129    11214
# 5      0.88    16.53    17.62       8.07   7876  147511  157256    72039
# 6      3.27    15.17    36.07      12.65    594    2754    6550     2297
# 7      1.61    11.10    21.42       9.41    635    4380    8449     3713
# 8      4.06    28.45    13.01      35.84     67     470     215      592
# 9      1.38    36.30    12.45      30.01    131    3438    1179     2842
# 10     5.70    27.38    11.79      49.05     15      72      31      129
# 11     4.86    25.43    12.00      40.29     17      89      42      141
# 12     1.37    13.85    20.71       9.23   1626   16385   24497    10918
# 13     0.86    16.51    17.73       8.02   7447  143746  154404    69859
# 14     2.85    15.79    34.26      13.37    487    2697    5851     2283
# 15     1.54    11.47    21.18       9.93    611    4561    8427     3951

# %%
curr_overall_retention_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

segment AS (
    
    SELECT
        customer_id,
        taxi_ltr_segment ltr_segment,
        taxi_retention_segments retention_segment,
        taxi_lifetime_stage lifetime_stage,
        taxi_service_affinity service_affinity,
        gender_tag gender
    FROM
        datasets.iallocator_customer_segments
    WHERE 
        run_date = '2024-09-05'
    
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        segment.retention_segment,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        segment
        ON exp_category.customer_id=segment.customer_id
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        retention_segment,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            retention_segment,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
curr_overall_retention_df=pd.read_sql(curr_overall_retention_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/3862842824.py:244: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_overall_retention_df=pd.read_sql(curr_overall_retention_query,conn)

# %%
curr_overall_retention_df.to_csv('curr_overall_retention_only_df.csv',index=False)

# %%
curr_overall_retention_df
# Out:
#    sample_category      user_type retention_segment  customers  fe_count  \
# 0          control  clicked_users           DORMANT        455      2781
# 1          control  clicked_users             ELITE        582      5429
# 2          control  clicked_users              GOLD        570      3601
# 3          control  clicked_users                HH        358      2475
# 4          control  clicked_users          INACTIVE        221      1254
UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_overall_retention_df=pd.read_sql(curr_overall_retention_query,conn)

# %%
curr_overall_retention_df
# Out:
#    sample_category      user_type ltr_segment retention_segment  customers  \
# 0          control  clicked_users          HH           DORMANT        162
# 1          control  clicked_users          HH                HH        358
# 2          control  clicked_users          HH          INACTIVE        116
# 3          control  clicked_users         PHH           DORMANT        293
# 4          control  clicked_users         PHH             ELITE        582
# 5          control  clicked_users         PHH              GOLD        570
# 6          control  clicked_users         PHH          INACTIVE        105
# 7          control  clicked_users         PHH          PLATINUM        600
# 8          control  clicked_users         PHH             PRIME         35
# 9          control  clicked_users         PHH            SILVER        328
# 10         control  clicked_users     UNKNOWN           UNKNOWN        114
# 11         control  clicked_users        None              None        260
# 12         control           None          HH           DORMANT      24609
# 13         control           None          HH                HH      52719
# 14         control           None          HH          INACTIVE      23009
# 15         control           None         PHH           DORMANT      55208
# 16         control           None         PHH             ELITE      62709
# 17         control           None         PHH              GOLD      79104
# 18         control           None         PHH          INACTIVE      20578
# 19         control           None         PHH          PLATINUM      76930
# 20         control           None         PHH             PRIME       3519
# 21         control           None         PHH            SILVER      49645
# 22         control           None     UNKNOWN           UNKNOWN      14813
# 23         control           None        None              None      40583
# 24            test  clicked_users          HH           DORMANT         85
# 25            test  clicked_users          HH                HH        354
# 26            test  clicked_users          HH          INACTIVE         80
# 27            test  clicked_users         PHH           DORMANT        188
# 28            test  clicked_users         PHH             ELITE        686
# 29            test  clicked_users         PHH              GOLD        508
# 30            test  clicked_users         PHH          INACTIVE         68
# 31            test  clicked_users         PHH          PLATINUM        587
# 32            test  clicked_users         PHH             PRIME         42
# 33            test  clicked_users         PHH            SILVER        240
# 34            test  clicked_users     UNKNOWN           UNKNOWN         95
# 35            test  clicked_users        None              None        108
# 36            test           None          HH           DORMANT      24135
# 37            test           None          HH                HH      52052
# 38            test           None          HH          INACTIVE      22258
# 39            test           None         PHH           DORMANT      54326
# 40            test           None         PHH             ELITE      60757
# 41            test           None         PHH              GOLD      77496
# 42            test           None         PHH          INACTIVE      20139
# 43            test           None         PHH          PLATINUM      75288
# 44            test           None         PHH             PRIME       3506
# 45            test           None         PHH            SILVER      48364
# 46            test           None     UNKNOWN           UNKNOWN      14523
# 47            test           None        None              None      40172
#
#     fe_count  gross_count  net_count  fe2rr    g2n  fe2net    aor  \
# 0       1029          444         79  43.15  17.79    7.68  33.78
# 1       2475         1101        231  44.48  20.98    9.33  37.15
# 2        752          341         54  45.35  15.84    7.18  30.79
# 3       1752          809        131  46.18  16.19    7.48  31.40
# 4       5429         2784        679  51.28  24.39   12.51  37.54
# 5       3601         1741        408  48.35  23.43   11.33  36.47
# 6        502          231         40  46.02  17.32    7.97  29.44
# 7       4440         2330        453  52.48  19.44   10.20  34.08
# 8        344          154         42  44.77  27.27   12.21  44.16
# 9       2033          977        199  48.06  20.37    9.79  34.29
# 10       696          316         28  45.40   8.86    4.02  21.52
# 11      1930          782        166  40.52  21.23    8.60  32.99
# 12     93744        21943      10607  23.41  48.34   11.31  72.91
# 13    275278        78986      44751  28.69  56.66   16.26  76.01
# 14     94772        20449      10213  21.58  49.94   10.78  74.40
# 31                      35     1.53    37.17    12.02      29.47     37
# 32                      46     1.50    32.00    15.50      21.00      3
# 33                      53     2.17    33.78    10.86      36.07     18
# 34                      83     5.70    27.38    11.79      49.05     15
# 35                      35     4.86    25.43    12.00      40.29     17
# 36                      13     1.72    15.11    23.60      10.77    374
# 37                      13     1.18    13.66    18.94       8.30    908
# 38                      13     1.76    13.18    24.44      11.16    344
# 39                      13     1.14    16.84    20.92      10.48    707
# 40                      13     0.67    16.53    16.84       7.20   2178
# 41                      13     1.03    16.27    18.16       8.30   1609
# 42                      12     1.27    16.14    20.96      11.08    254
# 43                      13     0.87    17.11    17.73       8.10   1877
# 44                      14     0.65    15.29    15.11       4.80    133
# 45                      14     0.98    15.21    17.92       8.87    689
# 46                      12     2.85    15.79    34.26      13.37    487
# 47                      13     1.54    11.47    21.18       9.93    611
#
#     cobra  ocara  expired
# 0     129     71      151
# 1     295    178      359
# 2     100     50      121
# 3     259    120      279
# 4     988    362      721
# 5     566    223      517
# 6      64     28       97
# 7     812    339      695
# 8      54     26       29
# 9     315    134      309
# 10     81     40      154
# 11    164     90      332
# 12   3171   5286     2379
# 13  11259  14948     6689
# 14   2767   4895     2146
# 15  10848  12853     6590
# 16  55618  55770    24029
# 17  25949  28832    13585
# 18   3235   4294     2159
# 19  37862  39558    18117
# 20   3070   3040     1075
# 21  10929  12909     6484
# 22   2754   6550     2297
# 23   4380   8449     3713
# 24     72     32      104
# 25    319    162      392
# 26     79     21       96
# 27    215     69      190
# 28   1289    439      925
# 29    644    238      583
# 30     49     22       92
# 31    897    290      711
# 32     64     31       42
# 33    280     90      299
# 34     72     31      129
# 35     89     42      141
# 36   3288   5133     2343
# 37  10520  14584     6393
# 38   2577   4780     2182
# 39  10452  12982     6502
# 40  53935  54931    23479
# 41  25503  28457    13007
# 42   3232   4196     2218
# 43  36834  38185    17451
# 44   3132   3094      982
# 45  10658  12559     6220
# 46   2697   5851     2283
# 47   4561   8427     3951

# %%
curr_overall_service_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category

        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        rr_net.service_category,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        service_category,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            service_category,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
curr_overall_service_df=pd.read_sql(curr_overall_service_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/3379055199.py:232: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_overall_service_df=pd.read_sql(curr_overall_service_query,conn)

# %%
filtered_df = df[df['service_category'].notnull()]

# %%
curr_overall_service_df=curr_overall_service_df[curr_overall_service_df['service_category'].notnull()]

# %%
curr_overall_service_df
# Out:
#    sample_category      user_type service_category  customers  fe_count  \
# 0          control  clicked_users             auto       2017      4775
# 1          control  clicked_users             bike       1766      4256
# 2          control  clicked_users              cab        795      1557

        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        --AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2
        )
    ORDER BY 1,2


"""
past_overall_df=pd.read_sql(past_overall_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/3217329975.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   past_overall_df=pd.read_sql(past_overall_query,conn)

# %%
past_overall_df
# Out:
#   sample_category      user_type  customers  fe_count  gross_count  net_count  \
# 0         control  clicked_users       2419     34431        14257       7170
# 1         control           None     355630   3535059      1315561     746010
# 2            test  clicked_users       2325     39170        16657       7996
# 3            test           None     347069   3437069      1281944     725859
#
#    fe2rr    g2n  fe2net    aor  impression_count  click_count    ctr  \
# 0  41.41  50.29   20.82  66.56              2719         2436  89.59
# 1  37.21  56.71   21.10  74.43            147383            0   0.00
# 2  42.52  48.00   20.41  65.32              2617         2344  89.57
# 3  37.30  56.62   21.12  74.34             86277            0   0.00
#
#    median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0                121                131                270
# 1                 96                125                272
# 2                139                139                287
# 3                 97                125                272
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       163                      16     1.03    19.98
# 1                       163                      14     0.91    16.55
# 2                       176                      19     1.75    19.99
# 3                       166                      14     0.94    16.57
#
#    % ocara  % expired  cobrm   cobra   ocara  expired
# 0    15.98      12.40    147    2848    2278     1768
# 1    17.38       8.11  11910  217693  228635   106674
# 2    16.95      12.93    292    3330    2824     2153
# 3    17.37       8.14  12100  212394  222723   104344

# %%
past_overall_df.to_csv('past_overall_df.csv',index=False)

# %%
click_time_bucket_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
         
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

click_time AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        event_epoch
         
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
),


fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        order_requested_epoch,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category

        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        rr_net.service_category,
        rr_net.order_requested_epoch,
        click_time.event_epoch,
        user_type
    FROM 
        intermediate_merge
    LEFT JOIN 
        click_time
        ON intermediate_merge.userid=click.userid
        and intermediate_merge.yyyymmdd=click.yyyymmdd
        and intermediate_merge.adid=click.adid
        and intermediate_merge.click_adid is not null
    LEFT JOIN 
        fe_tbl
        ON intermediate_merge.customer_id = fe_tbl.user_id 
        AND intermediate_merge.yyyymmdd = fe_tbl.yyyymmdd
        and intermediate_merge.click_adid is not null
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
        
        
)

SELECT
        sample_category,
        user_type,
        time_interval,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            CASE 
                WHEN click_adid IS NOT NULL THEN 
                    CASE 
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 0 AND 50 THEN '0-50 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 51 AND 100 THEN '51-100 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 101 AND 150 THEN '101-150 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 151 AND 200 THEN '151-200 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 201 AND 250 THEN '201-250 seconds'
                        ELSE '> 250 seconds'
                    END
                ELSE NULL
            END AS time_interval,

            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
            and click_adid is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
click_time_bucket_df=pd.read_sql(click_time_bucket_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/2356992927.py:275: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   click_time_bucket_df=pd.read_sql(click_time_bucket_query,conn)

# %%
click_time_bucket_df
# Out:
#    sample_category      user_type    time_interval  customers  fe_count  \
# 0          control  clicked_users     0-50 seconds       3377      8763
# 1          control  clicked_users  101-150 seconds       1768      2442
# 2          control  clicked_users  151-200 seconds       1596      2216
# 3          control  clicked_users  201-250 seconds       1439      2024
# 4          control  clicked_users   51-100 seconds       1940      2857
# 5          control  clicked_users    > 250 seconds       3436     24332
# 6             test  clicked_users     0-50 seconds       2943      9042
# 7             test  clicked_users  101-150 seconds       1750      2754
# 8             test  clicked_users  151-200 seconds       1678      2566
# 9             test  clicked_users  201-250 seconds       1523      2312
# 10            test  clicked_users   51-100 seconds       1964      3270
# 11            test  clicked_users    > 250 seconds       2976     22792
#
#     gross_count  net_count   fe2rr    g2n  fe2net    aor  impression_count  \
# 0          9046       1895  103.23  20.95   21.63  35.62              3757
# 1          2500        231  102.38   9.24    9.46  20.12              2001
# 2          2282        177  102.98   7.76    7.99  18.14              1795
# 3          2091        111  103.31   5.31    5.48  16.12              1635
# 4          2914        348  102.00  11.94   12.18  24.57              2183
# 5         11331       2318   46.57  20.46    9.53  34.40              3831
# 6          9367       1839  103.59  19.63   20.34  32.80              3280
# 7          2824        196  102.54   6.94    7.12  16.75              1951
# 8          2647        151  103.16   5.70    5.88  15.60              1877
# 9          2380        121  102.94   5.08    5.23  14.79              1712
# 10         3361        356  102.78  10.59   10.89  20.35              2191
# 11        11265       2114   49.43  18.77    9.28  31.30              3325
#
#     click_count    ctr  median_cobrm_time  median_cobra_time  \
# 0          3396  90.39                171                154
# 1          1772  88.56                131                131
# 2          1604  89.36                187                160
# 3          1447  88.50                233                195
# 4          1948  89.23                136                102
# 5          3456  90.21                156                146
# 6          2965  90.40                100                150
# 7          1759  90.16                129                133
# 8          1689  89.98                148                168
# 9          1532  89.49                179                196
# 10         1975  90.14                 73                115
# 11         3000  90.23                137                150
#
#     median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                 335                       181                      55
# 1                 255                       137                     139
# 2                 245                       166                     173
# 3                 247                       204                     163
# 4                 277                       120                     113
# 5                 309                       165                      34
# 6                 361                       170                      45
# 7                 253                       137                     149
# 8                 203                       167                     159
# 9                 251                       200                     114
# 10                264                       117                     122
# 11                374                       173                      28
#
#     % cobrm  % cobra  % ocara  % expired  cobrm  cobra  ocara  expired
# 0      1.76    32.95    14.51      29.64    159   2981   1313     2681
# 1      3.08    46.44    10.84      30.36     77   1161    271      759
# 2      3.02    48.20    10.34      30.54     69   1100    236      697
# 3      3.20    50.45    10.76      30.18     67   1055    225      631
# 4      2.40    42.72    12.59      30.27     70   1245    367      882
# 5      1.89    31.61    13.79      32.07    214   3582   1562     3634
# 6      1.95    35.96    13.00      29.29    183   3368   1218     2744
# 7      2.94    49.75     9.81      30.56     83   1405    277      863
# 8      3.10    51.61     9.86      29.69     82   1366    261      786
# 9      3.03    51.89     9.66      30.29     72   1235    230      721
# 10     2.77    46.27     9.70      30.62     93   1555    326     1029
# 11     2.00    34.65    12.41      32.06    225   3903   1398     3611

# %%
click_time_bucket_df
# Out:
#   sample_category      user_type  customers  fe_count  gross_count  net_count  \
# 0         control  clicked_users       3523     24983        12010       2510
# 1            test  clicked_users       3041     23245        11735       2249
#
#    fe2rr    g2n  fe2net    aor  impression_count  click_count    ctr  \
# 0  48.07  20.90   10.05  34.88              3918         3543  90.43
# 1  50.48  19.16    9.68  31.80              3391         3066  90.42
#
#    median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0                162                147                307
# 1                133                150                360
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       165                      37     1.88    31.87
# 1                       171                      32     1.96    34.67
#
#    % ocara  % expired  cobrm  cobra  ocara  expired
# 0    13.83      31.34    226   3827   1661     3764
# 1    12.50      31.56    230   4069   1467     3704

# %%
curr_overall_service_df
# Out:
#    sample_category      user_type    time_interval  customers  fe_count  \
# 0          control  clicked_users     0-50 seconds       3122      3151
# 1          control  clicked_users  101-150 seconds         38        38
# 2          control  clicked_users  151-200 seconds         34        34
# 3          control  clicked_users  201-250 seconds         28        28
# 4          control  clicked_users   51-100 seconds         28        28
# 5          control  clicked_users    > 250 seconds       3394     22272
# 6             test  clicked_users     0-50 seconds       2702      2734
# 7             test  clicked_users  101-150 seconds         19        19
# 8             test  clicked_users  151-200 seconds         27        27
# 9             test  clicked_users  201-250 seconds         32        32
# 10            test  clicked_users   51-100 seconds         53        53
# 11            test  clicked_users    > 250 seconds       2941     20849
#
#     gross_count  net_count   fe2rr    g2n  fe2net    aor  impression_count  \
# 0          3151        635  100.00  20.15   20.15  35.35              3466
# 1            38          0  100.00   0.00    0.00  10.53                58
# 2            34          2  100.00   5.88    5.88  17.65                51
# 3            28          1  100.00   3.57    3.57  14.29                45
# 4            28          3  100.00  10.71   10.71  21.43                44
# 5          8757       1871   39.32  21.37    8.40  34.94              3789
# 6          2734        562  100.00  20.56   20.56  34.89              3003
# 7            19          1  100.00   5.26    5.26  21.05                28
# 8            27          1  100.00   3.70    3.70  11.11                41
# 9            32          2  100.00   6.25    6.25  12.50                54
# 10           53          5  100.00   9.43    9.43  16.98                67
# 11         8902       1686   42.70  18.94    8.09  31.07              3290
#
#     click_count    ctr  median_cobrm_time  median_cobra_time  \
# 0          3137  90.51              222.0                199
# 1            38  65.52               91.0                116
# 2            34  66.67              277.0                154
# 3            28  62.22                NaN                194
# 4            28  63.64                NaN                 67
# 5          3414  90.10              165.0                149
# 6          2720  90.58              226.0                191
# 7            19  67.86              211.0                103
# 8            27  65.85              171.0                171
# 9            32  59.26              197.0                205
# 10           53  79.10              135.0                 98
# 11         2965  90.12              121.0                148
#
#     median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                 388                       228                      67
# 1                  29                       111                      13
# 2                 166                       157                      98
# 3                 208                       199                     118
# 4                 426                        68                     175
# 5                 332                       172                      33
# 6                 407                       221                      51
# 7                 275                       109                     123
# 8                  53                       170                      10
# 9                  25                       201                      25
# 10                456                       122                     179
# 11                374                       171                      34
#
#     % cobrm  % cobra  % ocara  % expired  cobrm  cobra  ocara  expired
# 0      1.33    27.86    15.07      35.42     42    878    475     1116
# 1      5.26    55.26    10.53      28.95      2     21      4       11
# 2      2.94    55.88    11.76      23.53      1     19      4        8
# 3      0.00    57.14    10.71      28.57      0     16      3        8
# 4      0.00    50.00    10.71      28.57      0     14      3        8
# 5      2.07    33.00    13.42      29.95    181   2890   1175     2623
# 6      1.35    28.49    14.16      35.26     37    779    387      964
# 7      5.26    42.11    15.79      31.58      1      8      3        6
# 8      7.41    51.85     7.41      29.63      2     14      2        8
# 9      3.13    53.13     6.25      31.25      1     17      2       10
# 10     1.89    45.28     7.55      35.85      1     24      4       19
# 11     2.11    36.42    12.01      30.40    188   3242   1069     2706

# %%
click_time_bucket_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
         
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

click_time AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        MIN(event_epoch) as event_epoch
         
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
        group by 1,2,3
),


fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

req_time as(
    select
            yyyymmdd, 
            customer_id,
            estimate_id AS fare_estimate_id, 
            Min(order_requested_epoch) as order_requested_epoch
    FROM 
        orders.order_logs_fact fact
        
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android' 
    group by 1,2,3

),


rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category

        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        rr_net.service_category,
        req_time.order_requested_epoch,
        click_time.event_epoch,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        click_time
            ON click.userid=click_time.userid
            and click.yyyymmdd=click_time.yyyymmdd
            and click_time.adid=click.adid
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
    LEFT JOIN req_time
        ON req_time.yyyymmdd = rr_net.yyyymmdd
        AND req_time.customer_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
        
        
)

SELECT
        sample_category,
        user_type,
        time_interval,
        customers,
        --fe_count,
        gross_count,
        net_count,
        --COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            CASE 
                WHEN click_adid IS NOT NULL THEN 
                    CASE 
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 0 AND 50 THEN '0-50 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 51 AND 100 THEN '51-100 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 101 AND 150 THEN '101-150 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 151 AND 200 THEN '151-200 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 201 AND 250 THEN '201-250 seconds'
                        WHEN (event_epoch / 1000 - order_requested_epoch / 1000) BETWEEN 251 AND 300 THEN '251-300 seconds'
                        ELSE '> 250 seconds'
                    END
                ELSE NULL
            END AS time_interval,

            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
            and click_adid is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
click_time_bucket_df=pd.read_sql(click_time_bucket_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/2511804075.py:303: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   click_time_bucket_df=pd.read_sql(click_time_bucket_query,conn)

# %%
click_time_bucket_df
# Out:
#    sample_category      user_type    time_interval  customers  gross_count  \
# 0          control  clicked_users     0-50 seconds       3122        10920
# 1          control  clicked_users  101-150 seconds         36          197
# 2          control  clicked_users  151-200 seconds         29          179
# 3          control  clicked_users  201-250 seconds         26          147
# 4          control  clicked_users  251-300 seconds         24          107
# 5          control  clicked_users   51-100 seconds         25          135
# 6          control  clicked_users    > 250 seconds       3351        10894
# 7             test  clicked_users     0-50 seconds       2701        10579
# 8             test  clicked_users  101-150 seconds         18           85
# 9             test  clicked_users  151-200 seconds         24          124
# 10            test  clicked_users  201-250 seconds         27          165
# 11            test  clicked_users  251-300 seconds         19           98
# 12            test  clicked_users   51-100 seconds         51          237
# 13            test  clicked_users    > 250 seconds       2909        10925
#
#     net_count    g2n  fe2net    aor  impression_count  click_count    ctr  \
# 0        2301  21.07   23.84  35.01              3466         3137  90.51
# 1          23  11.68   12.57  25.38                55           36  65.45
# 2          19  10.61   11.80  20.67                44           29  65.91
# 3          25  17.01   17.99  29.93                42           26  61.90
# 4          17  15.89   18.28  27.10                32           24  75.00
# 5          26  19.26   20.31  33.33                38           25  65.79
# 6        2265  20.79    9.39  34.89              3746         3371  89.99
# 7        2053  19.41   21.79  32.20              3002         2719  90.57
# 8          15  17.65   18.99  44.71                27           18  66.67
# 9          18  14.52   15.25  25.81                37           24  64.86
# 10         18  10.91   12.41  20.00                46           27  58.70
# 11         16  16.33   17.39  26.53                32           19  59.38
# 12         32  13.50   15.53  27.85                63           51  80.95
# 13       2060  18.86    9.11  31.57              3257         2933  90.05
#
#     median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0               176.0                156                335
# 1               134.0                123                302
# 2                 NaN                149                304
# 3                 NaN                156                260
# 4               134.0                149                390
# 5                 NaN                110                446
# 6               144.0                142                224
# 7               124.0                156                374
# 8                40.0                118                224
# 9               171.0                168                275
# 10               78.0                150                312
# 11              232.0                169                490
# 12               43.0                125                279
# 13              122.0                144                329
#
#     median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                        178                      40     1.91    32.29
# 1                        133                      29     2.03    47.72
# 2                        154                      63     0.00    57.54
# 3                        167                      25     0.00    48.30
# 4                        164                      58     2.80    39.25
# 5                        129                      55     0.00    46.67
# 6                        152                      30     1.92    33.39
# 7                        179                      35     1.96    35.02
# 8                        132                      12     3.53    30.59
# 9                        172                      43     3.23    45.16
# 10                       150                      13     1.21    51.52
# 11                       195                      36     3.06    53.06
# 12                       132                      14     2.53    38.82
# 13                       161                      23     2.06    36.02
#
#     % ocara  % expired  cobrm  cobra  ocara  expired
# 0     13.78      30.76    209   3526   1505     3359
# 1     13.20      24.87      4     94     26       49
# 2     10.06      21.79      0    103     18       39
# 3     12.93      21.77      0     71     19       32
# 4     11.21      30.84      3     42     12       33
# 5     14.07      20.00      0     63     19       27
# 6     13.94      29.77    209   3638   1519     3243
# 7     12.65      30.83    207   3705   1338     3261
# 8     27.06      21.18      3     26     23       18
# 9     11.29      25.81      4     56     14       32
# 10     9.09      27.27      2     85     15       45
# 11    10.20      17.35      3     52     10       17
# 12    14.35      30.80      6     92     34       73
# 13    12.59      30.35    225   3935   1375     3316

# %%
click_time_bucket_df
# Out:
#    sample_category      user_type    time_interval  customers  fe_count  \
# 0          control  clicked_users     0-50 seconds       3122      9652
# 1          control  clicked_users  101-150 seconds         36       183
# 2          control  clicked_users  151-200 seconds         29       161
# 3          control  clicked_users  201-250 seconds         26       139
# 4          control  clicked_users   51-100 seconds         25       128
# 5          control  clicked_users    > 250 seconds       3351     24134
# 6             test  clicked_users     0-50 seconds       2701      9420
# 7             test  clicked_users  101-150 seconds         18        79
# 8             test  clicked_users  151-200 seconds         24       118
# 9             test  clicked_users  201-250 seconds         27       145
# 10            test  clicked_users   51-100 seconds         51       206
# 11            test  clicked_users    > 250 seconds       2909     22624
#
#     gross_count  net_count   fe2rr    g2n  fe2net    aor  impression_count  \
# 0         10920       2301  113.14  21.07   23.84  35.01              3466
# 1           197         23  107.65  11.68   12.57  25.38                55
# 2           179         19  111.18  10.61   11.80  20.67                44
# 3           147         25  105.76  17.01   17.99  29.93                42
# 4           135         26  105.47  19.26   20.31  33.33                38
# 5         10903       2266   45.18  20.78    9.39  34.88              3746
# 6         10579       2053  112.30  19.41   21.79  32.20              3002
# 7            85         15  107.59  17.65   18.99  44.71                27
# 8           124         18  105.08  14.52   15.25  25.81                37
# 9           165         18  113.79  10.91   12.41  20.00                46
# 10          237         32  115.05  13.50   15.53  27.85                63
# 11        10933       2061   48.32  18.85    9.11  31.56              3257
#
#     click_count    ctr  median_cobrm_time  median_cobra_time  \
# 0          3137  90.51              174.0                156
# 1            36  65.45              134.0                124
# 2            29  65.91                NaN                149
# 3            26  61.90                NaN                156
# 4            25  65.79                NaN                111
# 5          3371  89.99              143.0                142
# 6          2719  90.57              126.0                156
# 7            18  66.67               40.0                119
# 8            24  64.86              171.0                169
# 9            27  58.70               78.0                150
# 10           51  80.95               43.0                125
# 11         2933  90.05              123.0                144
#
#     median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0                 335                       178                      39
# 1                 293                       132                      27
# 2                 306                       154                      63
# 3                 265                       167                      26
# 4                 445                       129                      54
# 5                 224                       152                      30
# 6                 378                       179                      37
# 7                 221                       132                      13
# 8                 285                       173                      40
# 9                 310                       151                      13
# 10                277                       132                      13
# 11                334                       162                      23
#
#     % cobrm  % cobra  % ocara  % expired  cobrm  cobra  ocara  expired
# 0      1.91    32.29    13.78      30.76    209   3526   1505     3359
# 1      2.03    47.72    13.20      24.87      4     94     26       49
# 2      0.00    57.54    10.06      21.79      0    103     18       39
# 3      0.00    48.30    12.93      21.77      0     71     19       32
# 4      0.00    46.67    14.07      20.00      0     63     19       27
# 5      1.92    33.38    13.94      29.80    209   3639   1520     3249
# 6      1.96    35.02    12.65      30.83    207   3705   1338     3261
# 7      3.53    30.59    27.06      21.18      3     26     23       18
# 8      3.23    45.16    11.29      25.81      4     56     14       32
# 9      1.21    51.52     9.09      27.27      2     85     15       45
# 10     2.53    38.82    14.35      30.80      6     92     34       73
# 11     2.07    36.03    12.59      30.34    226   3939   1376     3317

# %%
click_time_bucket_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
         
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

click_time AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        MIN(event_epoch) as event_epoch
         
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
        group by 1,2,3
),


fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

req_time as(
    select
            yyyymmdd, 
            customer_id,
            estimate_id AS fare_estimate_id, 
            Min(order_requested_epoch) as order_requested_epoch
    FROM 
        orders.order_logs_fact fact
        
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android' 
    group by 1,2,3

),


rr_net AS (
    SELECT 
        fact.yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN click.adid is not null
            THEN (event_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_click,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category

        
    
    FROM 
        orders.order_logs_fact fact
    LEFT JOIN 
        click
        ON customer_id = click.userid 
        AND fact.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        click_time
            ON click.userid=click_time.userid
            and click.yyyymmdd=click_time.yyyymmdd
            and click_time.adid=click.adid
    WHERE 
         fact.yyyymmdd >= '20240905' AND fact.yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        rr_net.service_category,
        rr_net.time_taken_to_click,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        click_time
            ON click.userid=click_time.userid
            and click.yyyymmdd=click_time.yyyymmdd
            and click_time.adid=click.adid
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON 
        -- fe_tbl.yyyymmdd = rr_net.yyyymmdd
        -- AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
        -and 
        
        
)

SELECT
        sample_category,
        user_type,
        time_interval,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            CASE 
                WHEN time_taken_to_click IS NOT NULL THEN 
                    CASE 
                        WHEN time_taken_to_click BETWEEN 0 AND 50 THEN '0-50 seconds'
                        WHEN time_taken_to_click BETWEEN 51 AND 100 THEN '51-100 seconds'
                        WHEN time_taken_to_click BETWEEN 101 AND 150 THEN '101-150 seconds'
                        WHEN time_taken_to_click BETWEEN 151 AND 200 THEN '151-200 seconds'
                        WHEN time_taken_to_click BETWEEN 201 AND 250 THEN '201-250 seconds'
                        WHEN time_taken_to_click BETWEEN 251 AND 300 THEN '251-300 seconds'
                    END
                ELSE NULL
            END AS time_interval,


            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
            and click_adid is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
click_time_bucket_df=pd.read_sql(click_time_bucket_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/3384563671.py:312: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   click_time_bucket_df=pd.read_sql(click_time_bucket_query,conn)

# %%
click_time_bucket_df
# Out:
#    sample_category      user_type    time_interval  customers  fe_count  \
# 0          control  clicked_users     0-50 seconds       3122      3151
# 1          control  clicked_users  101-150 seconds         38        38
# 2          control  clicked_users  151-200 seconds         34        34
# 3          control  clicked_users  201-250 seconds         28        28
# 4          control  clicked_users  251-300 seconds         27        27
# 5          control  clicked_users   51-100 seconds         28        28
# 6          control  clicked_users    > 300 seconds       2810      7859
# 7          control  clicked_users             None       3165     14395
# 8             test  clicked_users     0-50 seconds       2702      2734
# 9             test  clicked_users  101-150 seconds         19        19
# 10            test  clicked_users  151-200 seconds         27        27
# 11            test  clicked_users  201-250 seconds         32        32
# 12            test  clicked_users  251-300 seconds         22        22
# 13            test  clicked_users   51-100 seconds         53        53
# 14            test  clicked_users    > 300 seconds       2505      7960
# 15            test  clicked_users             None       2735     12873
#
#     gross_count  net_count   fe2rr    g2n  fe2net    aor  impression_count  \
# 0          3151        635  100.00  20.15   20.15  35.35              3466
# 1            38          0  100.00   0.00    0.00  10.53                58
# 2            34          2  100.00   5.88    5.88  17.65                51
# 3            28          1  100.00   3.57    3.57  14.29                45
# 4            27          4  100.00  14.81   14.81  25.93                36
# 5            28          3  100.00  10.71   10.71  21.43                44
# 6          8731       1867  111.10  21.38   23.76  34.97              3198
# 7             0          0    0.00   0.00    0.00   0.00              3544
# 8          2734        562  100.00  20.56   20.56  34.89              3003
# 9            19          1  100.00   5.26    5.26  21.05                28
# 10           27          1  100.00   3.70    3.70  11.11                41
# 11           32          2  100.00   6.25    6.25  12.50                54
# 12           22          1  100.00   4.55    4.55   4.55                37
# 13           53          5  100.00   9.43    9.43  16.98                67
# 14         8882       1685  111.58  18.97   21.17  31.13              2849
# 15            0          0    0.00   0.00    0.00   0.00              3066
#
#     click_count    ctr  median_cobrm_time  median_cobra_time  \
# 0          3142  90.65              220.0              198.0
# 1            39  67.24               91.0              119.0
# 2            35  68.63              277.0              150.0
# 3            30  66.67                NaN              191.0
# 4            28  77.78              134.0              228.0
# 5            28  63.64                NaN               67.0
# 6          2828  88.43              168.0              149.0
# 7          3183  89.81                NaN                NaN
# 8          2724  90.71              226.0              191.0
# 9            19  67.86              211.0              103.0
# 10           29  70.73              171.0              156.0
# 11           33  61.11              197.0              204.0
# 12           24  64.86              261.0              246.0
# 13           54  80.60              135.0               89.0
# 14         2529  88.77              118.0              150.0
# 15         2759  89.99                NaN                NaN
#
#     median_ocara_time  median_cancellation_time  median_acceptance_time  \
# 0               385.0                     227.0                    66.0
# 1                29.0                     112.0                    13.0
# 2               166.0                     154.0                    98.0
# 3               208.0                     197.0                   118.0
# 4               245.0                     228.0                    32.0
# 5               426.0                      68.0                   175.0
# 6               336.0                     172.0                    34.0
# 7                 NaN                       NaN                     NaN
# 8               406.0                     219.0                    50.0
# 9               275.0                     109.0                   123.0
# 10               53.0                     161.0                    10.0
# 11               25.0                     202.0                    25.0
# 12                NaN                     248.0                    18.0
# 13              456.0                     103.0                   179.0
# 14              373.0                     171.0                    34.0
# 15                NaN                       NaN                     NaN
#
#     % cobrm  % cobra  % ocara  % expired  cobrm  cobra  ocara  expired
# 0      1.33    27.86    15.07      35.42     42    878    475     1116
# 1      5.26    55.26    10.53      28.95      2     21      4       11
# 2      2.94    55.88    11.76      23.53      1     19      4        8
# 3      0.00    57.14    10.71      28.57      0     16      3        8
# 4      3.70    40.74    11.11      29.63      1     11      3        8
# 5      0.00    50.00    10.71      28.57      0     14      3        8
# 6      2.06    32.99    13.42      29.95    180   2880   1172     2615
# 7      0.00     0.00     0.00       0.00      0      0      0        0
# 8      1.35    28.49    14.16      35.26     37    779    387      964
# 9      5.26    42.11    15.79      31.58      1      8      3        6
# 10     7.41    51.85     7.41      29.63      2     14      2        8
# 11     3.13    53.13     6.25      31.25      1     17      2       10
# 12     4.55    77.27     0.00      13.64      1     17      0        3
# 13     1.89    45.28     7.55      35.85      1     24      4       19
# 14     2.11    36.32    12.04      30.44    187   3226   1069     2704
# 15     0.00     0.00     0.00       0.00      0      0      0        0

# %%
curr_overall_service_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp,
        CASE 
            WHEN service_obj_service_name IN ('Auto', 'Auto Lite', 'Auto NCR', 'Auto Pool', 'AutoPremium', 'CityAuto') THEN 'auto'
            WHEN service_obj_service_name IN ('Bike Lite', 'Bike Pink', 'Bike Metro', 'Link') THEN 'bike'
            WHEN service_obj_service_name IN ('CabEconomy', 'CabPremium') THEN 'cab'
            ELSE 'other'
        END AS service_category

        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        rr_net.service_category,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        service_category,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            service_category,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2,3
        )
    ORDER BY 1,2,3


"""
curr_overall_service_df=pd.read_sql(curr_overall_service_query,conn)

# %%
time_bucket_query=f"""
with olf as (

    SELECT
        yyyymmdd,
        customer_id,
        order_id,
        order_requested_epoch,
        customer_cancelled_epoch
        
    FROM 
        orders.order_logs_fact
    WHERE
        yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND modified_order_status = 'COBRA'
    ),

    click AS (
    
        SELECT
            yyyymmdd,
            adid,
            userid,
            epoch click_epoch
             
        FROM 
            canonical.iceberg_log_telemetry_ads_impressions_immutable
        WHERE  
             yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
            --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
            --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
            AND responseType = 'GAMBanner'
            AND city = 'Delhi'
            AND appversion >= '8.30.0'
            AND slotname = 'CaptainSearch1'
            AND eventName = 'Ad_Click'
    ),
    
    merge AS (
    
    SELECT 
        olf.*,
        click_epoch,
        (click_epoch / 1000 - order_requested_epoch / 1000) time_to_click,
        row_number() over(partition by olf.yyyymmdd,olf.customer_id,olf.order_id order by click_epoch) seq_no
    FROM 
        olf
    JOIN 
        click
        on olf.yyyymmdd = click.yyyymmdd
        and olf.customer_id = click.userid
        and olf.order_requested_epoch < click.click_epoch
        and olf.customer_cancelled_epoch > click.click_epoch
    )
    
    
    SELECT
        yyyymmdd,
        case 
        when time_to_click <= 60 then '0-60sec'
        when time_to_click between 61 and 120 then '61-120sec'
        when time_to_click between 121 and 180 then '121-180sec'
        when time_to_click between 180 and 240 then '181-240sec'
        when time_to_click > 240 then '240+sec' 
        else 'check' end as click_bucket,
        count(distinct customer_id) customers
    FROM 
        merge
    WHERE 
        seq_no = 1
    GROUP BY 1,2
    ORDER BY 1,2

    """

time_bucket_df=pd.read_sql(time_bucket_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/3122631905.py:79: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   time_bucket_df=pd.read_sql(time_bucket_query,conn)

# %%
time_bucket_df
# Out:
#     yyyymmdd click_bucket  customers
# 0   20240905      0-60sec        151
# 1   20240905   121-180sec        173
# 2   20240905   181-240sec        103
# 3   20240905      240+sec         62
# 4   20240905    61-120sec        227
# 5   20240906      0-60sec        241
# 6   20240906   121-180sec        264
# 7   20240906   181-240sec        172
# 8   20240906      240+sec        109
# 9   20240906    61-120sec        306
# 10  20240907      0-60sec         24
# 11  20240907   121-180sec         40
# 12  20240907   181-240sec         27
# 13  20240907      240+sec         14
# 14  20240907    61-120sec         61
# 15  20240908      0-60sec         14
# 16  20240908   121-180sec         21
# 17  20240908   181-240sec         11
# 18  20240908      240+sec          7
# 19  20240908    61-120sec         28
# 20  20240909      0-60sec         23
# 21  20240909   121-180sec         33
# 22  20240909   181-240sec         28
# 23  20240909      240+sec         23
# 24  20240909    61-120sec         46

# %%
pivot_df = time_bucket_df.pivot(index='yyyymmdd', columns='click_bucket', values='customers')
pivot_df
# Out:
# click_bucket  0-60sec  121-180sec  181-240sec  240+sec  61-120sec
# yyyymmdd
# 20240905          151         173         103       62        227
# 20240906          241         264         172      109        306
# 20240907           24          40          27       14         61
# 20240908           14          21          11        7         28
# 20240909           23          33          28       23         46

# %%
df_percentage = pivot_df.div(pivot_df.sum(axis=1), axis=0) * 100

# %%
df_percentage
# Out:
# click_bucket    0-60sec  121-180sec  181-240sec    240+sec  61-120sec
# yyyymmdd
# 20240905      21.089385   24.162011   14.385475   8.659218  31.703911
# 20240906      22.069597   24.175824   15.750916   9.981685  28.021978
# 20240907      14.457831   24.096386   16.265060   8.433735  36.746988
# 20240908      17.283951   25.925926   13.580247   8.641975  34.567901
# 20240909      15.032680   21.568627   18.300654  15.032680  30.065359

# %%
df_percentage.to_clipboard()

# %%
click_non_click_query=f"""
WITH exp_category AS (
    SELECT 
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
        yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id IN (
            SELECT DISTINCT userid
            FROM canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),
olf AS (
    SELECT
        customer_id,
        order_id,
        order_requested_epoch,
        customer_cancelled_epoch,
        order_status,
        modified_order_status,
        spd_fraud_flag,
        rider_accepted_epoch
    FROM 
        orders.order_logs_fact
    WHERE
        yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        AND city_name = 'Delhi'
),
click AS (
    SELECT
        userid,
        MIN(epoch) AS first_click_epoch
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
        yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName = 'Ad_Click'
    GROUP BY 1
),
merge AS (
    SELECT 
        olf.*,
        ec.sample_category,
        click.first_click_epoch,
        CASE 
            WHEN click.first_click_epoch IS NOT NULL 
                AND olf.order_requested_epoch < click.first_click_epoch
                AND olf.customer_cancelled_epoch > click.first_click_epoch
            THEN (click.first_click_epoch / 1000 - olf.order_requested_epoch / 1000)
            ELSE NULL
        END AS time_to_click,
        CASE 
            WHEN click.first_click_epoch IS NOT NULL THEN
                CASE
                    WHEN olf.order_requested_epoch < click.first_click_epoch
                        AND olf.customer_cancelled_epoch > click.first_click_epoch
                    THEN 'Click Order'
                    ELSE 'No-Click Order'
                END
            ELSE 'Non-Clicked User Order'
        END AS click_status
    FROM 
        olf
    JOIN
        exp_category ec ON olf.customer_id = ec.customer_id
    LEFT JOIN 
        click ON olf.customer_id = click.userid
)
SELECT
    m.sample_category,
    m.click_status,
    COUNT(DISTINCT m.customer_id) AS customers,
    COUNT(DISTINCT m.order_id) AS gross_orders,
    COUNT(DISTINCT CASE WHEN m.order_status = 'dropped' OR m.modified_order_status IN ('OCARA', 'aborted') THEN m.order_id END) AS net_orders,
    COUNT(DISTINCT CASE WHEN m.order_status = 'dropped' OR m.modified_order_status IN ('OCARA', 'aborted') THEN m.order_id END) AS accepted_orders,
    COUNT(DISTINCT CASE WHEN m.modified_order_status = 'COBRM' THEN m.order_id END) AS cobrm_orders,
    COUNT(DISTINCT CASE WHEN m.modified_order_status = 'COBRA' THEN m.order_id END) AS cobra_orders,
    COUNT(DISTINCT CASE WHEN m.modified_order_status = 'OCARA' THEN m.order_id END) AS ocara_orders,
    COUNT(DISTINCT CASE WHEN m.order_status = 'expired' THEN m.order_id END) AS expired_orders,
    AVG(CASE WHEN m.modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
        THEN (m.customer_cancelled_epoch / 1000 - m.order_requested_epoch / 1000) END) AS avg_cancellation_time,
    AVG(CASE WHEN m.order_status = 'dropped' OR m.modified_order_status IN ('OCARA', 'aborted') 
        THEN (m.rider_accepted_epoch / 1000 - m.order_requested_epoch / 1000) END) AS avg_acceptance_time,
    AVG(m.time_to_click) AS avg_time_to_click,
    COALESCE(
        COUNT(DISTINCT CASE WHEN m.order_status = 'dropped' OR m.modified_order_status IN ('OCARA', 'aborted') THEN m.order_id END) * 100.0 / 
        NULLIF(COUNT(DISTINCT m.order_id), 0),
        0
    ) AS acceptance_rate
FROM 
    merge m
GROUP BY 
    m.sample_category,
    m.click_status
ORDER BY 
    m.sample_category, 
    m.click_status
"""
click_non_click_df=pd.read_sql(click_non_click_query,conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/2270914200.py:109: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   click_non_click_df=pd.read_sql(click_non_click_query,conn)

# %%
click_non_click_df
# Out:
#   sample_category            click_status  customers  gross_orders  \
# 0         control             Click Order       1584          1584
# 1         control          No-Click Order       3428         18556
# 2         control  Non-Clicked User Order     362443       1098731
# 3            test             Click Order       1394          1394
# 4            test          No-Click Order       3008         19622
# 5            test  Non-Clicked User Order     355611       1071304
#
#    net_orders  accepted_orders  cobrm_orders  cobra_orders  ocara_orders  \
# 0         432              432            69          1083           430
# 1        8945             8945           353          4343          2637
# 2      812305           812305         14269        178695        200975
# 3         332              332            69           991           328
# 4        9356             9356           325          4993          2738
# 5      792801           792801         13436        173892        196468
#
#    expired_orders  avg_cancellation_time  avg_acceptance_time  \
# 0               0             329.805512           245.101555
# 1            4911             251.282619            86.146002
# 2           93269             286.598180            68.000577
# 3               2             316.913136           268.091580
# 4            4948             253.963060            87.453151
# 5           90957             286.472712            67.677012
#
#    avg_time_to_click  acceptance_rate
# 0         146.975201             27.3
# 1                NaN             48.2
# 2                NaN             73.9
# 3         144.727688             23.8
# 4                NaN             47.7
# 5                NaN             74.0

# %%
time_bucket_query = """
WITH olf AS (
    SELECT
        customer_id,
        order_id,
        order_requested_epoch,
        customer_cancelled_epoch
    FROM 
        orders.order_logs_fact
    WHERE
        yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        AND city_name = 'Delhi'
        AND modified_order_status = 'COBRA'
),

click AS (
    SELECT
        adid,
        userid,
        epoch click_epoch
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
        yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName = 'Ad_Click'
),

merge AS (
    SELECT 
        olf.*,
        click_epoch,
        (click_epoch / 1000 - order_requested_epoch / 1000) time_to_click,
        ROW_NUMBER() OVER(PARTITION BY olf.customer_id, olf.order_id ORDER BY click_epoch) seq_no
    FROM 
        olf
    JOIN 
        click
        ON olf.customer_id = click.userid
        AND olf.order_requested_epoch < click.click_epoch
        AND olf.customer_cancelled_epoch > click.click_epoch
)

SELECT
    CASE 
        WHEN time_to_click <= 60 THEN '0-60sec'
        WHEN time_to_click BETWEEN 61 AND 120 THEN '61-120sec'
        WHEN time_to_click BETWEEN 121 AND 180 THEN '121-180sec'
        WHEN time_to_click BETWEEN 181 AND 240 THEN '181-240sec'
        WHEN time_to_click > 240 THEN '240+sec' 
        ELSE 'check' 
    END AS click_bucket,
    COUNT(DISTINCT customer_id) AS customers
FROM 
    merge
WHERE 
    seq_no = 1
GROUP BY 1
ORDER BY 1
"""

time_bucket_df = pd.read_sql(time_bucket_query, conn)
# Out:
# /var/folders/km/1ltm54y105x6dzlcf44g881c0000gn/T/ipykernel_4765/2279916104.py:65: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   time_bucket_df = pd.read_sql(time_bucket_query, conn)

# %%
time_bucket_df
# Out:
#   click_bucket  customers
# 0      0-60sec        453
# 1   121-180sec        531
# 2   181-240sec        341
# 3      240+sec        215
# 4    61-120sec        667

# %%
# Calculate total customers
total_customers = time_bucket_df['customers'].sum()

# Add a new column for customer percentage
time_bucket_df['customer_percentage'] = (time_bucket_df['customers'] / total_customers) * 100

# Optionally round to 2 decimal places
time_bucket_df['customer_percentage'] = time_bucket_df['customer_percentage'].round(2)

# Display the updated DataFrame
time_bucket_df
# Out:
#   click_bucket  customers  customer_percentage
# 0      0-60sec        453                20.53
# 1   121-180sec        531                24.06
# 2   181-240sec        341                15.45
# 3      240+sec        215                 9.74
# 4    61-120sec        667                30.22

# %%
time_bucket_df.to_clipboard(index=False)

# %% [markdown]
# ## Wip

# %%
curr_overall_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression', 'Ad_Click')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2
        )
    ORDER BY 1,2


"""
curr_overall_df=pd.read_sql(curr_overall_query,conn)
# Out:
# /var/folders/j7/5rtfb17j30s9g9q790v9nr0h0000gn/T/ipykernel_62362/3925239526.py:222: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   curr_overall_df=pd.read_sql(curr_overall_query,conn)

# %%
curr_overall_df
# Out:
#   sample_category      user_type  customers  fe_count  gross_count  net_count  \
# 0         control  clicked_users       3523     24983        12010       2510
# 1         control           None     503477   3064719      1071476     598029
# 2            test  clicked_users       3041     23245        11735       2249
# 3            test           None     493077   2988917      1046105     584167
#
#    fe2rr    g2n  fe2net    aor  impression_count  click_count    ctr  \
# 0  48.07  20.90   10.05  34.88              3918         3543  90.43
# 1  34.96  55.81   19.51  74.61            191032            0   0.00
# 2  50.48  19.16    9.68  31.80              3391         3066  90.42
# 3  35.00  55.84   19.54  74.69            104370            0   0.00
#
#    median_cobrm_time  median_cobra_time  median_ocara_time  \
# 0                173                157                343
# 1                108                127                297
# 2                126                156                380
# 3                106                127                298
#
#    median_cancellation_time  median_acceptance_time  % cobrm  % cobra  \
# 0                       181                      39     1.88    31.87
# 1                       169                      14     1.01    16.04
# 2                       180                      36     1.96    34.67
# 3                       173                      14     0.97    16.00
#
#    % ocara  % expired  cobrm   cobra   ocara  expired
# 0    13.83      31.34    226    3827    1661     3764
# 1    18.42       8.33  10793  171843  197385    89267
# 2    12.50      31.56    230    4069    1467     3704
# 3    18.47       8.32  10171  167398  193184    87020

# %%
curr_overall_query=f"""
WITH exp_category AS (
    SELECT 
        yyyymmdd,
        customer_id,
        sample_category
    FROM 
        iceberg.experiments_internal.rapidex_user_customer_adSlots_v1_root 
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND experiment_name = 'CaptainSearchScreen_meme'
        AND customer_id in (
            SELECT 
                DISTINCT userid
            FROM
                 canonical.iceberg_log_telemetry_ads_impressions_immutable
            WHERE
                 yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
                --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
                --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
                AND city='Delhi'
                AND appversion >= '8.30.0'
        )
),

impression AS (
    SELECT
        yyyymmdd,
        adid,
        userid
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
       -- yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName IN ('Ad_Request', 'Ad_Response', 'Ad_Impression')
    GROUP BY 
        yyyymmdd, adid, userid
    HAVING 
        COUNT(DISTINCT eventName) = 3
),

click AS (
    SELECT
        yyyymmdd,
        adid,
        userid,
        epoch click_epoch,
        'clicked_users' as user_type
    FROM 
        canonical.iceberg_log_telemetry_ads_impressions_immutable
    WHERE  
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND responseType = 'GAMBanner'
        AND city = 'Delhi'
        AND appversion >= '8.30.0'
        AND slotname = 'CaptainSearch1'
        AND eventName = 'Ad_Click'
    GROUP BY 
        1,2,3,4
),

fe_tbl AS (
    SELECT
        DISTINCT
        yyyymmdd,
        user_id,
        city,
        fare_estimate_id,
        quarter_hour
    FROM
        pricing.fare_estimates_enriched fee
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city = 'Delhi'
        AND channel='android'
),

rr_net AS (
    SELECT 
        yyyymmdd, 
        customer_id,
        estimate_id AS fare_estimate_id, 
        order_id, 
        order_status, 
        modified_order_status, 
        spd_fraud_flag,
        quarter_hour,
        CASE 
            WHEN modified_order_status IN ('OCARA', 'COBRA', 'COBRM') 
            THEN (customer_cancelled_epoch / 1000 - order_requested_epoch / 1000) 
        END AS time_spent_in_sec,
        CASE 
            WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') 
            THEN (rider_accepted_epoch / 1000 - order_requested_epoch / 1000)
        END AS time_taken_to_accp
        
    
    FROM 
        orders.order_logs_fact fact
    WHERE 
         yyyymmdd >= '20240905' AND yyyymmdd <= '20240909'
        --yyyymmdd >= date_format({{start_date}},'%Y%m%d')
        --AND yyyymmdd <= date_format({{end_date}},'%Y%m%d')
        AND city_name = 'Delhi'
        AND service_obj_service_name in ('Auto','Auto Lite','Auto NCR','Auto Pool','AutoPremium','CityAuto','Link','Bike Lite','Bike Pink','CabEconomy','Bike Metro', 'CabPremium')
        AND channel_host='android'
),

merge AS (
    SELECT
        exp_category.customer_id,
        exp_category.sample_category,
        fe_tbl.*,
        rr_net.order_id,
        rr_net.order_status,
        rr_net.modified_order_status,
        rr_net.spd_fraud_flag,
        rr_net.time_spent_in_sec,
        rr_net.time_taken_to_accp,
        impression.adid as impression_adid,
        click.adid as click_adid,
        user_type
    FROM 
        exp_category
    LEFT JOIN 
        impression
        ON exp_category.customer_id = impression.userid 
        AND exp_category.yyyymmdd = impression.yyyymmdd
    LEFT JOIN 
        click
        ON exp_category.customer_id = click.userid 
        AND exp_category.yyyymmdd = click.yyyymmdd
    LEFT JOIN 
        fe_tbl
        ON exp_category.customer_id = fe_tbl.user_id 
        AND exp_category.yyyymmdd = fe_tbl.yyyymmdd
    LEFT JOIN rr_net
        ON fe_tbl.yyyymmdd = rr_net.yyyymmdd
        AND fe_tbl.user_id = rr_net.customer_id 
        AND fe_tbl.fare_estimate_id = rr_net.fare_estimate_id
)

SELECT
        sample_category,
        user_type,
        customers,
        fe_count,
        gross_count,
        net_count,
        COALESCE(TRY(gross_count*100.00/fe_count), 0) fe2rr,
        COALESCE(TRY(net_count*100.00/gross_count), 0) g2n,
        COALESCE(TRY(net_count*100.00/fe_count), 0) fe2net,
        COALESCE(TRY(tot_accepted*100.00/gross_count), 0) "aor",

        impression_count,
        click_count,
        COALESCE(TRY(click_count*100.00/impression_count), 0) "ctr",
        median_cobrm_time,
        median_cobra_time,
        median_ocara_time,
        median_cancellation_time,
        median_acceptance_time,
        
        COALESCE(TRY(cobrm*100.00/gross_count), 0) "% cobrm",
        COALESCE(TRY(cobra*100.00/gross_count), 0) "% cobra",
        COALESCE(TRY(ocara*100.00/gross_count), 0) "% ocara",
        COALESCE(TRY(expired*100.00/gross_count), 0) "% expired",
        cobrm, 
        cobra,
        ocara,
        expired
    FROM    
        (
        SELECT
            sample_category,
            user_type,
            COUNT(DISTINCT user_id) customers,
            COUNT(DISTINCT fare_estimate_id) fe_count,
            COUNT(DISTINCT order_id) gross_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' AND spd_fraud_flag != true THEN order_id END) net_count,
            COUNT(DISTINCT CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN order_id END) AS tot_accepted,


           COUNT(DISTINCT impression_adid) as impression_count,
            COUNT(DISTINCT click_adid) as click_count,
            
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRM' THEN order_id END) cobrm,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'COBRA' THEN order_id END) cobra,
            COUNT(DISTINCT CASE WHEN modified_order_status = 'OCARA' THEN order_id END) ocara,
            COUNT(DISTINCT CASE WHEN order_status = 'expired' THEN order_id END) expired,
            
            approx_percentile(CASE WHEN modified_order_status = 'COBRM' THEN time_spent_in_sec END,0.50) as median_cobrm_time,
            approx_percentile(CASE WHEN modified_order_status = 'COBRA' THEN time_spent_in_sec END,0.50) as median_cobra_time,
            approx_percentile(CASE WHEN modified_order_status = 'OCARA' THEN time_spent_in_sec END,0.50) as median_ocara_time,
            approx_percentile(CASE WHEN modified_order_status in ('COBRA','COBRM','OCARA') THEN time_spent_in_sec END,0.50) as median_cancellation_time,
            approx_percentile(CASE WHEN order_status = 'dropped' OR modified_order_status IN ('OCARA', 'aborted') THEN time_taken_to_accp END,0.50) as median_acceptance_time
            
        FROM 
            merge
        where 
            yyyymmdd is not null
        
        GROUP BY 1,2
        )
    ORDER BY 1,2


"""
curr_overall_df=pd.read_sql(curr_overall_query,conn)
